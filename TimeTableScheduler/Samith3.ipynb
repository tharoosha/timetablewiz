# %%
class Space:
    def __init__(self, *args):
        self.code = args[0]
        self.size = args[1]


class Group:
    def __init__(self, *args):
        self.id = args[0]
        self.size = args[1]


class Activity:
    def __init__(self, id, *args):
        self.id = id
        self.subject = args[0]
        self.teacher_id = args[1]
        self.group_ids = args[2]
        self.duration = args[3]

    def __repr__(self):
        return f"Activity(id={self.id}, subject={self.subject}, teacher_id={self.teacher_id}, group_ids={self.group_ids}, duration={self.duration})"


class Period:
    def __init__(self, *args):
        self.space = args[0]
        self.group = args[1]
        self.activity = args[2]

# %%
import json

# Load data from JSON file
with open('sliit_computing_dataset.json', 'r') as file:
    data = json.load(file)

# Create dictionaries to store instances
spaces_dict = {}
groups_dict = {}
activities_dict = {}
slots = []
# Populate the dictionaries with data from the JSON file
for space in data['spaces']:
    spaces_dict[space['code']] = Space(space['code'], space['capacity'])

for group in data['years']:
    groups_dict[group['id']] = Group(group['id'], group['size'])

for activity in data['activities']:
    activities_dict[activity['code']] = Activity(
        activity['code'], activity['subject'], activity['teacher_ids'][0], activity['subgroup_ids'], activity['duration'])

for day in ["MON", "TUE", "WED", "THU", "FRI"]:
    for id in range(1, 9):
        slots.append(day+str(id))
# Print the dictionaries to verify
print(spaces_dict)
print(groups_dict)
print(activities_dict)
print(slots)
# Out:
# {'LH401': <__main__.Space object at 0x000001B91AA20500>, 'LH501': <__main__.Space object at 0x000001B91A9EE450>, 'LAB501': <__main__.Space object at 0x000001B91A9EE840>, 'LAB502': <__main__.Space object at 0x000001B91AA9A570>}
# {'Y1S1.1': <__main__.Group object at 0x000001B91AA9A5D0>, 'Y1S1.2': <__main__.Group object at 0x000001B91956FFB0>, 'Y1S1.3': <__main__.Group object at 0x000001B91AA9A5A0>, 'Y1S1.4': <__main__.Group object at 0x000001B91AA9A600>, 'Y1S1.5': <__main__.Group object at 0x000001B91AA9A630>, 'Y1S2.1': <__main__.Group object at 0x000001B91AA9A660>, 'Y1S2.2': <__main__.Group object at 0x000001B91AA9A690>, 'Y1S2.3': <__main__.Group object at 0x000001B91AA9A6C0>, 'Y1S2.4': <__main__.Group object at 0x000001B91AA9A6F0>, 'Y1S2.5': <__main__.Group object at 0x000001B91AA9A720>, 'Y2S1.1': <__main__.Group object at 0x000001B91AA9A750>, 'Y2S1.2': <__main__.Group object at 0x000001B91AA9A780>, 'Y2S1.3': <__main__.Group object at 0x000001B91AA9A7B0>, 'Y2S1.4': <__main__.Group object at 0x000001B91AA9A7E0>, 'Y2S1.5': <__main__.Group object at 0x000001B91AA9A810>, 'Y2S2.1': <__main__.Group object at 0x000001B91AA9A840>, 'Y2S2.2': <__main__.Group object at 0x000001B91AA9A870>, 'Y2S2.3': <__main__.Group object at 0x000001B91AA9A8A0>, 'Y2S2.4': <__main__.Group object at 0x000001B91AA9A8D0>, 'Y2S2.5': <__main__.Group object at 0x000001B91AA9A900>, 'Y3S1.1': <__main__.Group object at 0x000001B91AA9A930>, 'Y3S1.2': <__main__.Group object at 0x000001B91AA9A960>, 'Y3S1.3': <__main__.Group object at 0x000001B91AA9A990>, 'Y3S1.4': <__main__.Group object at 0x000001B91AA9A9C0>, 'Y3S1.5': <__main__.Group object at 0x000001B91AA9A9F0>, 'Y3S2.1': <__main__.Group object at 0x000001B91AA9AA50>, 'Y3S2.2': <__main__.Group object at 0x000001B91AA9AAB0>, 'Y3S2.3': <__main__.Group object at 0x000001B91AA9AAE0>, 'Y3S2.4': <__main__.Group object at 0x000001B91AA9AB10>, 'Y3S2.5': <__main__.Group object at 0x000001B91AA9AB40>, 'Y4S1.1': <__main__.Group object at 0x000001B91AA9AB70>, 'Y4S1.2': <__main__.Group object at 0x000001B91AA9ABA0>, 'Y4S1.3': <__main__.Group object at 0x000001B91AA9ABD0>, 'Y4S1.4': <__main__.Group object at 0x000001B91AA9AC00>, 'Y4S1.5': <__main__.Group object at 0x000001B91AA9AC30>, 'Y4S2.1': <__main__.Group object at 0x000001B91AA9AC60>, 'Y4S2.2': <__main__.Group object at 0x000001B91AA9AC90>, 'Y4S2.3': <__main__.Group object at 0x000001B91AA9ACC0>, 'Y4S2.4': <__main__.Group object at 0x000001B91AA9ACF0>, 'Y4S2.5': <__main__.Group object at 0x000001B91AA9AD20>}
# {'AC-001': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2), 'AC-002': Activity(id=AC-002, subject=IT1010, teacher_id=FA0000001, group_ids=['Y1S1.1'], duration=1), 'AC-003': Activity(id=AC-003, subject=IT1010, teacher_id=FA0000006, group_ids=['Y1S1.2'], duration=1), 'AC-004': Activity(id=AC-004, subject=IT1010, teacher_id=FA0000009, group_ids=['Y1S1.3'], duration=1), 'AC-005': Activity(id=AC-005, subject=IT1010, teacher_id=FA0000008, group_ids=['Y1S1.4'], duration=1), 'AC-006': Activity(id=AC-006, subject=IT1010, teacher_id=FA0000001, group_ids=['Y1S1.5'], duration=1), 'AC-007': Activity(id=AC-007, subject=IT1020, teacher_id=FA0000003, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2), 'AC-008': Activity(id=AC-008, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.1'], duration=1), 'AC-009': Activity(id=AC-009, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.2'], duration=1), 'AC-010': Activity(id=AC-010, subject=IT1020, teacher_id=FA0000005, group_ids=['Y1S1.3'], duration=1), 'AC-011': Activity(id=AC-011, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.4'], duration=1), 'AC-012': Activity(id=AC-012, subject=IT1020, teacher_id=FA0000006, group_ids=['Y1S1.5'], duration=1), 'AC-013': Activity(id=AC-013, subject=IT1030, teacher_id=FA0000006, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2), 'AC-014': Activity(id=AC-014, subject=IT1030, teacher_id=FA0000001, group_ids=['Y1S1.1'], duration=1), 'AC-015': Activity(id=AC-015, subject=IT1030, teacher_id=FA0000007, group_ids=['Y1S1.2'], duration=1), 'AC-016': Activity(id=AC-016, subject=IT1030, teacher_id=FA0000010, group_ids=['Y1S1.3'], duration=1), 'AC-017': Activity(id=AC-017, subject=IT1030, teacher_id=FA0000002, group_ids=['Y1S1.4'], duration=1), 'AC-018': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1), 'AC-019': Activity(id=AC-019, subject=IT1040, teacher_id=FA0000007, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2), 'AC-020': Activity(id=AC-020, subject=IT1040, teacher_id=FA0000006, group_ids=['Y1S1.1'], duration=1), 'AC-021': Activity(id=AC-021, subject=IT1040, teacher_id=FA0000005, group_ids=['Y1S1.2'], duration=1), 'AC-022': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1), 'AC-023': Activity(id=AC-023, subject=IT1040, teacher_id=FA0000005, group_ids=['Y1S1.4'], duration=1), 'AC-024': Activity(id=AC-024, subject=IT1040, teacher_id=FA0000001, group_ids=['Y1S1.5'], duration=1), 'AC-025': Activity(id=AC-025, subject=IT1550, teacher_id=FA0000004, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2), 'AC-026': Activity(id=AC-026, subject=IT1550, teacher_id=FA0000006, group_ids=['Y1S2.1'], duration=1), 'AC-027': Activity(id=AC-027, subject=IT1550, teacher_id=FA0000009, group_ids=['Y1S2.2'], duration=1), 'AC-028': Activity(id=AC-028, subject=IT1550, teacher_id=FA0000008, group_ids=['Y1S2.3'], duration=1), 'AC-029': Activity(id=AC-029, subject=IT1550, teacher_id=FA0000009, group_ids=['Y1S2.4'], duration=1), 'AC-030': Activity(id=AC-030, subject=IT1550, teacher_id=FA0000007, group_ids=['Y1S2.5'], duration=1), 'AC-031': Activity(id=AC-031, subject=IT1560, teacher_id=FA0000007, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2), 'AC-032': Activity(id=AC-032, subject=IT1560, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1), 'AC-033': Activity(id=AC-033, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=1), 'AC-034': Activity(id=AC-034, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1), 'AC-035': Activity(id=AC-035, subject=IT1560, teacher_id=FA0000005, group_ids=['Y1S2.4'], duration=1), 'AC-036': Activity(id=AC-036, subject=IT1560, teacher_id=FA0000008, group_ids=['Y1S2.5'], duration=1), 'AC-037': Activity(id=AC-037, subject=IT1560, teach ...
# ['MON1', 'MON2', 'MON3', 'MON4', 'MON5', 'MON6', 'MON7', 'MON8', 'TUE1', 'TUE2', 'TUE3', 'TUE4', 'TUE5', 'TUE6', 'TUE7', 'TUE8', 'WED1', 'WED2', 'WED3', 'WED4', 'WED5', 'WED6', 'WED7', 'WED8', 'THU1', 'THU2', 'THU3', 'THU4', 'THU5', 'THU6', 'THU7', 'THU8', 'FRI1', 'FRI2', 'FRI3', 'FRI4', 'FRI5', 'FRI6', 'FRI7', 'FRI8']

# %%
vacant_rooms = []


def evaluator(timetable):
    vacant_room = 0
    prof_conflicts = 0
    room_size_conflicts = 0
    sub_group_conflicts = 0
    unasigned_activities = len(activities_dict)
    activities_set = set()

    for slot in timetable:
        prof_set = set()
        sub_group_set = set()
        for room in timetable[slot]:
            activity = timetable[slot][room]

            if not isinstance(activity, Activity):
                vacant_room += 1
                vacant_rooms.append((slot, room))

            else:
                activities_set.add(activity.id)
                if activity.teacher_id in prof_set:
                    prof_conflicts += 1

                sub_group_conflicts += len(
                    set(activity.group_ids).intersection(sub_group_set))

                group_size = 0
                for group_id in activity.group_ids:
                    group_size += groups_dict[group_id].size
                    sub_group_set.add(group_id)

                if group_size > spaces_dict[room].size:
                    room_size_conflicts += 1
                teacher_id = activity.teacher_id
                prof_set.add(teacher_id)
    unasigned_activities -= len(activities_set)
    return vacant_room, prof_conflicts, room_size_conflicts, sub_group_conflicts, unasigned_activities
    # return f" Vacant Rooms : {vacant_room} \nLecturer Conflicts : {prof_conflicts}\nRoom Size Conflicts : {room_size_conflicts}\nSub Group Conflicts:{sub_group_conflicts} \nNo:of Unassigned Activities:{unasigned_activities} "

# %%
import random

POPULATION_SIZE = 50
NUM_GENERATIONS = 100
MUTATION_RATE = 0.1
CROSSOVER_RATE = 0.8


def get_classsize(activity: Activity) -> int:
    classsize = 0
    for id in activity.group_ids:
        classsize += groups_dict[id].size
    return classsize

def evaluate_population(population):
    """Evaluate each individual using the provided evaluator function."""
    fitness_values = []
    for timetable in population:
        fitness_values.append(evaluator(timetable))
    return fitness_values

def mutate(individual):
    """Perform mutation by randomly swapping activities in the timetable."""
    slots = list(individual.keys())
    slot1, slot2 = random.sample(slots, 2)
    room1, room2 = random.choice(list(individual[slot1])), random.choice(list(individual[slot2]))
    
    individual[slot1][room1], individual[slot2][room2] = individual[slot2][room2], individual[slot1][room1]

def crossover(parent1, parent2):
    """Perform crossover by swapping time slots between two parents."""
    child1, child2 = parent1.copy(), parent2.copy()
    slots = list(parent1.keys())
    split = random.randint(0, len(slots) - 1)
    
    for i in range(split, len(slots)):
        child1[slots[i]], child2[slots[i]] = parent2[slots[i]], parent1[slots[i]]
    
    return child1, child2

def fast_nondominated_sort(fitness_values):
    """Perform non-dominated sorting based on the multi-objective fitness values."""
    fronts = [[]]
    S = [[] for _ in range(len(fitness_values))]
    n = [0] * len(fitness_values)
    rank = [0] * len(fitness_values)

    for p in range(len(fitness_values)):
        for q in range(len(fitness_values)):
            if dominates(fitness_values[p], fitness_values[q]):
                S[p].append(q)
            elif dominates(fitness_values[q], fitness_values[p]):
                n[p] += 1
        if n[p] == 0:
            rank[p] = 0
            fronts[0].append(p)

    i = 0
    while fronts[i]:
        next_front = []
        for p in fronts[i]:
            for q in S[p]:
                n[q] -= 1
                if n[q] == 0:
                    rank[q] = i + 1
                    next_front.append(q)
        i += 1
        fronts.append(next_front)

    return fronts[:-1]

def dominates(fitness1, fitness2):
    """Return True if fitness1 dominates fitness2."""
    return all(f1 <= f2 for f1, f2 in zip(fitness1, fitness2)) and any(f1 < f2 for f1, f2 in zip(fitness1, fitness2))

def calculate_crowding_distance(front, fitness_values):
    """Calculate crowding distance for a front."""
    distances = [0] * len(front)
    num_objectives = len(fitness_values[0])

    for m in range(num_objectives):
        front.sort(key=lambda x: fitness_values[x][m])
        distances[0] = distances[-1] = float('inf')

        min_value = fitness_values[front[0]][m]
        max_value = fitness_values[front[-1]][m]
        if max_value == min_value:
            continue

        for i in range(1, len(front) - 1):
            distances[i] += (fitness_values[front[i + 1]][m] - fitness_values[front[i - 1]][m]) / (max_value - min_value)

    return distances

def select_parents(population, fitness_values):
    """Perform tournament selection based on non-dominated sorting and crowding distance."""
    fronts = fast_nondominated_sort(fitness_values)
    selected = []
    
    for front in fronts:
        if len(selected) + len(front) > POPULATION_SIZE:
            crowding_distances = calculate_crowding_distance(front, fitness_values)
            sorted_front = sorted(zip(front, crowding_distances), key=lambda x: x[1], reverse=True)
            selected.extend([x[0] for x in sorted_front[:POPULATION_SIZE - len(selected)]])
            break
        else:
            selected.extend(front)

    return [population[i] for i in selected]

def generate_initial_population():
    """Generate an initial population with random timetables."""
    population = []

    for _ in range(POPULATION_SIZE):
        timetable = {}
        activity_slots = {activity.id: []
                          for activity in activities_dict.values()}
        activities_remain = [activity.id for activity in activities_dict.values()
                             for _ in range(activity.duration)]
        for slot in slots:
            timetable[slot] = {}
            for space_id in spaces_dict.keys():
                space = spaces_dict[space_id]
                a_activities = [activity for activity in activities_remain if get_classsize(
                    activities_dict[activity]) <= space.size]
                a_activities = [
                    activity for activity in a_activities if slot not in activity_slots[activity]]
                activity = random.sample(a_activities,1)[0]
                timetable[slot][space_id] = activities_dict[activity]
                activity_slots[activity].append(slot)

        population.append(timetable)
    return population

def nsga2():
    """Main NSGA-II algorithm loop."""
    population = generate_initial_population()

    for generation in range(NUM_GENERATIONS):
        fitness_values = evaluate_population(population)
        new_population = []

        while len(new_population) < POPULATION_SIZE:
            parent1, parent2 = random.sample(population, 2)
            if random.random() < CROSSOVER_RATE:
                child1, child2 = crossover(parent1, parent2)
            else:
                child1, child2 = parent1.copy(), parent2.copy()

            if random.random() < MUTATION_RATE:
                mutate(child1)
            if random.random() < MUTATION_RATE:
                mutate(child2)

            new_population.extend([child1, child2])

        population = select_parents(new_population, evaluate_population(new_population))
    
    return population

# Run NSGA-II
final_population = nsga2()

# %%
final_population
# Out:
# [{'MON1': {'LH401': Activity(id=AC-140, subject=IT3550, teacher_id=FA0000007, group_ids=['Y3S2.4'], duration=1),
#    'LH501': Activity(id=AC-139, subject=IT3550, teacher_id=FA0000001, group_ids=['Y3S2.3'], duration=1),
#    'LAB501': Activity(id=AC-006, subject=IT1010, teacher_id=FA0000001, group_ids=['Y1S1.5'], duration=1),
#    'LAB502': Activity(id=AC-138, subject=IT3550, teacher_id=FA0000010, group_ids=['Y3S2.2'], duration=1)},
#   'MON2': {'LH401': Activity(id=AC-077, subject=IT2040, teacher_id=FA0000006, group_ids=['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'], duration=2),
#    'LH501': Activity(id=AC-132, subject=IT3040, teacher_id=FA0000005, group_ids=['Y3S1.2'], duration=1),
#    'LAB501': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1),
#    'LAB502': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1)},
#   'MON3': {'LH401': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1),
#    'LH501': Activity(id=AC-088, subject=IT2550, teacher_id=FA0000007, group_ids=['Y2S2.5'], duration=1),
#    'LAB501': Activity(id=AC-072, subject=IT2030, teacher_id=FA0000010, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-158, subject=IT3580, teacher_id=FA0000009, group_ids=['Y3S2.4'], duration=1)},
#   'MON4': {'LH401': Activity(id=AC-165, subject=IT4010, teacher_id=FA0000009, group_ids=['Y4S1.5'], duration=1),
#    'LH501': Activity(id=AC-130, subject=IT3040, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB501': Activity(id=AC-014, subject=IT1030, teacher_id=FA0000001, group_ids=['Y1S1.1'], duration=1),
#    'LAB502': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1)},
#   'MON5': {'LH401': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2),
#    'LH501': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LAB501': Activity(id=AC-078, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-093, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.4'], duration=1)},
#   'MON6': {'LH401': Activity(id=AC-115, subject=IT3010, teacher_id=FA0000010, group_ids=['Y3S1.3'], duration=1),
#    'LH501': Activity(id=AC-045, subject=IT1570, teacher_id=FA0000004, group_ids=['Y1S2.3'], duration=1),
#    'LAB501': Activity(id=AC-144, subject=IT3560, teacher_id=FA0000001, group_ids=['Y3S2.2'], duration=1),
#    'LAB502': Activity(id=AC-010, subject=IT1020, teacher_id=FA0000005, group_ids=['Y1S1.3'], duration=1)},
#   'MON7': {'LH401': Activity(id=AC-031, subject=IT1560, teacher_id=FA0000007, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2),
#    'LAB501': Activity(id=AC-147, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.5'], duration=1),
#    'LAB502': Activity(id=AC-098, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.4'], duration=2)},
#   'MON8': {'LH401': Activity(id=AC-182, subject=IT4550, teacher_id=FA0000004, group_ids=['Y4S2.4'], duration=1),
#    'LH501': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LAB501': Activity(id=AC-097, subject=IT2560, teacher_id=FA0000002, group_ids=['Y2S2.3'], duration=2),
#    'LAB502': Activity(id=AC-036, subject=IT1560, teacher_id=FA0000008, group_ids=['Y1S2.5'], duration=1)},
#   'TUE1': {'LH401': Activity(id=AC-108, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.2'], duration=1),
#    'LH501': Activity(id=AC-119, subject=IT3020, teacher_id=FA0000002, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-096, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.2'], duration=2),
#    'LAB502': Activity(id=AC-076, subject=IT2030, teacher_id=FA0000001, group_ids=['Y2S1.5'], duration=1)},
#   'TUE2': {'LH401': Activity(id=AC-032, subject=IT1560, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1),
#    'LH501': Activity(id=AC-173, subject=IT4030, teacher_id=FA0000008, group_ids=['Y4S1.1'], duration=1),
#    'LAB501': Activity(id=AC-159, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.5'], duration=1),
#    'LAB502': Activity(id=AC-153, subject=IT3570, teacher_id=FA0000008, group_ids=['Y3S2.5'], duration=1)},
#   'TUE3': {'LH401': Activity(id=AC-085, subject=IT2550, teacher_id=FA0000008, group_ids=['Y2S2.2'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-155, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.1'], duration=1),
#    'LAB502': Activity(id=AC-021, subject=IT1040, teacher_id=FA0000005, group_ids=['Y1S1.2'], duration=1)},
#   'TUE4': {'LH401': Activity(id=AC-017, subject=IT1030, teacher_id=FA0000002, group_ids=['Y1S1.4'], duration=1),
#    'LH501': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LAB501': Activity(id=AC-195, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.5'], duration=1),
#    'LAB502': Activity(id=AC-070, subject=IT2020, teacher_id=FA0000007, group_ids=['Y2S1.5'], duration=1)},
#   'TUE5': {'LH401': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LH501': Activity(id=AC-160, subject=IT4010, teacher_id=FA0000006, group_ids=['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'], duration=2),
#    'LAB501': Activity(id=AC-051, subject=IT1580, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1),
#    'LAB502': Activity(id=AC-187, subject=IT4560, teacher_id=FA0000010, group_ids=['Y4S2.3'], duration=1)},
#   'TUE6': {'LH401': Activity(id=AC-038, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=2),
#    'LH501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB501': Activity(id=AC-033, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=1),
#    'LAB502': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1)},
#   'TUE7': {'LH401': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LH501': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-181, subject=IT4550, teacher_id=FA0000002, group_ids=['Y4S2.3'], duration=1),
#    'LAB502': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1)},
#   'TUE8': {'LH401': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LH501': Activity(id=AC-144, subject=IT3560, teacher_id=FA0000001, group_ids=['Y3S2.2'], duration=1),
#    'LAB501': Activity(id=AC-040, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.4'], duration=2),
#    'LAB502': Activity(id=AC-129, subject=IT3030, teacher_id=FA0000010, group_ids=['Y3S1.5'], duration=1)},
#   'WED1': {'LH401': Activity(id=AC-042, subject=IT1570, teacher_id=FA0000001, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-118, subject=IT3020, teacher_id=FA0000001, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB501': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LAB502': Activity(id=AC-061, subject=IT2010, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=2)},
#   'WED2': {'LH401': Activity(id=AC-134, subject=IT3040, teacher_id=FA0000010, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-061, subject=IT2010, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=2),
#    'LAB501': Activity(id=AC-079, subject=IT2040, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=1),
#    'LAB502': Activity(id=AC-145, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.3'], duration=1)},
#   'WED3': {'LH401': Activity(id=AC-130, subject=IT3040, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LH501': Activity(id=AC-076, subject=IT2030, teacher_id=FA0000001, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-111, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.5'], duration=1),
#    'LAB502': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2)},
#   'WED4': {'LH401': Activity(id=AC-193, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.3'], duration=1),
#    'LH501': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2),
#    'LAB501': Activity(id=AC-008, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.1'], duration=1),
#    'LAB502': Activity(id=AC-102, subject=IT2570, teacher_id=FA0000006, group_ids=['Y2S2.2'], duration=1)},
#   'WED5': {'LH401': Activity(id=AC-159, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.5'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB502': Activity(id=AC-134, subject=IT3040, teacher_id=FA0000010, group_ids=['Y3S1.4'], duration=1)},
#   'WED6': {'LH401': Activity(id=AC-074, subject=IT2030, teacher_id=FA0000009, group_ids=['Y2S1.3'], duration=1),
#    'LH501': Activity(id=AC-049, subject=IT1580, teacher_id=FA0000010, group_ids=['Y1S2.1'], duration=1),
#    'LAB501': Activity(id=AC-108, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.2'], duration=1),
#    'LAB502': Activity(id=AC-104, subject=IT2570, teacher_id=FA0000002, group_ids=['Y2S2.4'], duration=1)},
#   'WED7': {'LH401': Activity(id=AC-137, subject=IT3550, teacher_id=FA0000003, group_ids=['Y3S2.1'], duration=1),
#    'LH501': Activity(id=AC-066, subject=IT2020, teacher_id=FA0000008, group_ids=['Y2S1.1'], duration=1),
#    'LAB501': Activity(id=AC-063, subject=IT2010, teacher_id=FA0000006, group_ids=['Y2S1.4'], duration=2),
#    'LAB502': Activity(id=AC-176, subject=IT4030, teacher_id=FA0000007, group_ids=['Y4S1.4'], duration=1)},
#   'WED8': {'LH401': Activity(id=AC-141, subject=IT3550, teacher_id=FA0000001, group_ids=['Y3S2.5'], duration=1),
#    'LH501': Activity(id=AC-171, subject=IT4020, teacher_id=FA0000009, group_ids=['Y4S1.5'], duration=1),
#    'LAB501': Activity(id=AC-069, subject=IT2020, teacher_id=FA0000009, group_ids=['Y2S1.4'], duration=1),
#    'LAB502': Activity(id=AC-028, subject=IT1550, teacher_id=FA0000008, group_ids=['Y1S2.3'], duration=1)},
#   'THU1': {'LH401': Activity(id=AC-175, subject=IT4030, teacher_id=FA0000004, group_ids=['Y4S1.3'], duration=1),
#    'LH501': Activity(id=AC-131, subject=IT3040, teacher_id=FA0000005, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-055, subject=IT2010, teacher_id=FA0000007, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-188, subject=IT4560, teacher_id=FA0000001, group_ids=['Y4S2.4'], duration=1)},
#   'THU2': {'LH401': Activity(id=AC-043, subject=IT1570, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1),
#    'LH501': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-127, subject=IT3030, teacher_id=FA0000003, group_ids=['Y3S1.3'], duration=1),
#    'LAB502': Activity(id=AC-125, subject=IT3030, teacher_id=FA0000006, group_ids=['Y3S1.1'], duration=1)},
#   'THU3': {'LH401': Activity(id=AC-116, subject=IT3010, teacher_id=FA0000006, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-149, subject=IT3570, teacher_id=FA0000009, group_ids=['Y3S2.1'], duration=1),
#    'LAB501': Activity(id=AC-118, subject=IT3020, teacher_id=FA0000001, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB502': Activity(id=AC-195, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.5'], duration=1)},
#   'THU4': {'LH401': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LH501': Activity(id=AC-011, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.4'], duration=1),
#    'LAB501': Activity(id=AC-009, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.2'], duration=1),
#    'LAB502': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2)},
#   'THU5': {'LH401': Activity(id=AC-194, subject=IT4570, teacher_id=FA0000005, group_ids=['Y4S2.4'], duration=1),
#    'LH501': Activity(id=AC-183, subject=IT4550, teacher_id=FA0000007, group_ids=['Y4S2.5'], duration=1),
#    'LAB501': Activity(id=AC-156, subject=IT3580, teacher_id=FA0000010, group_ids=['Y3S2.2'], duration=1),
#    'LAB502': Activity(id=AC-034, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1)},
#   'THU6': {'LH401': Activity(id=AC-169, subject=IT4020, teacher_id=FA0000008, group_ids=['Y4S1.3'], duration=1),
#    'LH501': Activity(id=AC-142, subject=IT3560, teacher_id=FA0000008, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#    'LAB501': Activity(id=AC-137, subject=IT3550, teacher_id=FA0000003, group_ids=['Y3S2.1'], duration=1),
#    'LAB502': Activity(id=AC-050, subject=IT1580, teacher_id=FA0000002, group_ids=['Y1S2.2'], duration=1)},
#   'THU7': {'LH401': Activity(id=AC-128, subject=IT3030, teacher_id=FA0000008, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB501': Activity(id=AC-110, subject=IT2580, teacher_id=FA0000006, group_ids=['Y2S2.4'], duration=1),
#    'LAB502': Activity(id=AC-191, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.1'], duration=1)},
#   'THU8': {'LH401': Activity(id=AC-081, subject=IT2040, teacher_id=FA0000007, group_ids=['Y2S1.4'], duration=1),
#    'LH501': Activity(id=AC-192, subject=IT4570, teacher_id=FA0000001, group_ids=['Y4S2.2'], duration=1),
#    'LAB501': Activity(id=AC-175, subject=IT4030, teacher_id=FA0000004, group_ids=['Y4S1.3'], duration=1),
#    'LAB502': Activity(id=AC-070, subject=IT2020, teacher_id=FA0000007, group_ids=['Y2S1.5'], duration=1)},
#   'FRI1': {'LH401': Activity(id=AC-191, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.1'], duration=1),
#    'LH501': Activity(id=AC-062, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.3'], duration=2),
#    'LAB501': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1),
#    'LAB502': Activity(id=AC-164, subject=IT4010, teacher_id=FA0000005, group_ids=['Y4S1.4'], duration=1)},
#   'FRI2': {'LH401': Activity(id=AC-028, subject=IT1550, teacher_id=FA0000008, group_ids=['Y1S2.3'], duration=1),
#    'LH501': Activity(id=AC-194, subject=IT4570, teacher_id=FA0000005, group_ids=['Y4S2.4'], duration=1),
#    'LAB501': Activity(id=AC-180, subject=IT4550, teacher_id=FA0000001, group_ids=['Y4S2.2'], duration=1),
#    'LAB502': Activity(id=AC-114, subject=IT3010, teacher_id=FA0000010, group_ids=['Y3S1.2'], duration=1)},
#   'FRI3': {'LH401': Activity(id=AC-111, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.5'], duration=1),
#    'LH501': Activity(id=AC-053, subject=IT1580, teacher_id=FA0000001, group_ids=['Y1S2.5'], duration=1),
#    'LAB501': Activity(id=AC-012, subject=IT1020, teacher_id=FA0000006, group_ids=['Y1S1.5'], duration=1),
#    'LAB502': Activity(id=AC-015, subject=IT1030, teacher_id=FA0000007, group_ids=['Y1S1.2'], duration=1)},
#   'FRI4': {'LH401': Activity(id=AC-181, subject=IT4550, teacher_id=FA0000002, group_ids=['Y4S2.3'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-016, subject=IT1030, teacher_id=FA0000010, group_ids=['Y1S1.3'], duration=1),
#    'LAB502': Activity(id=AC-129, subject=IT3030, teacher_id=FA0000010, group_ids=['Y3S1.5'], duration=1)},
#   'FRI5': {'LH401': Activity(id=AC-127, subject=IT3030, teacher_id=FA0000003, group_ids=['Y3S1.3'], duration=1),
#    'LH501': Activity(id=AC-046, subject=IT1570, teacher_id=FA0000009, group_ids=['Y1S2.4'], duration=1),
#    'LAB501': Activity(id=AC-005, subject=IT1010, teacher_id=FA0000008, group_ids=['Y1S1.4'], duration=1),
#    'LAB502': Activity(id=AC-101, subject=IT2570, teacher_id=FA0000005, group_ids=['Y2S2.1'], duration=1)},
#   'FRI6': {'LH401': Activity(id=AC-169, subject=IT4020, teacher_id=FA0000008, group_ids=['Y4S1.3'], duration=1),
#    'LH501': Activity(id=AC-103, subject=IT2570, teacher_id=FA0000008, group_ids=['Y2S2.3'], duration=1),
#    'LAB501': Activity(id=AC-061, subject=IT2010, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=2),
#    'LAB502': Activity(id=AC-174, subject=IT4030, teacher_id=FA0000002, group_ids=['Y4S1.2'], duration=1)},
#   'FRI7': {'LH401': Activity(id=AC-072, subject=IT2030, teacher_id=FA0000010, group_ids=['Y2S1.1'], duration=1),
#    'LH501': Activity(id=AC-126, subject=IT3030, teacher_id=FA0000006, group_ids=['Y3S1.2'], duration=1),
#    'LAB501': Activity(id=AC-039, subject=IT1560, teacher_id=FA0000010, group_ids=['Y1S2.3'], duration=2),
#    'LAB502': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1)},
#   'FRI8': {'LH401': Activity(id=AC-069, subject=IT2020, teacher_id=FA0000009, group_ids=['Y2S1.4'], duration=1),
#    'LH501': Activity(id=AC-084, subject=IT2550, teacher_id=FA0000008, group_ids=['Y2S2.1'], duration=1),
#    'LAB501': Activity(id=AC-009, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.2'], duration=1),
#    'LAB502': Activity(id=AC-051, subject=IT1580, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1)}},
#  {'MON1': {'LH401': Activity(id=AC-140, subject=IT3550, teacher_id=FA0000007, group_ids=['Y3S2.4'], duration=1),
#    'LH501': Activity(id=AC-139, subject=IT3550, teacher_id=FA0000001, group_ids=['Y3S2.3'], duration=1),
#    'LAB501': Activity(id=AC-006, subject=IT1010, teacher_id=FA0000001, group_ids=['Y1S1.5'], duration=1),
#    'LAB502': Activity(id=AC-138, subject=IT3550, teacher_id=FA0000010, group_ids=['Y3S2.2'], duration=1)},
#   'MON2': {'LH401': Activity(id=AC-077, subject=IT2040, teacher_id=FA0000006, group_ids=['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'], duration=2),
#    'LH501': Activity(id=AC-132, subject=IT3040, teacher_id=FA0000005, group_ids=['Y3S1.2'], duration=1),
#    'LAB501': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1),
#    'LAB502': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1)},
#   'MON3': {'LH401': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1),
#    'LH501': Activity(id=AC-088, subject=IT2550, teacher_id=FA0000007, group_ids=['Y2S2.5'], duration=1),
#    'LAB501': Activity(id=AC-072, subject=IT2030, teacher_id=FA0000010, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-158, subject=IT3580, teacher_id=FA0000009, group_ids=['Y3S2.4'], duration=1)},
#   'MON4': {'LH401': Activity(id=AC-165, subject=IT4010, teacher_id=FA0000009, group_ids=['Y4S1.5'], duration=1),
#    'LH501': Activity(id=AC-130, subject=IT3040, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB501': Activity(id=AC-014, subject=IT1030, teacher_id=FA0000001, group_ids=['Y1S1.1'], duration=1),
#    'LAB502': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1)},
#   'MON5': {'LH401': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2),
#    'LH501': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LAB501': Activity(id=AC-078, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-093, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.4'], duration=1)},
#   'MON6': {'LH401': Activity(id=AC-115, subject=IT3010, teacher_id=FA0000010, group_ids=['Y3S1.3'], duration=1),
#    'LH501': Activity(id=AC-045, subject=IT1570, teacher_id=FA0000004, group_ids=['Y1S2.3'], duration=1),
#    'LAB501': Activity(id=AC-144, subject=IT3560, teacher_id=FA0000001, group_ids=['Y3S2.2'], duration=1),
#    'LAB502': Activity(id=AC-010, subject=IT1020, teacher_id=FA0000005, group_ids=['Y1S1.3'], duration=1)},
#   'MON7': {'LH401': Activity(id=AC-031, subject=IT1560, teacher_id=FA0000007, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2),
#    'LAB501': Activity(id=AC-147, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.5'], duration=1),
#    'LAB502': Activity(id=AC-098, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.4'], duration=2)},
#   'MON8': {'LH401': Activity(id=AC-182, subject=IT4550, teacher_id=FA0000004, group_ids=['Y4S2.4'], duration=1),
#    'LH501': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LAB501': Activity(id=AC-097, subject=IT2560, teacher_id=FA0000002, group_ids=['Y2S2.3'], duration=2),
#    'LAB502': Activity(id=AC-036, subject=IT1560, teacher_id=FA0000008, group_ids=['Y1S2.5'], duration=1)},
#   'TUE1': {'LH401': Activity(id=AC-108, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.2'], duration=1),
#    'LH501': Activity(id=AC-119, subject=IT3020, teacher_id=FA0000002, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-096, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.2'], duration=2),
#    'LAB502': Activity(id=AC-076, subject=IT2030, teacher_id=FA0000001, group_ids=['Y2S1.5'], duration=1)},
#   'TUE2': {'LH401': Activity(id=AC-032, subject=IT1560, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1),
#    'LH501': Activity(id=AC-173, subject=IT4030, teacher_id=FA0000008, group_ids=['Y4S1.1'], duration=1),
#    'LAB501': Activity(id=AC-159, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.5'], duration=1),
#    'LAB502': Activity(id=AC-153, subject=IT3570, teacher_id=FA0000008, group_ids=['Y3S2.5'], duration=1)},
#   'TUE3': {'LH401': Activity(id=AC-085, subject=IT2550, teacher_id=FA0000008, group_ids=['Y2S2.2'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-155, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.1'], duration=1),
#    'LAB502': Activity(id=AC-021, subject=IT1040, teacher_id=FA0000005, group_ids=['Y1S1.2'], duration=1)},
#   'TUE4': {'LH401': Activity(id=AC-017, subject=IT1030, teacher_id=FA0000002, group_ids=['Y1S1.4'], duration=1),
#    'LH501': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LAB501': Activity(id=AC-195, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.5'], duration=1),
#    'LAB502': Activity(id=AC-070, subject=IT2020, teacher_id=FA0000007, group_ids=['Y2S1.5'], duration=1)},
#   'TUE5': {'LH401': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LH501': Activity(id=AC-160, subject=IT4010, teacher_id=FA0000006, group_ids=['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'], duration=2),
#    'LAB501': Activity(id=AC-051, subject=IT1580, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1),
#    'LAB502': Activity(id=AC-187, subject=IT4560, teacher_id=FA0000010, group_ids=['Y4S2.3'], duration=1)},
#   'TUE6': {'LH401': Activity(id=AC-038, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=2),
#    'LH501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB501': Activity(id=AC-033, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=1),
#    'LAB502': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1)},
#   'TUE7': {'LH401': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LH501': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-181, subject=IT4550, teacher_id=FA0000002, group_ids=['Y4S2.3'], duration=1),
#    'LAB502': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1)},
#   'TUE8': {'LH401': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LH501': Activity(id=AC-144, subject=IT3560, teacher_id=FA0000001, group_ids=['Y3S2.2'], duration=1),
#    'LAB501': Activity(id=AC-040, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.4'], duration=2),
#    'LAB502': Activity(id=AC-129, subject=IT3030, teacher_id=FA0000010, group_ids=['Y3S1.5'], duration=1)},
#   'WED1': {'LH401': Activity(id=AC-042, subject=IT1570, teacher_id=FA0000001, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-118, subject=IT3020, teacher_id=FA0000001, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB501': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LAB502': Activity(id=AC-061, subject=IT2010, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=2)},
#   'WED2': {'LH401': Activity(id=AC-134, subject=IT3040, teacher_id=FA0000010, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-061, subject=IT2010, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=2),
#    'LAB501': Activity(id=AC-079, subject=IT2040, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=1),
#    'LAB502': Activity(id=AC-145, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.3'], duration=1)},
#   'WED3': {'LH401': Activity(id=AC-130, subject=IT3040, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LH501': Activity(id=AC-076, subject=IT2030, teacher_id=FA0000001, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-111, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.5'], duration=1),
#    'LAB502': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2)},
#   'WED4': {'LH401': Activity(id=AC-193, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.3'], duration=1),
#    'LH501': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2),
#    'LAB501': Activity(id=AC-008, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.1'], duration=1),
#    'LAB502': Activity(id=AC-102, subject=IT2570, teacher_id=FA0000006, group_ids=['Y2S2.2'], duration=1)},
#   'WED5': {'LH401': Activity(id=AC-159, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.5'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB502': Activity(id=AC-134, subject=IT3040, teacher_id=FA0000010, group_ids=['Y3S1.4'], duration=1)},
#   'WED6': {'LH401': Activity(id=AC-074, subject=IT2030, teacher_id=FA0000009, group_ids=['Y2S1.3'], duration=1),
#    'LH501': Activity(id=AC-049, subject=IT1580, teacher_id=FA0000010, group_ids=['Y1S2.1'], duration=1),
#    'LAB501': Activity(id=AC-108, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.2'], duration=1),
#    'LAB502': Activity(id=AC-104, subject=IT2570, teacher_id=FA0000002, group_ids=['Y2S2.4'], duration=1)},
#   'WED7': {'LH401': Activity(id=AC-137, subject=IT3550, teacher_id=FA0000003, group_ids=['Y3S2.1'], duration=1),
#    'LH501': Activity(id=AC-066, subject=IT2020, teacher_id=FA0000008, group_ids=['Y2S1.1'], duration=1),
#    'LAB501': Activity(id=AC-063, subject=IT2010, teacher_id=FA0000006, group_ids=['Y2S1.4'], duration=2),
#    'LAB502': Activity(id=AC-176, subject=IT4030, teacher_id=FA0000007, group_ids=['Y4S1.4'], duration=1)},
#   'WED8': {'LH401': Activity(id=AC-141, subject=IT3550, teacher_id=FA0000001, group_ids=['Y3S2.5'], duration=1),
#    'LH501': Activity(id=AC-171, subject=IT4020, teacher_id=FA0000009, group_ids=['Y4S1.5'], duration=1),
#    'LAB501': Activity(id=AC-069, subject=IT2020, teacher_id=FA0000009, group_ids=['Y2S1.4'], duration=1),
#    'LAB502': Activity(id=AC-028, subject=IT1550, teacher_id=FA0000008, group_ids=['Y1S2.3'], duration=1)},
#   'THU1': {'LH401': Activity(id=AC-175, subject=IT4030, teacher_id=FA0000004, group_ids=['Y4S1.3'], duration=1),
#    'LH501': Activity(id=AC-131, subject=IT3040, teacher_id=FA0000005, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-055, subject=IT2010, teacher_id=FA0000007, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-188, subject=IT4560, teacher_id=FA0000001, group_ids=['Y4S2.4'], duration=1)},
#   'THU2': {'LH401': Activity(id=AC-043, subject=IT1570, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1),
#    'LH501': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-127, subject=IT3030, teacher_id=FA0000003, group_ids=['Y3S1.3'], duration=1),
#    'LAB502': Activity(id=AC-125, subject=IT3030, teacher_id=FA0000006, group_ids=['Y3S1.1'], duration=1)},
#   'THU3': {'LH401': Activity(id=AC-116, subject=IT3010, teacher_id=FA0000006, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-149, subject=IT3570, teacher_id=FA0000009, group_ids=['Y3S2.1'], duration=1),
#    'LAB501': Activity(id=AC-118, subject=IT3020, teacher_id=FA0000001, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB502': Activity(id=AC-195, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.5'], duration=1)},
#   'THU4': {'LH401': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LH501': Activity(id=AC-011, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.4'], duration=1),
#    'LAB501': Activity(id=AC-009, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.2'], duration=1),
#    'LAB502': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2)},
#   'THU5': {'LH401': Activity(id=AC-194, subject=IT4570, teacher_id=FA0000005, group_ids=['Y4S2.4'], duration=1),
#    'LH501': Activity(id=AC-183, subject=IT4550, teacher_id=FA0000007, group_ids=['Y4S2.5'], duration=1),
#    'LAB501': Activity(id=AC-156, subject=IT3580, teacher_id=FA0000010, group_ids=['Y3S2.2'], duration=1),
#    'LAB502': Activity(id=AC-034, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1)},
#   'THU6': {'LH401': Activity(id=AC-169, subject=IT4020, teacher_id=FA0000008, group_ids=['Y4S1.3'], duration=1),
#    'LH501': Activity(id=AC-142, subject=IT3560, teacher_id=FA0000008, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#    'LAB501': Activity(id=AC-137, subject=IT3550, teacher_id=FA0000003, group_ids=['Y3S2.1'], duration=1),
#    'LAB502': Activity(id=AC-050, subject=IT1580, teacher_id=FA0000002, group_ids=['Y1S2.2'], duration=1)},
#   'THU7': {'LH401': Activity(id=AC-128, subject=IT3030, teacher_id=FA0000008, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB501': Activity(id=AC-110, subject=IT2580, teacher_id=FA0000006, group_ids=['Y2S2.4'], duration=1),
#    'LAB502': Activity(id=AC-191, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.1'], duration=1)},
#   'THU8': {'LH401': Activity(id=AC-081, subject=IT2040, teacher_id=FA0000007, group_ids=['Y2S1.4'], duration=1),
#    'LH501': Activity(id=AC-192, subject=IT4570, teacher_id=FA0000001, group_ids=['Y4S2.2'], duration=1),
#    'LAB501': Activity(id=AC-175, subject=IT4030, teacher_id=FA0000004, group_ids=['Y4S1.3'], duration=1),
#    'LAB502': Activity(id=AC-070, subject=IT2020, teacher_id=FA0000007, group_ids=['Y2S1.5'], duration=1)},
#   'FRI1': {'LH401': Activity(id=AC-191, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.1'], duration=1),
#    'LH501': Activity(id=AC-062, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.3'], duration=2),
#    'LAB501': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1),
#    'LAB502': Activity(id=AC-164, subject=IT4010, teacher_id=FA0000005, group_ids=['Y4S1.4'], duration=1)},
#   'FRI2': {'LH401': Activity(id=AC-190, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'], duration=2),
#    'LH501': Activity(id=AC-003, subject=IT1010, teacher_id=FA0000006, group_ids=['Y1S1.2'], duration=1),
#    'LAB501': Activity(id=AC-154, subject=IT3580, teacher_id=FA0000009, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#    'LAB502': Activity(id=AC-176, subject=IT4030, teacher_id=FA0000007, group_ids=['Y4S1.4'], duration=1)},
#   'FRI3': {'LH401': Activity(id=AC-093, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.4'], duration=1),
#    'LH501': Activity(id=AC-112, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB501': Activity(id=AC-091, subject=IT2560, teacher_id=FA0000001, group_ids=['Y2S2.2'], duration=1),
#    'LAB502': Activity(id=AC-103, subject=IT2570, teacher_id=FA0000008, group_ids=['Y2S2.3'], duration=1)},
#   'FRI4': {'LH401': Activity(id=AC-181, subject=IT4550, teacher_id=FA0000002, group_ids=['Y4S2.3'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-016, subject=IT1030, teacher_id=FA0000010, group_ids=['Y1S1.3'], duration=1),
#    'LAB502': Activity(id=AC-129, subject=IT3030, teacher_id=FA0000010, group_ids=['Y3S1.5'], duration=1)},
#   'FRI5': {'LH401': Activity(id=AC-127, subject=IT3030, teacher_id=FA0000003, group_ids=['Y3S1.3'], duration=1),
#    'LH501': Activity(id=AC-046, subject=IT1570, teacher_id=FA0000009, group_ids=['Y1S2.4'], duration=1),
#    'LAB501': Activity(id=AC-005, subject=IT1010, teacher_id=FA0000008, group_ids=['Y1S1.4'], duration=1),
#    'LAB502': Activity(id=AC-101, subject=IT2570, teacher_id=FA0000005, group_ids=['Y2S2.1'], duration=1)},
#   'FRI6': {'LH401': Activity(id=AC-048, subject=IT1580, teacher_id=FA0000004, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-025, subject=IT1550, teacher_id=FA0000004, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LAB501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB502': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1)},
#   'FRI7': {'LH401': Activity(id=AC-123, subject=IT3020, teacher_id=FA0000006, group_ids=['Y3S1.5'], duration=1),
#    'LH501': Activity(id=AC-185, subject=IT4560, teacher_id=FA0000008, group_ids=['Y4S2.1'], duration=1),
#    'LAB501': Activity(id=AC-048, subject=IT1580, teacher_id=FA0000004, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LAB502': Activity(id=AC-150, subject=IT3570, teacher_id=FA0000010, group_ids=['Y3S2.2'], duration=1)},
#   'FRI8': {'LH401': Activity(id=AC-069, subject=IT2020, teacher_id=FA0000009, group_ids=['Y2S1.4'], duration=1),
#    'LH501': Activity(id=AC-084, subject=IT2550, teacher_id=FA0000008, group_ids=['Y2S2.1'], duration=1),
#    'LAB501': Activity(id=AC-009, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.2'], duration=1),
#    'LAB502': Activity(id=AC-051, subject=IT1580, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1)}},
#  {'MON1': {'LH401': Activity(id=AC-140, subject=IT3550, teacher_id=FA0000007, group_ids=['Y3S2.4'], duration=1),
#    'LH501': Activity(id=AC-139, subject=IT3550, teacher_id=FA0000001, group_ids=['Y3S2.3'], duration=1),
#    'LAB501': Activity(id=AC-006, subject=IT1010, teacher_id=FA0000001, group_ids=['Y1S1.5'], duration=1),
#    'LAB502': Activity(id=AC-138, subject=IT3550, teacher_id=FA0000010, group_ids=['Y3S2.2'], duration=1)},
#   'MON2': {'LH401': Activity(id=AC-077, subject=IT2040, teacher_id=FA0000006, group_ids=['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'], duration=2),
#    'LH501': Activity(id=AC-132, subject=IT3040, teacher_id=FA0000005, group_ids=['Y3S1.2'], duration=1),
#    'LAB501': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1),
#    'LAB502': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1)},
#   'MON3': {'LH401': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1),
#    'LH501': Activity(id=AC-088, subject=IT2550, teacher_id=FA0000007, group_ids=['Y2S2.5'], duration=1),
#    'LAB501': Activity(id=AC-072, subject=IT2030, teacher_id=FA0000010, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-158, subject=IT3580, teacher_id=FA0000009, group_ids=['Y3S2.4'], duration=1)},
#   'MON4': {'LH401': Activity(id=AC-165, subject=IT4010, teacher_id=FA0000009, group_ids=['Y4S1.5'], duration=1),
#    'LH501': Activity(id=AC-130, subject=IT3040, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB501': Activity(id=AC-014, subject=IT1030, teacher_id=FA0000001, group_ids=['Y1S1.1'], duration=1),
#    'LAB502': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1)},
#   'MON5': {'LH401': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2),
#    'LH501': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LAB501': Activity(id=AC-078, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-093, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.4'], duration=1)},
#   'MON6': {'LH401': Activity(id=AC-115, subject=IT3010, teacher_id=FA0000010, group_ids=['Y3S1.3'], duration=1),
#    'LH501': Activity(id=AC-045, subject=IT1570, teacher_id=FA0000004, group_ids=['Y1S2.3'], duration=1),
#    'LAB501': Activity(id=AC-144, subject=IT3560, teacher_id=FA0000001, group_ids=['Y3S2.2'], duration=1),
#    'LAB502': Activity(id=AC-010, subject=IT1020, teacher_id=FA0000005, group_ids=['Y1S1.3'], duration=1)},
#   'MON7': {'LH401': Activity(id=AC-031, subject=IT1560, teacher_id=FA0000007, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2),
#    'LAB501': Activity(id=AC-147, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.5'], duration=1),
#    'LAB502': Activity(id=AC-098, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.4'], duration=2)},
#   'MON8': {'LH401': Activity(id=AC-182, subject=IT4550, teacher_id=FA0000004, group_ids=['Y4S2.4'], duration=1),
#    'LH501': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LAB501': Activity(id=AC-097, subject=IT2560, teacher_id=FA0000002, group_ids=['Y2S2.3'], duration=2),
#    'LAB502': Activity(id=AC-036, subject=IT1560, teacher_id=FA0000008, group_ids=['Y1S2.5'], duration=1)},
#   'TUE1': {'LH401': Activity(id=AC-108, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.2'], duration=1),
#    'LH501': Activity(id=AC-119, subject=IT3020, teacher_id=FA0000002, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-096, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.2'], duration=2),
#    'LAB502': Activity(id=AC-076, subject=IT2030, teacher_id=FA0000001, group_ids=['Y2S1.5'], duration=1)},
#   'TUE2': {'LH401': Activity(id=AC-032, subject=IT1560, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1),
#    'LH501': Activity(id=AC-173, subject=IT4030, teacher_id=FA0000008, group_ids=['Y4S1.1'], duration=1),
#    'LAB501': Activity(id=AC-159, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.5'], duration=1),
#    'LAB502': Activity(id=AC-153, subject=IT3570, teacher_id=FA0000008, group_ids=['Y3S2.5'], duration=1)},
#   'TUE3': {'LH401': Activity(id=AC-085, subject=IT2550, teacher_id=FA0000008, group_ids=['Y2S2.2'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-155, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.1'], duration=1),
#    'LAB502': Activity(id=AC-021, subject=IT1040, teacher_id=FA0000005, group_ids=['Y1S1.2'], duration=1)},
#   'TUE4': {'LH401': Activity(id=AC-017, subject=IT1030, teacher_id=FA0000002, group_ids=['Y1S1.4'], duration=1),
#    'LH501': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LAB501': Activity(id=AC-195, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.5'], duration=1),
#    'LAB502': Activity(id=AC-070, subject=IT2020, teacher_id=FA0000007, group_ids=['Y2S1.5'], duration=1)},
#   'TUE5': {'LH401': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LH501': Activity(id=AC-160, subject=IT4010, teacher_id=FA0000006, group_ids=['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'], duration=2),
#    'LAB501': Activity(id=AC-051, subject=IT1580, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1),
#    'LAB502': Activity(id=AC-187, subject=IT4560, teacher_id=FA0000010, group_ids=['Y4S2.3'], duration=1)},
#   'TUE6': {'LH401': Activity(id=AC-038, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=2),
#    'LH501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB501': Activity(id=AC-033, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=1),
#    'LAB502': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1)},
#   'TUE7': {'LH401': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LH501': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-181, subject=IT4550, teacher_id=FA0000002, group_ids=['Y4S2.3'], duration=1),
#    'LAB502': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1)},
#   'TUE8': {'LH401': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LH501': Activity(id=AC-144, subject=IT3560, teacher_id=FA0000001, group_ids=['Y3S2.2'], duration=1),
#    'LAB501': Activity(id=AC-040, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.4'], duration=2),
#    'LAB502': Activity(id=AC-129, subject=IT3030, teacher_id=FA0000010, group_ids=['Y3S1.5'], duration=1)},
#   'WED1': {'LH401': Activity(id=AC-042, subject=IT1570, teacher_id=FA0000001, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-118, subject=IT3020, teacher_id=FA0000001, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB501': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LAB502': Activity(id=AC-061, subject=IT2010, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=2)},
#   'WED2': {'LH401': Activity(id=AC-134, subject=IT3040, teacher_id=FA0000010, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-061, subject=IT2010, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=2),
#    'LAB501': Activity(id=AC-079, subject=IT2040, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=1),
#    'LAB502': Activity(id=AC-145, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.3'], duration=1)},
#   'WED3': {'LH401': Activity(id=AC-130, subject=IT3040, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LH501': Activity(id=AC-076, subject=IT2030, teacher_id=FA0000001, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-111, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.5'], duration=1),
#    'LAB502': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2)},
#   'WED4': {'LH401': Activity(id=AC-193, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.3'], duration=1),
#    'LH501': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2),
#    'LAB501': Activity(id=AC-008, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.1'], duration=1),
#    'LAB502': Activity(id=AC-102, subject=IT2570, teacher_id=FA0000006, group_ids=['Y2S2.2'], duration=1)},
#   'WED5': {'LH401': Activity(id=AC-159, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.5'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB502': Activity(id=AC-134, subject=IT3040, teacher_id=FA0000010, group_ids=['Y3S1.4'], duration=1)},
#   'WED6': {'LH401': Activity(id=AC-074, subject=IT2030, teacher_id=FA0000009, group_ids=['Y2S1.3'], duration=1),
#    'LH501': Activity(id=AC-049, subject=IT1580, teacher_id=FA0000010, group_ids=['Y1S2.1'], duration=1),
#    'LAB501': Activity(id=AC-108, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.2'], duration=1),
#    'LAB502': Activity(id=AC-104, subject=IT2570, teacher_id=FA0000002, group_ids=['Y2S2.4'], duration=1)},
#   'WED7': {'LH401': Activity(id=AC-137, subject=IT3550, teacher_id=FA0000003, group_ids=['Y3S2.1'], duration=1),
#    'LH501': Activity(id=AC-066, subject=IT2020, teacher_id=FA0000008, group_ids=['Y2S1.1'], duration=1),
#    'LAB501': Activity(id=AC-063, subject=IT2010, teacher_id=FA0000006, group_ids=['Y2S1.4'], duration=2),
#    'LAB502': Activity(id=AC-176, subject=IT4030, teacher_id=FA0000007, group_ids=['Y4S1.4'], duration=1)},
#   'WED8': {'LH401': Activity(id=AC-141, subject=IT3550, teacher_id=FA0000001, group_ids=['Y3S2.5'], duration=1),
#    'LH501': Activity(id=AC-171, subject=IT4020, teacher_id=FA0000009, group_ids=['Y4S1.5'], duration=1),
#    'LAB501': Activity(id=AC-069, subject=IT2020, teacher_id=FA0000009, group_ids=['Y2S1.4'], duration=1),
#    'LAB502': Activity(id=AC-028, subject=IT1550, teacher_id=FA0000008, group_ids=['Y1S2.3'], duration=1)},
#   'THU1': {'LH401': Activity(id=AC-175, subject=IT4030, teacher_id=FA0000004, group_ids=['Y4S1.3'], duration=1),
#    'LH501': Activity(id=AC-131, subject=IT3040, teacher_id=FA0000005, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-055, subject=IT2010, teacher_id=FA0000007, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-188, subject=IT4560, teacher_id=FA0000001, group_ids=['Y4S2.4'], duration=1)},
#   'THU2': {'LH401': Activity(id=AC-043, subject=IT1570, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1),
#    'LH501': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-127, subject=IT3030, teacher_id=FA0000003, group_ids=['Y3S1.3'], duration=1),
#    'LAB502': Activity(id=AC-125, subject=IT3030, teacher_id=FA0000006, group_ids=['Y3S1.1'], duration=1)},
#   'THU3': {'LH401': Activity(id=AC-116, subject=IT3010, teacher_id=FA0000006, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-149, subject=IT3570, teacher_id=FA0000009, group_ids=['Y3S2.1'], duration=1),
#    'LAB501': Activity(id=AC-118, subject=IT3020, teacher_id=FA0000001, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB502': Activity(id=AC-195, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.5'], duration=1)},
#   'THU4': {'LH401': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LH501': Activity(id=AC-011, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.4'], duration=1),
#    'LAB501': Activity(id=AC-009, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.2'], duration=1),
# ...
#    'LH501': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LAB501': Activity(id=AC-078, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-093, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.4'], duration=1)},
#   'MON6': {'LH401': Activity(id=AC-115, subject=IT3010, teacher_id=FA0000010, group_ids=['Y3S1.3'], duration=1),
#    'LH501': Activity(id=AC-045, subject=IT1570, teacher_id=FA0000004, group_ids=['Y1S2.3'], duration=1),
#    'LAB501': Activity(id=AC-144, subject=IT3560, teacher_id=FA0000001, group_ids=['Y3S2.2'], duration=1),
#    'LAB502': Activity(id=AC-010, subject=IT1020, teacher_id=FA0000005, group_ids=['Y1S1.3'], duration=1)},
#   'MON7': {'LH401': Activity(id=AC-031, subject=IT1560, teacher_id=FA0000007, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2),
#    'LAB501': Activity(id=AC-147, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.5'], duration=1),
#    'LAB502': Activity(id=AC-098, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.4'], duration=2)},
#   'MON8': {'LH401': Activity(id=AC-182, subject=IT4550, teacher_id=FA0000004, group_ids=['Y4S2.4'], duration=1),
#    'LH501': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LAB501': Activity(id=AC-097, subject=IT2560, teacher_id=FA0000002, group_ids=['Y2S2.3'], duration=2),
#    'LAB502': Activity(id=AC-036, subject=IT1560, teacher_id=FA0000008, group_ids=['Y1S2.5'], duration=1)},
#   'TUE1': {'LH401': Activity(id=AC-108, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.2'], duration=1),
#    'LH501': Activity(id=AC-119, subject=IT3020, teacher_id=FA0000002, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-096, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.2'], duration=2),
#    'LAB502': Activity(id=AC-076, subject=IT2030, teacher_id=FA0000001, group_ids=['Y2S1.5'], duration=1)},
#   'TUE2': {'LH401': Activity(id=AC-052, subject=IT1580, teacher_id=FA0000010, group_ids=['Y1S2.4'], duration=1),
#    'LH501': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LAB501': Activity(id=AC-126, subject=IT3030, teacher_id=FA0000006, group_ids=['Y3S1.2'], duration=1),
#    'LAB502': Activity(id=AC-052, subject=IT1580, teacher_id=FA0000010, group_ids=['Y1S2.4'], duration=1)},
#   'TUE3': {'LH401': Activity(id=AC-085, subject=IT2550, teacher_id=FA0000008, group_ids=['Y2S2.2'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-155, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.1'], duration=1),
#    'LAB502': Activity(id=AC-021, subject=IT1040, teacher_id=FA0000005, group_ids=['Y1S1.2'], duration=1)},
#   'TUE4': {'LH401': Activity(id=AC-017, subject=IT1030, teacher_id=FA0000002, group_ids=['Y1S1.4'], duration=1),
#    'LH501': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LAB501': Activity(id=AC-195, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.5'], duration=1),
#    'LAB502': Activity(id=AC-070, subject=IT2020, teacher_id=FA0000007, group_ids=['Y2S1.5'], duration=1)},
#   'TUE5': {'LH401': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LH501': Activity(id=AC-160, subject=IT4010, teacher_id=FA0000006, group_ids=['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'], duration=2),
#    'LAB501': Activity(id=AC-051, subject=IT1580, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1),
#    'LAB502': Activity(id=AC-187, subject=IT4560, teacher_id=FA0000010, group_ids=['Y4S2.3'], duration=1)},
#   'TUE6': {'LH401': Activity(id=AC-038, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=2),
#    'LH501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB501': Activity(id=AC-033, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=1),
#    'LAB502': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1)},
#   'TUE7': {'LH401': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#    'LH501': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-181, subject=IT4550, teacher_id=FA0000002, group_ids=['Y4S2.3'], duration=1),
#    'LAB502': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1)},
#   'TUE8': {'LH401': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LH501': Activity(id=AC-144, subject=IT3560, teacher_id=FA0000001, group_ids=['Y3S2.2'], duration=1),
#    'LAB501': Activity(id=AC-040, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.4'], duration=2),
#    'LAB502': Activity(id=AC-129, subject=IT3030, teacher_id=FA0000010, group_ids=['Y3S1.5'], duration=1)},
#   'WED1': {'LH401': Activity(id=AC-042, subject=IT1570, teacher_id=FA0000001, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-118, subject=IT3020, teacher_id=FA0000001, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB501': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LAB502': Activity(id=AC-061, subject=IT2010, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=2)},
#   'WED2': {'LH401': Activity(id=AC-134, subject=IT3040, teacher_id=FA0000010, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-061, subject=IT2010, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=2),
#    'LAB501': Activity(id=AC-079, subject=IT2040, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=1),
#    'LAB502': Activity(id=AC-145, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.3'], duration=1)},
#   'WED3': {'LH401': Activity(id=AC-130, subject=IT3040, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LH501': Activity(id=AC-076, subject=IT2030, teacher_id=FA0000001, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-111, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.5'], duration=1),
#    'LAB502': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2)},
#   'WED4': {'LH401': Activity(id=AC-193, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.3'], duration=1),
#    'LH501': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2),
#    'LAB501': Activity(id=AC-008, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.1'], duration=1),
#    'LAB502': Activity(id=AC-102, subject=IT2570, teacher_id=FA0000006, group_ids=['Y2S2.2'], duration=1)},
#   'WED5': {'LH401': Activity(id=AC-159, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.5'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB502': Activity(id=AC-134, subject=IT3040, teacher_id=FA0000010, group_ids=['Y3S1.4'], duration=1)},
#   'WED6': {'LH401': Activity(id=AC-074, subject=IT2030, teacher_id=FA0000009, group_ids=['Y2S1.3'], duration=1),
#    'LH501': Activity(id=AC-049, subject=IT1580, teacher_id=FA0000010, group_ids=['Y1S2.1'], duration=1),
#    'LAB501': Activity(id=AC-108, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.2'], duration=1),
#    'LAB502': Activity(id=AC-104, subject=IT2570, teacher_id=FA0000002, group_ids=['Y2S2.4'], duration=1)},
#   'WED7': {'LH401': Activity(id=AC-137, subject=IT3550, teacher_id=FA0000003, group_ids=['Y3S2.1'], duration=1),
#    'LH501': Activity(id=AC-066, subject=IT2020, teacher_id=FA0000008, group_ids=['Y2S1.1'], duration=1),
#    'LAB501': Activity(id=AC-063, subject=IT2010, teacher_id=FA0000006, group_ids=['Y2S1.4'], duration=2),
#    'LAB502': Activity(id=AC-176, subject=IT4030, teacher_id=FA0000007, group_ids=['Y4S1.4'], duration=1)},
#   'WED8': {'LH401': Activity(id=AC-141, subject=IT3550, teacher_id=FA0000001, group_ids=['Y3S2.5'], duration=1),
#    'LH501': Activity(id=AC-171, subject=IT4020, teacher_id=FA0000009, group_ids=['Y4S1.5'], duration=1),
#    'LAB501': Activity(id=AC-069, subject=IT2020, teacher_id=FA0000009, group_ids=['Y2S1.4'], duration=1),
#    'LAB502': Activity(id=AC-028, subject=IT1550, teacher_id=FA0000008, group_ids=['Y1S2.3'], duration=1)},
#   'THU1': {'LH401': Activity(id=AC-175, subject=IT4030, teacher_id=FA0000004, group_ids=['Y4S1.3'], duration=1),
#    'LH501': Activity(id=AC-131, subject=IT3040, teacher_id=FA0000005, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-055, subject=IT2010, teacher_id=FA0000007, group_ids=['Y2S1.1'], duration=1),
#    'LAB502': Activity(id=AC-188, subject=IT4560, teacher_id=FA0000001, group_ids=['Y4S2.4'], duration=1)},
#   'THU2': {'LH401': Activity(id=AC-043, subject=IT1570, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1),
#    'LH501': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1),
#    'LAB501': Activity(id=AC-127, subject=IT3030, teacher_id=FA0000003, group_ids=['Y3S1.3'], duration=1),
#    'LAB502': Activity(id=AC-125, subject=IT3030, teacher_id=FA0000006, group_ids=['Y3S1.1'], duration=1)},
#   'THU3': {'LH401': Activity(id=AC-116, subject=IT3010, teacher_id=FA0000006, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-149, subject=IT3570, teacher_id=FA0000009, group_ids=['Y3S2.1'], duration=1),
#    'LAB501': Activity(id=AC-118, subject=IT3020, teacher_id=FA0000001, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#    'LAB502': Activity(id=AC-195, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.5'], duration=1)},
#   'THU4': {'LH401': Activity(id=AC-095, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.1'], duration=2),
#    'LH501': Activity(id=AC-011, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.4'], duration=1),
#    'LAB501': Activity(id=AC-009, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.2'], duration=1),
#    'LAB502': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2)},
#   'THU5': {'LH401': Activity(id=AC-194, subject=IT4570, teacher_id=FA0000005, group_ids=['Y4S2.4'], duration=1),
#    'LH501': Activity(id=AC-183, subject=IT4550, teacher_id=FA0000007, group_ids=['Y4S2.5'], duration=1),
#    'LAB501': Activity(id=AC-156, subject=IT3580, teacher_id=FA0000010, group_ids=['Y3S2.2'], duration=1),
#    'LAB502': Activity(id=AC-034, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1)},
#   'THU6': {'LH401': Activity(id=AC-169, subject=IT4020, teacher_id=FA0000008, group_ids=['Y4S1.3'], duration=1),
#    'LH501': Activity(id=AC-142, subject=IT3560, teacher_id=FA0000008, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#    'LAB501': Activity(id=AC-137, subject=IT3550, teacher_id=FA0000003, group_ids=['Y3S2.1'], duration=1),
#    'LAB502': Activity(id=AC-050, subject=IT1580, teacher_id=FA0000002, group_ids=['Y1S2.2'], duration=1)},
#   'THU7': {'LH401': Activity(id=AC-128, subject=IT3030, teacher_id=FA0000008, group_ids=['Y3S1.4'], duration=1),
#    'LH501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#    'LAB501': Activity(id=AC-110, subject=IT2580, teacher_id=FA0000006, group_ids=['Y2S2.4'], duration=1),
#    'LAB502': Activity(id=AC-191, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.1'], duration=1)},
#   'THU8': {'LH401': Activity(id=AC-081, subject=IT2040, teacher_id=FA0000007, group_ids=['Y2S1.4'], duration=1),
#    'LH501': Activity(id=AC-192, subject=IT4570, teacher_id=FA0000001, group_ids=['Y4S2.2'], duration=1),
#    'LAB501': Activity(id=AC-175, subject=IT4030, teacher_id=FA0000004, group_ids=['Y4S1.3'], duration=1),
#    'LAB502': Activity(id=AC-070, subject=IT2020, teacher_id=FA0000007, group_ids=['Y2S1.5'], duration=1)},
#   'FRI1': {'LH401': Activity(id=AC-191, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.1'], duration=1),
#    'LH501': Activity(id=AC-062, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.3'], duration=2),
#    'LAB501': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1),
#    'LAB502': Activity(id=AC-164, subject=IT4010, teacher_id=FA0000005, group_ids=['Y4S1.4'], duration=1)},
#   'FRI2': {'LH401': Activity(id=AC-028, subject=IT1550, teacher_id=FA0000008, group_ids=['Y1S2.3'], duration=1),
#    'LH501': Activity(id=AC-194, subject=IT4570, teacher_id=FA0000005, group_ids=['Y4S2.4'], duration=1),
#    'LAB501': Activity(id=AC-180, subject=IT4550, teacher_id=FA0000001, group_ids=['Y4S2.2'], duration=1),
#    'LAB502': Activity(id=AC-114, subject=IT3010, teacher_id=FA0000010, group_ids=['Y3S1.2'], duration=1)},
#   'FRI3': {'LH401': Activity(id=AC-097, subject=IT2560, teacher_id=FA0000002, group_ids=['Y2S2.3'], duration=2),
#    'LH501': Activity(id=AC-167, subject=IT4020, teacher_id=FA0000001, group_ids=['Y4S1.1'], duration=1),
#    'LAB501': Activity(id=AC-101, subject=IT2570, teacher_id=FA0000005, group_ids=['Y2S2.1'], duration=1),
#    'LAB502': Activity(id=AC-031, subject=IT1560, teacher_id=FA0000007, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2)},
#   'FRI4': {'LH401': Activity(id=AC-181, subject=IT4550, teacher_id=FA0000002, group_ids=['Y4S2.3'], duration=1),
#    'LH501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB501': Activity(id=AC-016, subject=IT1030, teacher_id=FA0000010, group_ids=['Y1S1.3'], duration=1),
#    'LAB502': Activity(id=AC-129, subject=IT3030, teacher_id=FA0000010, group_ids=['Y3S1.5'], duration=1)},
#   'FRI5': {'LH401': Activity(id=AC-127, subject=IT3030, teacher_id=FA0000003, group_ids=['Y3S1.3'], duration=1),
#    'LH501': Activity(id=AC-046, subject=IT1570, teacher_id=FA0000009, group_ids=['Y1S2.4'], duration=1),
#    'LAB501': Activity(id=AC-005, subject=IT1010, teacher_id=FA0000008, group_ids=['Y1S1.4'], duration=1),
#    'LAB502': Activity(id=AC-101, subject=IT2570, teacher_id=FA0000005, group_ids=['Y2S2.1'], duration=1)},
#   'FRI6': {'LH401': Activity(id=AC-048, subject=IT1580, teacher_id=FA0000004, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LH501': Activity(id=AC-025, subject=IT1550, teacher_id=FA0000004, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LAB501': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#    'LAB502': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1)},
#   'FRI7': {'LH401': Activity(id=AC-123, subject=IT3020, teacher_id=FA0000006, group_ids=['Y3S1.5'], duration=1),
#    'LH501': Activity(id=AC-185, subject=IT4560, teacher_id=FA0000008, group_ids=['Y4S2.1'], duration=1),
#    'LAB501': Activity(id=AC-048, subject=IT1580, teacher_id=FA0000004, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#    'LAB502': Activity(id=AC-150, subject=IT3570, teacher_id=FA0000010, group_ids=['Y3S2.2'], duration=1)},
#   'FRI8': {'LH401': Activity(id=AC-069, subject=IT2020, teacher_id=FA0000009, group_ids=['Y2S1.4'], duration=1),
#    'LH501': Activity(id=AC-084, subject=IT2550, teacher_id=FA0000008, group_ids=['Y2S2.1'], duration=1),
#    'LAB501': Activity(id=AC-009, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.2'], duration=1),
#    'LAB502': Activity(id=AC-051, subject=IT1580, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1)}}]

# %%
def adapter(solution):
    timetable = {}
    for slot in slots:
        timetable[slot] = {}
        for space in spaces_dict.keys():
            timetable[slot][space] = ""

    for period in solution:
        time_slots = period[3]
        room = period[2]
        activity_id = period[0]
        if not isinstance(time_slots, list):
            time_slots = [time_slots]
        for aslot in time_slots:
            timetable[aslot][room] = activities_dict[activity_id]
    return timetable


def get_classsize(activity: Activity) -> int:
    classsize = 0
    for id in activity.group_ids:
        classsize += groups_dict[id].size
    return classsize

def create_timetable():
    population = []
    
    for _ in range(POPULATION_SIZE):
        timetable = {}
        activity_slots = {activity.id :[] for activity in activities_dict.values}
        activities_remain = [activity.id for activity in activities_dict.values()
                             for _ in range(activity.duration)]
        for slot in slots:
            timetable[slot] = {}
            for space_id in spaces_dict.keys():
                space = spaces_dict[space_id]
                a_activities = [activity for activity in activities_remain if get_classsize(activities_dict[activity]) <=space.size]
                a_activities = [activity for activity in a_activities if slot not in activity_slots[activity]]
                activity = random.sample(a_activities)
                timetable[slot][space] = activity
                activity_slots[activity].append(slot)

        population.append(timetable)
    return population
                # timetable[slot][space]

# %%
evaluator(final_population[0])
# Out:
# (0, 28, 1, 10, 79)

# %%
def print_metric(vacant_rooms, prof_conflicts, room_size_conflicts, sub_group_conflicts, unassigned_activities):
    a = f" Vacant Rooms : {vacant_rooms} \nLecturer Conflicts : {prof_conflicts}\nRoom Size Conflicts : {room_size_conflicts}\nSub Group Conflicts:{sub_group_conflicts} \nNo:of Unassigned Activities:{unassigned_activities} "
    print(a)

print_metric(*evaluator(final_population[0]))
# Out:
#  Vacant Rooms : 0
# Lecturer Conflicts : 28
# Room Size Conflicts : 1
# Sub Group Conflicts:10
# No:of Unassigned Activities:79
