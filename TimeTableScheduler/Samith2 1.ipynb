# %%
class Space:
    def __init__(self, *args):
        self.code = args[0]
        self.size = args[1]


class Group:
    def __init__(self, *args):
        self.id = args[0]
        self.size = args[1]


class Activity:
    def __init__(self, id, *args):
        self.id = id
        self.subject = args[0]
        self.teacher_id = args[1]
        self.group_ids = args[2]
        self.duration = args[3]

    def __repr__(self):
        return f"Activity(id={self.id}, subject={self.subject}, teacher_id={self.teacher_id}, group_ids={self.group_ids}, duration={self.duration})"


class Period:
    def __init__(self, *args):
        self.space = args[0]
        self.group = args[1]
        self.activity = args[2]

# %%
import json

# Load data from JSON file
with open('sliit_computing_dataset.json', 'r') as file:
    data = json.load(file)

# Create dictionaries to store instances
spaces_dict = {}
groups_dict = {}
activities_dict = {}
slots = []
# Populate the dictionaries with data from the JSON file
for space in data['spaces']:
    spaces_dict[space['code']] = Space(space['code'], space['capacity'])

for group in data['years']:
    groups_dict[group['id']] = Group(group['id'], group['size'])

for activity in data['activities']:
    activities_dict[activity['code']] = Activity(
        activity['code'], activity['subject'], activity['teacher_ids'][0], activity['subgroup_ids'], activity['duration'])

for day in ["MON", "TUE", "WED", "THU", "FRI"]:
    for id in range(1, 9):
        slots.append(day+str(id))
# Print the dictionaries to verify
print(spaces_dict)
print(groups_dict)
print(activities_dict)
print(slots)
# Out:
# {'LH401': <__main__.Space object at 0x000001ECA2C3C500>, 'LH501': <__main__.Space object at 0x000001ECA3719730>, 'LAB501': <__main__.Space object at 0x000001ECA6075580>, 'LAB502': <__main__.Space object at 0x000001ECA6074E00>}
# {'Y1S1.1': <__main__.Group object at 0x000001ECA6076C90>, 'Y1S1.2': <__main__.Group object at 0x000001ECA60749E0>, 'Y1S1.3': <__main__.Group object at 0x000001ECA60751C0>, 'Y1S1.4': <__main__.Group object at 0x000001ECA6076960>, 'Y1S1.5': <__main__.Group object at 0x000001ECA6074C20>, 'Y1S2.1': <__main__.Group object at 0x000001ECA6076BD0>, 'Y1S2.2': <__main__.Group object at 0x000001ECA6075490>, 'Y1S2.3': <__main__.Group object at 0x000001ECA6075790>, 'Y1S2.4': <__main__.Group object at 0x000001ECA60745F0>, 'Y1S2.5': <__main__.Group object at 0x000001ECA6075460>, 'Y2S1.1': <__main__.Group object at 0x000001ECA6077440>, 'Y2S1.2': <__main__.Group object at 0x000001ECA6075250>, 'Y2S1.3': <__main__.Group object at 0x000001ECA6076750>, 'Y2S1.4': <__main__.Group object at 0x000001ECA6075220>, 'Y2S1.5': <__main__.Group object at 0x000001ECA6074170>, 'Y2S2.1': <__main__.Group object at 0x000001ECA60768A0>, 'Y2S2.2': <__main__.Group object at 0x000001ECA6074E30>, 'Y2S2.3': <__main__.Group object at 0x000001ECA6077080>, 'Y2S2.4': <__main__.Group object at 0x000001ECA6075D30>, 'Y2S2.5': <__main__.Group object at 0x000001ECA6076AB0>, 'Y3S1.1': <__main__.Group object at 0x000001ECA6075160>, 'Y3S1.2': <__main__.Group object at 0x000001ECA6074A10>, 'Y3S1.3': <__main__.Group object at 0x000001ECA60749B0>, 'Y3S1.4': <__main__.Group object at 0x000001ECA6074950>, 'Y3S1.5': <__main__.Group object at 0x000001ECA6077C50>, 'Y3S2.1': <__main__.Group object at 0x000001ECA6074A70>, 'Y3S2.2': <__main__.Group object at 0x000001ECA60744D0>, 'Y3S2.3': <__main__.Group object at 0x000001ECA6077350>, 'Y3S2.4': <__main__.Group object at 0x000001ECA60748C0>, 'Y3S2.5': <__main__.Group object at 0x000001ECA60741D0>, 'Y4S1.1': <__main__.Group object at 0x000001ECA6076930>, 'Y4S1.2': <__main__.Group object at 0x000001ECA6074140>, 'Y4S1.3': <__main__.Group object at 0x000001ECA6076DE0>, 'Y4S1.4': <__main__.Group object at 0x000001ECA6077770>, 'Y4S1.5': <__main__.Group object at 0x000001ECA6074350>, 'Y4S2.1': <__main__.Group object at 0x000001ECA6076540>, 'Y4S2.2': <__main__.Group object at 0x000001ECA60766F0>, 'Y4S2.3': <__main__.Group object at 0x000001ECA6074440>, 'Y4S2.4': <__main__.Group object at 0x000001ECA60747A0>, 'Y4S2.5': <__main__.Group object at 0x000001ECA6074200>}
# {'AC-001': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2), 'AC-002': Activity(id=AC-002, subject=IT1010, teacher_id=FA0000001, group_ids=['Y1S1.1'], duration=1), 'AC-003': Activity(id=AC-003, subject=IT1010, teacher_id=FA0000006, group_ids=['Y1S1.2'], duration=1), 'AC-004': Activity(id=AC-004, subject=IT1010, teacher_id=FA0000009, group_ids=['Y1S1.3'], duration=1), 'AC-005': Activity(id=AC-005, subject=IT1010, teacher_id=FA0000008, group_ids=['Y1S1.4'], duration=1), 'AC-006': Activity(id=AC-006, subject=IT1010, teacher_id=FA0000001, group_ids=['Y1S1.5'], duration=1), 'AC-007': Activity(id=AC-007, subject=IT1020, teacher_id=FA0000003, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2), 'AC-008': Activity(id=AC-008, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.1'], duration=1), 'AC-009': Activity(id=AC-009, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.2'], duration=1), 'AC-010': Activity(id=AC-010, subject=IT1020, teacher_id=FA0000005, group_ids=['Y1S1.3'], duration=1), 'AC-011': Activity(id=AC-011, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.4'], duration=1), 'AC-012': Activity(id=AC-012, subject=IT1020, teacher_id=FA0000006, group_ids=['Y1S1.5'], duration=1), 'AC-013': Activity(id=AC-013, subject=IT1030, teacher_id=FA0000006, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2), 'AC-014': Activity(id=AC-014, subject=IT1030, teacher_id=FA0000001, group_ids=['Y1S1.1'], duration=1), 'AC-015': Activity(id=AC-015, subject=IT1030, teacher_id=FA0000007, group_ids=['Y1S1.2'], duration=1), 'AC-016': Activity(id=AC-016, subject=IT1030, teacher_id=FA0000010, group_ids=['Y1S1.3'], duration=1), 'AC-017': Activity(id=AC-017, subject=IT1030, teacher_id=FA0000002, group_ids=['Y1S1.4'], duration=1), 'AC-018': Activity(id=AC-018, subject=IT1030, teacher_id=FA0000005, group_ids=['Y1S1.5'], duration=1), 'AC-019': Activity(id=AC-019, subject=IT1040, teacher_id=FA0000007, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2), 'AC-020': Activity(id=AC-020, subject=IT1040, teacher_id=FA0000006, group_ids=['Y1S1.1'], duration=1), 'AC-021': Activity(id=AC-021, subject=IT1040, teacher_id=FA0000005, group_ids=['Y1S1.2'], duration=1), 'AC-022': Activity(id=AC-022, subject=IT1040, teacher_id=FA0000004, group_ids=['Y1S1.3'], duration=1), 'AC-023': Activity(id=AC-023, subject=IT1040, teacher_id=FA0000005, group_ids=['Y1S1.4'], duration=1), 'AC-024': Activity(id=AC-024, subject=IT1040, teacher_id=FA0000001, group_ids=['Y1S1.5'], duration=1), 'AC-025': Activity(id=AC-025, subject=IT1550, teacher_id=FA0000004, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2), 'AC-026': Activity(id=AC-026, subject=IT1550, teacher_id=FA0000006, group_ids=['Y1S2.1'], duration=1), 'AC-027': Activity(id=AC-027, subject=IT1550, teacher_id=FA0000009, group_ids=['Y1S2.2'], duration=1), 'AC-028': Activity(id=AC-028, subject=IT1550, teacher_id=FA0000008, group_ids=['Y1S2.3'], duration=1), 'AC-029': Activity(id=AC-029, subject=IT1550, teacher_id=FA0000009, group_ids=['Y1S2.4'], duration=1), 'AC-030': Activity(id=AC-030, subject=IT1550, teacher_id=FA0000007, group_ids=['Y1S2.5'], duration=1), 'AC-031': Activity(id=AC-031, subject=IT1560, teacher_id=FA0000007, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2), 'AC-032': Activity(id=AC-032, subject=IT1560, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1), 'AC-033': Activity(id=AC-033, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=1), 'AC-034': Activity(id=AC-034, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1), 'AC-035': Activity(id=AC-035, subject=IT1560, teacher_id=FA0000005, group_ids=['Y1S2.4'], duration=1), 'AC-036': Activity(id=AC-036, subject=IT1560, teacher_id=FA0000008, group_ids=['Y1S2.5'], duration=1), 'AC-037': Activity(id=AC-037, subject=IT1560, teach ...
# ['MON1', 'MON2', 'MON3', 'MON4', 'MON5', 'MON6', 'MON7', 'MON8', 'TUE1', 'TUE2', 'TUE3', 'TUE4', 'TUE5', 'TUE6', 'TUE7', 'TUE8', 'WED1', 'WED2', 'WED3', 'WED4', 'WED5', 'WED6', 'WED7', 'WED8', 'THU1', 'THU2', 'THU3', 'THU4', 'THU5', 'THU6', 'THU7', 'THU8', 'FRI1', 'FRI2', 'FRI3', 'FRI4', 'FRI5', 'FRI6', 'FRI7', 'FRI8']

# %%
import random


def fitness(solution):
    room_overbooking = 0
    slot_conflicts = 0
    prof_conflicts = 0

    slot_assignments = {}
    prof_assignments = {}

    # Evaluate room overbooking and slot conflicts
    for entry in solution:
        course_id, student_group, room_id, valid_slots, professor = entry
        course = activities_dict[course_id]
        room = spaces_dict[room_id]

        # Room overbooking
        if room.size < get_classsize(course):
            room_overbooking += 1

        # Slot conflicts (same student in multiple classes at the same time)
        for slot_id in valid_slots:
            if slot_id not in slot_assignments:
                slot_assignments[slot_id] = []
            slot_assignments[slot_id].append((student_group, course_id))

        # Professor conflicts (same professor teaching multiple courses at the same time)
        if course.teacher_id not in prof_assignments:
            prof_assignments[course.teacher_id] = []
        prof_assignments[course.teacher_id].append(slot_id)

    # Calculate slot conflicts
    for slot_id, assignments in slot_assignments.items():
        student_groups_in_slot = {}
        for student_groups, course_id in assignments:
            for student_group in student_groups:
                if student_group in student_groups_in_slot:
                    slot_conflicts += 1  # Conflict when a student is assigned to two courses at the same time
                else:
                    student_groups_in_slot[student_group] = course_id

    # Calculate professor conflicts
    for professor, assigned_slots in prof_assignments.items():
        if len(assigned_slots) > len(set(assigned_slots)):  # Duplicate slots means conflict
            prof_conflicts += 1

    return room_overbooking, slot_conflicts, prof_conflicts


def get_classsize(activity: Activity) -> int:
    classsize = 0
    for id in activity.group_ids:
        classsize += groups_dict[id].size
    return classsize

# Updated create_population function


def create_population(pop_size):
    population = []
    for _ in range(pop_size):
        solution = []
        room_slot_assignments = {space.code: set()
                                 # Track slots per room
                                 for space in spaces_dict.values()}
        prof_slot_assignments = {prof: set() for prof in set(
            activity.teacher_id for activity in activities_dict.values())}  # Track professor slots

        for activity in activities_dict.values():
            # course = courses[course_id]

            student_groups = activity.group_ids
            rooms = [room for room in spaces_dict.values(
            ) if room.size >= get_classsize(activity)]
            # student_group = course.student  # Get student group
            selected_room = random.choice(rooms)  # Random room

            # Find consecutive slots for the course
            valid_slots = [
                slot for slot in slots if slot not in room_slot_assignments[selected_room.code] and slot not in prof_slot_assignments[activity.teacher_id]]

            if len(valid_slots) >= activity.duration:
                selected_slots = random.sample(valid_slots, activity.duration)
            else:
                selected_slots = random.sample(slots, activity.duration)

            for slot in selected_slots:
                room_slot_assignments[selected_room.code].add(slot)
                prof_slot_assignments[activity.teacher_id].add(slot)

            solution.append(
                (activity.id, student_groups, selected_room.code, selected_slots, activity.teacher_id))
        
        population.append(solution)
        print(evaluator(adapter(solution)))
    return population

# Crossover function


def crossover(parent1, parent2):
    crossover_point = random.choice(range(1, len(parent1)))
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]
    return child1, child2


# NSGA-II selection based on non-dominated sorting and crowding distance
def non_dominated_sorting(population, fitness_values):
    fronts = [[]]
    rank = [0] * len(population)
    domination_count = [0] * len(population)
    dominated_solutions = [[] for _ in range(len(population))]

    for p in range(len(population)):
        for q in range(len(population)):
            if dominates(fitness_values[p], fitness_values[q]):
                dominated_solutions[p].append(q)
            elif dominates(fitness_values[q], fitness_values[p]):
                domination_count[p] += 1

        if domination_count[p] == 0:
            rank[p] = 0
            fronts[0].append(p)

    front_counter = 0
    while len(fronts[front_counter]) > 0:
        next_front = []
        for p in fronts[front_counter]:
            for q in dominated_solutions[p]:
                domination_count[q] -= 1
                if domination_count[q] == 0:
                    rank[q] = front_counter + 1
                    next_front.append(q)
        front_counter += 1
        fronts.append(next_front)

    return fronts


# Crowding distance for maintaining diversity in the population
def crowding_distance(front, fitness_values):
    distance = [0] * len(front)
    if len(front) > 1:  # Only calculate crowding distance if there are at least two individuals in the front
        sorted_by_first = sorted(front, key=lambda x: fitness_values[x][0])
        sorted_by_second = sorted(front, key=lambda x: fitness_values[x][1])

        # Set infinity for boundary individuals
        distance[0] = distance[-1] = float('inf')
        for i in range(1, len(front) - 1):
            distance[i] = (fitness_values[sorted_by_first[i + 1]][0] - fitness_values[sorted_by_first[i - 1]][0]) + \
                          (fitness_values[sorted_by_second[i + 1]][1] -
                           fitness_values[sorted_by_second[i - 1]][1])

    return distance


# Tournament selection for parents
def tournament_selection(population, fitness_values):
    selected_parents = random.sample(list(range(len(population))), 2)
    p1, p2 = selected_parents[0], selected_parents[1]

    if dominates(fitness_values[p1], fitness_values[p2]):
        return p1
    else:
        return p2


def mutate(solution):
    mutation_point = random.randint(0, len(solution) - 1)
    course_id, student_group, _, _, _ = solution[mutation_point]

    new_room = random.choice(list(spaces_dict.values())).code  # Random room
    new_slot = random.choice(slots)  # Random slot

    professor = activities_dict[course_id].teacher_id
    # Update with new room and slot, keep course_id and student_group the same
    solution[mutation_point] = (
        course_id, student_group, new_room, new_slot, professor)
    return solution

# Domination check


def dominates(fit1, fit2):
    return (fit1[0] <= fit2[0] and fit1[1] <= fit2[1] and fit1[2] <= fit2[2]) and \
           (fit1[0] < fit2[0] or fit1[1] < fit2[1] or fit1[2] < fit2[2])


# Run NSGA-II algorithm
def run_nsga2(pop_size=50, generations=1000):
    population = create_population(pop_size)
    for generation in range(generations):
        # Evaluate the fitness of the current population
        fitness_values = [fitness(solution) for solution in population]

        # Non-dominated sorting
        fronts = non_dominated_sorting(population, fitness_values)
        new_population = []

        # Iterate through each front and apply crossover and mutation
        for front in fronts:
            distances = crowding_distance(front, fitness_values)
            sorted_front = sorted(
                front, key=lambda x: distances[front.index(x)], reverse=True)

            # Select parents from the sorted front
            while len(new_population) < pop_size and len(sorted_front) > 1:
                parent1 = population[sorted_front[0]]
                parent2 = population[sorted_front[1]]

                # Crossover
                child1, child2 = crossover(parent1, parent2)

                # Mutation
                child1 = mutate(child1)
                child2 = mutate(child2)

                # Add children to the new population
                new_population.append(child1)
                new_population.append(child2)

        # Truncate to maintain population size
        population = new_population[:pop_size]

        # Print the progress
        if generation % 10 == 0:
            print(
                f"Generation {generation}: Population size {len(population)}")

    return population


# Running the algorithm
best_solution = run_nsga2()
print(f"Best solution: {best_solution}")
# Out:
#  Vacant Rooms : 0
# Lecturer Conflicts : 17
# Room Size Conflicts : 0
# Sub Group Conflicts:14
#  Vacant Rooms : 0
# Lecturer Conflicts : 13
# Room Size Conflicts : 0
# Sub Group Conflicts:16
#  Vacant Rooms : 7
# Lecturer Conflicts : 13
# Room Size Conflicts : 0
# Sub Group Conflicts:9
#  Vacant Rooms : 0
# Lecturer Conflicts : 9
# Room Size Conflicts : 0
# Sub Group Conflicts:12
#  Vacant Rooms : 0
# Lecturer Conflicts : 18
# Room Size Conflicts : 0
# Sub Group Conflicts:12
#  Vacant Rooms : 0
# Lecturer Conflicts : 11
# Room Size Conflicts : 0
# Sub Group Conflicts:15
#  Vacant Rooms : 0
# Lecturer Conflicts : 8
# Room Size Conflicts : 0
# Sub Group Conflicts:15
#  Vacant Rooms : 6
# Lecturer Conflicts : 19
# Room Size Conflicts : 0
# Sub Group Conflicts:8
#  Vacant Rooms : 2
# Lecturer Conflicts : 15
# Room Size Conflicts : 0
# Sub Group Conflicts:20
#  Vacant Rooms : 0
# Lecturer Conflicts : 14
# Room Size Conflicts : 0
# Sub Group Conflicts:20
#  Vacant Rooms : 0
# Lecturer Conflicts : 11
# Room Size Conflicts : 0
# Sub Group Conflicts:20
#  Vacant Rooms : 0
# Lecturer Conflicts : 10
# Room Size Conflicts : 0
# Sub Group Conflicts:13
#  Vacant Rooms : 5
# Lecturer Conflicts : 15
# Room Size Conflicts : 0
# Sub Group Conflicts:12
#  Vacant Rooms : 2
# Lecturer Conflicts : 9
# Room Size Conflicts : 0
# Sub Group Conflicts:20
#  Vacant Rooms : 5
# Lecturer Conflicts : 7
# Room Size Conflicts : 0
# Sub Group Conflicts:14
#  Vacant Rooms : 13
# Lecturer Conflicts : 15
# Room Size Conflicts : 0
# Sub Group Conflicts:14
#  Vacant Rooms : 0
# Lecturer Conflicts : 20
# Room Size Conflicts : 0
# Sub Group Conflicts:10
#  Vacant Rooms : 0
# Lecturer Conflicts : 13
# Room Size Conflicts : 0
# Sub Group Conflicts:12
#  Vacant Rooms : 3
# Lecturer Conflicts : 13
# Room Size Conflicts : 0
# Sub Group Conflicts:12
#  Vacant Rooms : 1
# Lecturer Conflicts : 12
# Room Size Conflicts : 0
# Sub Group Conflicts:12
#  Vacant Rooms : 1
# Lecturer Conflicts : 8
# Room Size Conflicts : 0
# Sub Group Conflicts:14
#  Vacant Rooms : 0
# Lecturer Conflicts : 12
# Room Size Conflicts : 0
# Sub Group Conflicts:7
#  Vacant Rooms : 0
# Lecturer Conflicts : 14
# Room Size Conflicts : 0
# Sub Group Conflicts:18
#  Vacant Rooms : 0
# Lecturer Conflicts : 10
# Room Size Conflicts : 0
# Sub Group Conflicts:11
#  Vacant Rooms : 1
# Lecturer Conflicts : 13
# Room Size Conflicts : 0
# Sub Group Conflicts:9
#  Vacant Rooms : 0
# Lecturer Conflicts : 15
# Room Size Conflicts : 0
# Sub Group Conflicts:14
#  Vacant Rooms : 5
# Lecturer Conflicts : 15
# Room Size Conflicts : 0
# Sub Group Conflicts:21
#  Vacant Rooms : 2
# Lecturer Conflicts : 9
# Room Size Conflicts : 0
# Sub Group Conflicts:19
#  Vacant Rooms : 0
# Lecturer Conflicts : 9
# Room Size Conflicts : 0
# Sub Group Conflicts:12
#  Vacant Rooms : 4
# Lecturer Conflicts : 16
# Room Size Conflicts : 0
# Sub Group Conflicts:13
#  Vacant Rooms : 0
# Lecturer Conflicts : 12
# Room Size Conflicts : 0
# Sub Group Conflicts:10
#  Vacant Rooms : 3
# Lecturer Conflicts : 8
# Room Size Conflicts : 0
# Sub Group Conflicts:13
#  Vacant Rooms : 0
# Lecturer Conflicts : 7
# Room Size Conflicts : 0
# Sub Group Conflicts:14
#  Vacant Rooms : 2
# Lecturer Conflicts : 17
# Room Size Conflicts : 0
# Sub Group Conflicts:11
#  Vacant Rooms : 8
# Lecturer Conflicts : 17
# Room Size Conflicts : 0
# Sub Group Conflicts:18
#  Vacant Rooms : 2
# Lecturer Conflicts : 20
# Room Size Conflicts : 0
# Sub Group Conflicts:27
#  Vacant Rooms : 6
# Lecturer Conflicts : 10
# Room Size Conflicts : 0
# Sub Group Conflicts:9
#  Vacant Rooms : 2
# Lecturer Conflicts : 14
# Room Size Conflicts : 0
# Sub Group Conflicts:15
#  Vacant Rooms : 0
# Lecturer Conflicts : 11
# Room Size Conflicts : 0
# Sub Group Conflicts:14
#  Vacant Rooms : 0
# Lecturer Conflicts : 12
# Room Size Conflicts : 0
# Sub Group Conflicts:12
#  Vacant Rooms : 0
# Lecturer Conflicts : 10
# Room Size Conflicts : 0
# Sub Group Conflicts:9
#  Vacant Rooms : 3
# Lecturer Conflicts : 9
# Room Size Conflicts : 0
# Sub Group Conflicts:15
#  Vacant Rooms : 0
# Lecturer Conflicts : 12
# Room Size Conflicts : 0
# Sub Group Conflicts:15
#  Vacant Rooms : 0
# Lecturer Conflicts : 12
# Room Size Conflicts : 0
# Sub Group Conflicts:11
#  Vacant Rooms : 3
# Lecturer Conflicts : 13
# Room Size Conflicts : 0
# Sub Group Conflicts:15
#  Vacant Rooms : 7
# Lecturer Conflicts : 11
# Room Size Conflicts : 0
# Sub Group Conflicts:10
#  Vacant Rooms : 0
# Lecturer Conflicts : 13
# Room Size Conflicts : 0
# Sub Group Conflicts:12
#  Vacant Rooms : 0
# Lecturer Conflicts : 13
# Room Size Conflicts : 0
# Sub Group Conflicts:24
#  Vacant Rooms : 0
# Lecturer Conflicts : 11
# Room Size Conflicts : 0
# Sub Group Conflicts:8
#  Vacant Rooms : 0
# Lecturer Conflicts : 14
# Room Size Conflicts : 0
# Sub Group Conflicts:13
# Generation 0: Population size 50
# Generation 10: Population size 50
# Generation 20: Population size 50
# Generation 30: Population size 50
# Generation 40: Population size 50
# Generation 50: Population size 50
# Generation 60: Population size 50
# Generation 70: Population size 50
# Generation 80: Population size 50
# Generation 90: Population size 50
# Generation 100: Population size 50
# Generation 110: Population size 50
# Generation 120: Population size 50
# Generation 130: Population size 50
# Generation 140: Population size 50
# Generation 150: Population size 50
# Generation 160: Population size 50
# Generation 170: Population size 50
# Generation 180: Population size 50
# Generation 190: Population size 50
# Generation 200: Population size 50
# Generation 210: Population size 50
# Generation 220: Population size 50
# Generation 230: Population size 50
# Generation 240: Population size 50
# Generation 250: Population size 50
# Generation 260: Population size 50
# Generation 270: Population size 50
# Generation 280: Population size 50
# Generation 290: Population size 50
# Generation 300: Population size 50
# Generation 310: Population size 50
# Generation 320: Population size 50
# Generation 330: Population size 50
# Generation 340: Population size 50
# Generation 350: Population size 50
# Generation 360: Population size 50
# Generation 370: Population size 50
# Generation 380: Population size 50
# Generation 390: Population size 50
# Generation 400: Population size 50
# Generation 410: Population size 50
# Generation 420: Population size 50
# Generation 430: Population size 50
# Generation 440: Population size 50
# Generation 450: Population size 50
# Generation 460: Population size 50
# Generation 470: Population size 50
# Generation 480: Population size 50
# Generation 490: Population size 50
# Generation 500: Population size 50
# Generation 510: Population size 50
# Generation 520: Population size 50
# Generation 530: Population size 50
# Generation 540: Population size 50
# Generation 550: Population size 50
# Generation 560: Population size 50
# Generation 570: Population size 50
# Generation 580: Population size 50
# Generation 590: Population size 50
# Generation 600: Population size 50
# Generation 610: Population size 50
# Generation 620: Population size 50
# Generation 630: Population size 50
# Generation 640: Population size 50
# Generation 650: Population size 50
# Generation 660: Population size 50
# Generation 670: Population size 50
# Generation 680: Population size 50
# Generation 690: Population size 50
# Generation 700: Population size 50
# Generation 710: Population size 50
# Generation 720: Population size 50
# Generation 730: Population size 50
# Generation 740: Population size 50
# Generation 750: Population size 50
# Generation 760: Population size 50
# Generation 770: Population size 50
# Generation 780: Population size 50
# Generation 790: Population size 50
# Generation 800: Population size 50
# Generation 810: Population size 50
# Generation 820: Population size 50
# Generation 830: Population size 50
# Generation 840: Population size 50
# Generation 850: Population size 50
# Generation 860: Population size 50
# Generation 870: Population size 50
# Generation 880: Population size 50
# Generation 890: Population size 50
# Generation 900: Population size 50
# Generation 910: Population size 50
# Generation 920: Population size 50
# Generation 930: Population size 50
# Generation 940: Population size 50
# Generation 950: Population size 50
# Generation 960: Population size 50
# Generation 970: Population size 50
# Generation 980: Population size 50
# Generation 990: Population size 50
# Best solution: [[('AC-001', ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], 'LH501', ['FRI5', 'THU8'], 'FA0000004'), ('AC-002', ['Y1S1.1'], 'LH501', 'MON2', 'FA0000001'), ('AC-003', ['Y1S1.2'], 'LH501', 'FRI1', 'FA0000006'), ('AC-004', ['Y1S1.3'], 'LAB501', 'WED1', 'FA0000009'), ('AC-005', ['Y1S1.4'], 'LH401', 'WED3', 'FA0000008'), ('AC-006', ['Y1S1.5'], 'LAB502', 'THU7', 'FA0000001'), ('AC-007', ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], 'LH401', ['TUE8', 'MON7'], 'FA0000003'), ('AC-008', ['Y1S1.1'], 'LH401', 'WED7', 'FA0000004'), ('AC-009', ['Y1S1.2'], 'LAB502', 'THU2', 'FA0000004'), ('AC-010', ['Y1S1.3'], 'LAB502', ['TUE4'], 'FA0000005'), ('AC-011', ['Y1S1.4'], 'LAB501', 'MON6', 'FA0000004'), ('AC-012', ['Y1S1.5'], 'LAB501', 'FRI2', 'FA0000006'), ('AC-013', ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], 'LH401', ['TUE1', 'THU2'], 'FA0000006'), ('AC-014', ['Y1S1.1'], 'LH401', 'THU3', 'FA0000001'), ('AC-015', ['Y1S1.2'], 'LH501', 'MON6', 'FA0000007'), ('AC-016', ['Y1S1.3'], 'LH401', 'MON3', 'FA0000010'), ('AC-017', ['Y1S1.4'], 'LAB502', 'THU2', 'FA0000002'), ('AC-018', ['Y1S1.5'], 'LAB502', 'MON1', 'FA0000005'), ('AC-019', ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], 'LH401', ['WED8', 'WED6'], 'FA0000007'), ('AC-020', ['Y1S1.1'], 'LH401', 'FRI8', 'FA0000006'), ('AC-021', ['Y1S1.2'], 'LH501', ['MON5'], 'FA0000005'), ('AC-022', ['Y1S1.3'], 'LAB501', 'THU6', 'FA0000004'), ('AC-023', ['Y1S1.4'], 'LAB501', 'FRI7', 'FA0000005'), ('AC-024', ['Y1S1.5'], 'LH501', 'WED4', 'FA0000001'), ('AC-025', ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], 'LH401', ['THU4', 'THU1'], 'FA0000004'), ('AC-026', ['Y1S2.1'], 'LH501', ['MON3'], 'FA0000006'), ('AC-027', ['Y1S2.2'], 'LH401', 'FRI6', 'FA0000009'), ('AC-028', ['Y1S2.3'], 'LAB501', 'THU2', 'FA0000008'), ('AC-029', ['Y1S2.4'], 'LH401', ['MON3'], 'FA0000009'), ('AC-030', ['Y1S2.5'], 'LH401', 'WED2', 'FA0000007'), ('AC-031', ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], 'LH501', ['FRI6', 'WED3'], 'FA0000007'), ('AC-032', ['Y1S2.1'], 'LAB502', 'WED4', 'FA0000003'), ('AC-033', ['Y1S2.2'], 'LH401', 'THU7', 'FA0000006'), ('AC-034', ['Y1S2.3'], 'LAB501', 'FRI7', 'FA0000006'), ('AC-035', ['Y1S2.4'], 'LAB502', 'THU5', 'FA0000005'), ('AC-036', ['Y1S2.5'], 'LAB501', ['WED8'], 'FA0000008'), ('AC-037', ['Y1S2.1'], 'LAB501', ['TUE4', 'TUE2'], 'FA0000009'), ('AC-038', ['Y1S2.2'], 'LAB501', ['WED2', 'MON6'], 'FA0000006'), ('AC-039', ['Y1S2.3'], 'LAB502', ['WED5', 'WED2'], 'FA0000010'), ('AC-040', ['Y1S2.4'], 'LAB501', 'THU1', 'FA0000006'), ('AC-041', ['Y1S2.5'], 'LH401', 'FRI4', 'FA0000003'), ('AC-042', ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], 'LH501', 'MON8', 'FA0000001'), ('AC-043', ['Y1S2.1'], 'LH501', 'THU7', 'FA0000003'), ('AC-044', ['Y1S2.2'], 'LH401', ['FRI5'], 'FA0000006'), ('AC-045', ['Y1S2.3'], 'LH501', ['MON4'], 'FA0000004'), ('AC-046', ['Y1S2.4'], 'LAB502', ['WED7'], 'FA0000009'), ('AC-047', ['Y1S2.5'], 'LH501', ['WED4'], 'FA0000007'), ('AC-048', ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], 'LH401', ['THU5', 'FRI4'], 'FA0000004'), ('AC-049', ['Y1S2.1'], 'LH401', 'FRI2', 'FA0000010'), ('AC-050', ['Y1S2.2'], 'LAB501', 'WED1', 'FA0000002'), ('AC-051', ['Y1S2.3'], 'LH501', 'WED6', 'FA0000006'), ('AC-052', ['Y1S2.4'], 'LAB502', 'FRI1', 'FA0000010'), ('AC-053', ['Y1S2.5'], 'LH501', 'THU5', 'FA0000001'), ('AC-054', ['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'], 'LH401', ['WED2', 'THU3'], 'FA0000009'), ('AC-055', ['Y2S1.1'], 'LAB502', ['TUE1'], 'FA0000007'), ('AC-056', ['Y2S1.2'], 'LH401', ['WED1'], 'FA0000009'), ('AC-057', ['Y2S1.3'], 'LH501', 'MON3', 'FA0000010'), ('AC-058', ['Y2S1.4'], 'LAB501', 'THU1', 'FA0000001'), ('AC-059', ['Y2S1.5'], 'LAB502', 'THU7', 'FA0000002'), ('AC-060', ['Y2S1.1'], 'LAB501', 'WED8', 'FA0000001'), ('AC-061', ['Y2S1.2'], 'LH501', 'MON6', 'FA0000004'), ('AC-062', ['Y2S1.3'], 'LAB501', 'WED2', 'FA0000001'), ('AC-063', ['Y2S1.4'], 'LAB502', 'MON4', 'FA0000006'), ('AC-064', ['Y2S1.5'], 'LH401', ['MON8', 'WED5'], 'FA0000005' ...

# %%
evaluator(adapter(best_solution[0]))
# Out:
# ' Vacant Rooms : 47 \nLecturer Conflicts : 11\nRoom Size Conflicts : 0\nSub Group Conflicts:6 '

# %%
minimum_conflicts = 1000
final_solution = "hello"
for solution in best_solution:
    if minimum_conflicts >= sum(fitness(solution)):
        minimum_conflicts = sum(fitness(solution))
        final_solution = solution
print(minimum_conflicts)
# Out:
# 17

# %%
# Activity(id=AC-057, subject=IT2010, teacher_id=FA0000010, group_ids=['Y2S1.3'], duration=1),
def adapter(solution):
    timetable = {}
    for slot in slots:
        timetable[slot] = {}
        for space in spaces_dict.keys():
            timetable[slot][space] = ""

    for period in solution:
        time_slots = period[3]
        room = period[2]
        activity_id = period[0]
        if not isinstance(time_slots, list):
            time_slots = [time_slots]
        for aslot in time_slots:
            timetable[aslot][room] = activities_dict[activity_id]
    return timetable

timetable = adapter(final_solution)

# %%
vacant_rooms = []
def evaluator(timetable):
    vacant_room = 0
    prof_conflicts = 0
    room_size_conflicts = 0
    sub_group_conflicts = 0
    unasigned_activities = len(activities_dict)
    activities_set = set()

    for slot in timetable:
        prof_set = set()
        sub_group_set = set()
        for room in timetable[slot]:
            activity = timetable[slot][room]

            if not isinstance(activity, Activity):
                vacant_room += 1
                vacant_rooms.append((slot,room))

            else:
                activities_set.add(activity.id)
                if activity.teacher_id in prof_set:
                    prof_conflicts += 1

                sub_group_conflicts += len(
                    set(activity.group_ids).intersection(sub_group_set))

                group_size = 0
                for group_id in activity.group_ids:
                    group_size += groups_dict[group_id].size
                    sub_group_set.add(group_id)

                if group_size > spaces_dict[room].size:
                    room_size_conflicts += 1
                teacher_id = activity.teacher_id
                prof_set.add(teacher_id)
    unasigned_activities -= len(activities_set)
    return vacant_room, prof_conflicts, room_size_conflicts, sub_group_conflicts, unasigned_activities
    # return f" Vacant Rooms : {vacant_room} \nLecturer Conflicts : {prof_conflicts}\nRoom Size Conflicts : {room_size_conflicts}\nSub Group Conflicts:{sub_group_conflicts} \nNo:of Unassigned Activities:{unasigned_activities} "

# %%
evaluator(timetable)
# Out:
# (39, 9, 0, 5, 82)

# %%
def print_metric(vacant_rooms, prof_conflicts, room_size_conflicts,sub_group_conflicts, unassigned_activities):
    return f" Vacant Rooms : {vacant_rooms} \nLecturer Conflicts : {prof_conflicts}\nRoom Size Conflicts : {room_size_conflicts}\nSub Group Conflicts:{sub_group_conflicts} \nNo:of Unassigned Activities:{unassigned_activities} "

print_metric(*evaluator(timetable))
# Out:
# ' Vacant Rooms : 39 \nLecturer Conflicts : 9\nRoom Size Conflicts : 0\nSub Group Conflicts:5 \nNo:of Unassigned Activities:82 '

# %%
timetable
# Out:
# {'MON1': {'LH401': '',
#   'LH501': Activity(id=AC-194, subject=IT4570, teacher_id=FA0000005, group_ids=['Y4S2.4'], duration=1),
#   'LAB501': Activity(id=AC-170, subject=IT4020, teacher_id=FA0000006, group_ids=['Y4S1.4'], duration=1),
#   'LAB502': Activity(id=AC-008, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.1'], duration=1)},
#  'MON2': {'LH401': Activity(id=AC-125, subject=IT3030, teacher_id=FA0000006, group_ids=['Y3S1.1'], duration=1),
#   'LH501': Activity(id=AC-136, subject=IT3550, teacher_id=FA0000002, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#   'LAB501': '',
#   'LAB502': ''},
#  'MON3': {'LH401': Activity(id=AC-053, subject=IT1580, teacher_id=FA0000001, group_ids=['Y1S2.5'], duration=1),
#   'LH501': '',
#   'LAB501': Activity(id=AC-045, subject=IT1570, teacher_id=FA0000004, group_ids=['Y1S2.3'], duration=1),
#   'LAB502': Activity(id=AC-168, subject=IT4020, teacher_id=FA0000006, group_ids=['Y4S1.2'], duration=1)},
#  'MON4': {'LH401': Activity(id=AC-161, subject=IT4010, teacher_id=FA0000002, group_ids=['Y4S1.1'], duration=1),
#   'LH501': '',
#   'LAB501': '',
#   'LAB502': ''},
#  'MON5': {'LH401': Activity(id=AC-191, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.1'], duration=1),
#   'LH501': Activity(id=AC-172, subject=IT4030, teacher_id=FA0000010, group_ids=['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'], duration=2),
#   'LAB501': Activity(id=AC-078, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.1'], duration=1),
#   'LAB502': Activity(id=AC-075, subject=IT2030, teacher_id=FA0000006, group_ids=['Y2S1.4'], duration=1)},
#  'MON6': {'LH401': Activity(id=AC-065, subject=IT2020, teacher_id=FA0000003, group_ids=['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'], duration=2),
#   'LH501': Activity(id=AC-030, subject=IT1550, teacher_id=FA0000007, group_ids=['Y1S2.5'], duration=1),
#   'LAB501': '',
#   'LAB502': ''},
#  'MON7': {'LH401': Activity(id=AC-033, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=1),
#   'LH501': Activity(id=AC-175, subject=IT4030, teacher_id=FA0000004, group_ids=['Y4S1.3'], duration=1),
#   'LAB501': '',
#   'LAB502': Activity(id=AC-114, subject=IT3010, teacher_id=FA0000010, group_ids=['Y3S1.2'], duration=1)},
#  'MON8': {'LH401': Activity(id=AC-187, subject=IT4560, teacher_id=FA0000010, group_ids=['Y4S2.3'], duration=1),
#   'LH501': Activity(id=AC-178, subject=IT4550, teacher_id=FA0000007, group_ids=['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'], duration=2),
#   'LAB501': Activity(id=AC-038, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.2'], duration=2),
#   'LAB502': Activity(id=AC-156, subject=IT3580, teacher_id=FA0000010, group_ids=['Y3S2.2'], duration=1)},
#  'TUE1': {'LH401': Activity(id=AC-034, subject=IT1560, teacher_id=FA0000006, group_ids=['Y1S2.3'], duration=1),
#   'LH501': Activity(id=AC-083, subject=IT2550, teacher_id=FA0000001, group_ids=['Y2S2.1', 'Y2S2.2', 'Y2S2.3', 'Y2S2.4', 'Y2S2.5'], duration=2),
#   'LAB501': '',
#   'LAB502': ''},
#  'TUE2': {'LH401': Activity(id=AC-112, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#   'LH501': Activity(id=AC-042, subject=IT1570, teacher_id=FA0000001, group_ids=['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], duration=2),
#   'LAB501': Activity(id=AC-162, subject=IT4010, teacher_id=FA0000009, group_ids=['Y4S1.2'], duration=1),
#   'LAB502': ''},
#  'TUE3': {'LH401': '',
#   'LH501': Activity(id=AC-169, subject=IT4020, teacher_id=FA0000008, group_ids=['Y4S1.3'], duration=1),
#   'LAB501': '',
#   'LAB502': ''},
#  'TUE4': {'LH401': Activity(id=AC-112, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#   'LH501': Activity(id=AC-172, subject=IT4030, teacher_id=FA0000010, group_ids=['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'], duration=2),
#   'LAB501': Activity(id=AC-092, subject=IT2560, teacher_id=FA0000006, group_ids=['Y2S2.3'], duration=1),
#   'LAB502': Activity(id=AC-155, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.1'], duration=1)},
#  'TUE5': {'LH401': '',
#   'LH501': Activity(id=AC-190, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'], duration=2),
#   'LAB501': Activity(id=AC-028, subject=IT1550, teacher_id=FA0000008, group_ids=['Y1S2.3'], duration=1),
#   'LAB502': Activity(id=AC-064, subject=IT2010, teacher_id=FA0000005, group_ids=['Y2S1.5'], duration=2)},
#  'TUE6': {'LH401': Activity(id=AC-166, subject=IT4020, teacher_id=FA0000002, group_ids=['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'], duration=2),
#   'LH501': Activity(id=AC-164, subject=IT4010, teacher_id=FA0000005, group_ids=['Y4S1.4'], duration=1),
#   'LAB501': '',
#   'LAB502': Activity(id=AC-080, subject=IT2040, teacher_id=FA0000008, group_ids=['Y2S1.3'], duration=1)},
#  'TUE7': {'LH401': '',
#   'LH501': Activity(id=AC-029, subject=IT1550, teacher_id=FA0000009, group_ids=['Y1S2.4'], duration=1),
#   'LAB501': '',
#   'LAB502': Activity(id=AC-032, subject=IT1560, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1)},
#  'TUE8': {'LH401': Activity(id=AC-148, subject=IT3570, teacher_id=FA0000003, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#   'LH501': Activity(id=AC-178, subject=IT4550, teacher_id=FA0000007, group_ids=['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'], duration=2),
#   'LAB501': '',
#   'LAB502': Activity(id=AC-108, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.2'], duration=1)},
#  'WED1': {'LH401': Activity(id=AC-141, subject=IT3550, teacher_id=FA0000001, group_ids=['Y3S2.5'], duration=1),
#   'LH501': Activity(id=AC-036, subject=IT1560, teacher_id=FA0000008, group_ids=['Y1S2.5'], duration=1),
#   'LAB501': Activity(id=AC-093, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.4'], duration=1),
#   'LAB502': ''},
#  'WED2': {'LH401': Activity(id=AC-185, subject=IT4560, teacher_id=FA0000008, group_ids=['Y4S2.1'], duration=1),
#   'LH501': Activity(id=AC-132, subject=IT3040, teacher_id=FA0000005, group_ids=['Y3S1.2'], duration=1),
#   'LAB501': Activity(id=AC-182, subject=IT4550, teacher_id=FA0000004, group_ids=['Y4S2.4'], duration=1),
#   'LAB502': Activity(id=AC-091, subject=IT2560, teacher_id=FA0000001, group_ids=['Y2S2.2'], duration=1)},
#  'WED3': {'LH401': Activity(id=AC-192, subject=IT4570, teacher_id=FA0000001, group_ids=['Y4S2.2'], duration=1),
#   'LH501': '',
#   'LAB501': '',
#   'LAB502': Activity(id=AC-134, subject=IT3040, teacher_id=FA0000010, group_ids=['Y3S1.4'], duration=1)},
#  'WED4': {'LH401': Activity(id=AC-171, subject=IT4020, teacher_id=FA0000009, group_ids=['Y4S1.5'], duration=1),
#   'LH501': Activity(id=AC-154, subject=IT3580, teacher_id=FA0000009, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#   'LAB501': '',
#   'LAB502': Activity(id=AC-127, subject=IT3030, teacher_id=FA0000003, group_ids=['Y3S1.3'], duration=1)},
#  'WED5': {'LH401': Activity(id=AC-100, subject=IT2570, teacher_id=FA0000009, group_ids=['Y2S2.1', 'Y2S2.2', 'Y2S2.3', 'Y2S2.4', 'Y2S2.5'], duration=2),
#   'LH501': Activity(id=AC-120, subject=IT3020, teacher_id=FA0000001, group_ids=['Y3S1.2'], duration=1),
#   'LAB501': Activity(id=AC-158, subject=IT3580, teacher_id=FA0000009, group_ids=['Y3S2.4'], duration=1),
#   'LAB502': Activity(id=AC-131, subject=IT3040, teacher_id=FA0000005, group_ids=['Y3S1.1'], duration=1)},
#  'WED6': {'LH401': Activity(id=AC-183, subject=IT4550, teacher_id=FA0000007, group_ids=['Y4S2.5'], duration=1),
#   'LH501': Activity(id=AC-154, subject=IT3580, teacher_id=FA0000009, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#   'LAB501': Activity(id=AC-027, subject=IT1550, teacher_id=FA0000009, group_ids=['Y1S2.2'], duration=1),
#   'LAB502': Activity(id=AC-082, subject=IT2040, teacher_id=FA0000003, group_ids=['Y2S1.5'], duration=1)},
#  'WED7': {'LH401': Activity(id=AC-184, subject=IT4560, teacher_id=FA0000001, group_ids=['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'], duration=2),
#   'LH501': Activity(id=AC-097, subject=IT2560, teacher_id=FA0000002, group_ids=['Y2S2.3'], duration=2),
#   'LAB501': Activity(id=AC-024, subject=IT1040, teacher_id=FA0000001, group_ids=['Y1S1.5'], duration=1),
#   'LAB502': ''},
#  'WED8': {'LH401': Activity(id=AC-142, subject=IT3560, teacher_id=FA0000008, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#   'LH501': Activity(id=AC-107, subject=IT2580, teacher_id=FA0000003, group_ids=['Y2S2.1'], duration=1),
#   'LAB501': '',
#   'LAB502': ''},
#  'THU1': {'LH401': Activity(id=AC-070, subject=IT2020, teacher_id=FA0000007, group_ids=['Y2S1.5'], duration=1),
#   'LH501': Activity(id=AC-098, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.4'], duration=2),
#   'LAB501': Activity(id=AC-102, subject=IT2570, teacher_id=FA0000006, group_ids=['Y2S2.2'], duration=1),
#   'LAB502': Activity(id=AC-076, subject=IT2030, teacher_id=FA0000001, group_ids=['Y2S1.5'], duration=1)},
#  'THU2': {'LH401': '',
#   'LH501': Activity(id=AC-099, subject=IT2560, teacher_id=FA0000009, group_ids=['Y2S2.5'], duration=2),
#   'LAB501': Activity(id=AC-055, subject=IT2010, teacher_id=FA0000007, group_ids=['Y2S1.1'], duration=1),
#   'LAB502': ''},
#  'THU3': {'LH401': Activity(id=AC-137, subject=IT3550, teacher_id=FA0000003, group_ids=['Y3S2.1'], duration=1),
#   'LH501': Activity(id=AC-195, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.5'], duration=1),
#   'LAB501': Activity(id=AC-181, subject=IT4550, teacher_id=FA0000002, group_ids=['Y4S2.3'], duration=1),
#   'LAB502': Activity(id=AC-012, subject=IT1020, teacher_id=FA0000006, group_ids=['Y1S1.5'], duration=1)},
#  'THU4': {'LH401': Activity(id=AC-159, subject=IT3580, teacher_id=FA0000005, group_ids=['Y3S2.5'], duration=1),
#   'LH501': '',
#   'LAB501': '',
#   'LAB502': Activity(id=AC-144, subject=IT3560, teacher_id=FA0000001, group_ids=['Y3S2.2'], duration=1)},
#  'THU5': {'LH401': Activity(id=AC-117, subject=IT3010, teacher_id=FA0000005, group_ids=['Y3S1.5'], duration=1),
#   'LH501': Activity(id=AC-037, subject=IT1560, teacher_id=FA0000009, group_ids=['Y1S2.1'], duration=2),
#   'LAB501': Activity(id=AC-111, subject=IT2580, teacher_id=FA0000007, group_ids=['Y2S2.5'], duration=1),
#   'LAB502': Activity(id=AC-180, subject=IT4550, teacher_id=FA0000001, group_ids=['Y4S2.2'], duration=1)},
#  'THU6': {'LH401': Activity(id=AC-166, subject=IT4020, teacher_id=FA0000002, group_ids=['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'], duration=2),
#   'LH501': Activity(id=AC-103, subject=IT2570, teacher_id=FA0000008, group_ids=['Y2S2.3'], duration=1),
#   'LAB501': Activity(id=AC-188, subject=IT4560, teacher_id=FA0000001, group_ids=['Y4S2.4'], duration=1),
#   'LAB502': Activity(id=AC-153, subject=IT3570, teacher_id=FA0000008, group_ids=['Y3S2.5'], duration=1)},
#  'THU7': {'LH401': Activity(id=AC-167, subject=IT4020, teacher_id=FA0000001, group_ids=['Y4S1.1'], duration=1),
#   'LH501': Activity(id=AC-119, subject=IT3020, teacher_id=FA0000002, group_ids=['Y3S1.1'], duration=1),
#   'LAB501': Activity(id=AC-140, subject=IT3550, teacher_id=FA0000007, group_ids=['Y3S2.4'], duration=1),
#   'LAB502': Activity(id=AC-052, subject=IT1580, teacher_id=FA0000010, group_ids=['Y1S2.4'], duration=1)},
#  'THU8': {'LH401': Activity(id=AC-165, subject=IT4010, teacher_id=FA0000009, group_ids=['Y4S1.5'], duration=1),
#   'LH501': Activity(id=AC-043, subject=IT1570, teacher_id=FA0000003, group_ids=['Y1S2.1'], duration=1),
#   'LAB501': '',
#   'LAB502': Activity(id=AC-129, subject=IT3030, teacher_id=FA0000010, group_ids=['Y3S1.5'], duration=1)},
#  'FRI1': {'LH401': Activity(id=AC-001, subject=IT1010, teacher_id=FA0000004, group_ids=['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], duration=2),
#   'LH501': Activity(id=AC-174, subject=IT4030, teacher_id=FA0000002, group_ids=['Y4S1.2'], duration=1),
#   'LAB501': Activity(id=AC-189, subject=IT4560, teacher_id=FA0000006, group_ids=['Y4S2.5'], duration=1),
#   'LAB502': Activity(id=AC-058, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.4'], duration=1)},
#  'FRI2': {'LH401': '',
#   'LH501': Activity(id=AC-173, subject=IT4030, teacher_id=FA0000008, group_ids=['Y4S1.1'], duration=1),
#   'LAB501': Activity(id=AC-193, subject=IT4570, teacher_id=FA0000004, group_ids=['Y4S2.3'], duration=1),
#   'LAB502': Activity(id=AC-176, subject=IT4030, teacher_id=FA0000007, group_ids=['Y4S1.4'], duration=1)},
#  'FRI3': {'LH401': Activity(id=AC-113, subject=IT3010, teacher_id=FA0000007, group_ids=['Y3S1.1'], duration=1),
#   'LH501': Activity(id=AC-124, subject=IT3030, teacher_id=FA0000004, group_ids=['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'], duration=2),
#   'LAB501': Activity(id=AC-060, subject=IT2010, teacher_id=FA0000001, group_ids=['Y2S1.1'], duration=2),
#   'LAB502': Activity(id=AC-126, subject=IT3030, teacher_id=FA0000006, group_ids=['Y3S1.2'], duration=1)},
#  'FRI4': {'LH401': Activity(id=AC-010, subject=IT1020, teacher_id=FA0000005, group_ids=['Y1S1.3'], duration=1),
#   'LH501': Activity(id=AC-190, subject=IT4570, teacher_id=FA0000008, group_ids=['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'], duration=2),
#   'LAB501': Activity(id=AC-147, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.5'], duration=1),
#   'LAB502': Activity(id=AC-079, subject=IT2040, teacher_id=FA0000004, group_ids=['Y2S1.2'], duration=1)},
#  'FRI5': {'LH401': Activity(id=AC-157, subject=IT3580, teacher_id=FA0000002, group_ids=['Y3S2.3'], duration=1),
#   'LH501': Activity(id=AC-086, subject=IT2550, teacher_id=FA0000005, group_ids=['Y2S2.3'], duration=1),
#   'LAB501': '',
#   'LAB502': ''},
#  'FRI6': {'LH401': Activity(id=AC-184, subject=IT4560, teacher_id=FA0000001, group_ids=['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'], duration=2),
#   'LH501': Activity(id=AC-149, subject=IT3570, teacher_id=FA0000009, group_ids=['Y3S2.1'], duration=1),
#   'LAB501': Activity(id=AC-035, subject=IT1560, teacher_id=FA0000005, group_ids=['Y1S2.4'], duration=1),
#   'LAB502': Activity(id=AC-146, subject=IT3560, teacher_id=FA0000004, group_ids=['Y3S2.4'], duration=1)},
#  'FRI7': {'LH401': Activity(id=AC-123, subject=IT3020, teacher_id=FA0000006, group_ids=['Y3S1.5'], duration=1),
#   'LH501': Activity(id=AC-096, subject=IT2560, teacher_id=FA0000004, group_ids=['Y2S2.2'], duration=2),
#   'LAB501': '',
#   'LAB502': ''},
#  'FRI8': {'LH401': Activity(id=AC-148, subject=IT3570, teacher_id=FA0000003, group_ids=['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'], duration=2),
#   'LH501': Activity(id=AC-121, subject=IT3020, teacher_id=FA0000010, group_ids=['Y3S1.3'], duration=1),
#   'LAB501': '',
#   'LAB502': Activity(id=AC-011, subject=IT1020, teacher_id=FA0000004, group_ids=['Y1S1.4'], duration=1)}}
