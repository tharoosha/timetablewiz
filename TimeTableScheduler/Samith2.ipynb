# %%
# Out:
# {'faculties': [{'name': 'Computing', 'code': 'FCSC', 'departments': ['Computer Science and Software Engineering', 'Information Technology', 'Cyber Security', 'Interactive Media', 'Information Systems Engineering', 'Data Science']}], 'modules': [{'code': 'IT1010', 'name': 'Introduction to Computing', 'long_name': 'Introduction to Computing', 'description': 'Basic computing concepts'}, {'code': 'IT1020', 'name': 'IP', 'long_name': 'Introduction to Programming', 'description': 'Programming fundamentals'}, {'code': 'IT1030', 'name': 'MC', 'long_name': 'Mathematics for Computing', 'description': 'Mathematical concepts'}, {'code': 'IT1040', 'name': 'DBMS', 'long_name': 'Database Management Systems', 'description': 'Database fundamentals'}, {'code': 'IT1550', 'name': 'OOP', 'long_name': 'Object Oriented Programming', 'description': 'OOP concepts'}, {'code': 'IT1560', 'name': 'Web Development', 'long_name': 'Web Development', 'description': 'Web development basics'}, {'code': 'IT1570', 'name': 'Statistics', 'long_name': 'Statistics for IT', 'description': 'Statistical methods'}, {'code': 'IT1580', 'name': 'DSA', 'long_name': 'Data Structures and Algorithms', 'description': 'Data structures basics'}, {'code': 'IT2010', 'name': 'Advanced Programming', 'long_name': 'Advanced Programming', 'description': 'Advanced programming concepts'}, {'code': 'IT2020', 'name': 'DBMS II', 'long_name': 'Advanced Database Systems', 'description': 'Advanced database concepts'}, {'code': 'IT2030', 'name': 'Software Engineering', 'long_name': 'Software Engineering', 'description': 'Software engineering principles'}, {'code': 'IT2040', 'name': 'Networking', 'long_name': 'Computer Networks II', 'description': 'Advanced networking concepts'}, {'code': 'IT2550', 'name': 'Mobile Development', 'long_name': 'Mobile Application Development', 'description': 'Mobile app development'}, {'code': 'IT2560', 'name': 'Web Programming', 'long_name': 'Advanced Web Programming', 'description': 'Advanced web development'}, {'code': 'IT2570', 'name': 'OS', 'long_name': 'Operating Systems', 'description': 'Operating systems concepts'}, {'code': 'IT2580', 'name': 'Security', 'long_name': 'Information Security', 'description': 'Information security basics'}, {'code': 'IT3010', 'name': 'Project Management', 'long_name': 'Software Project Management', 'description': 'Project management principles'}, {'code': 'IT3020', 'name': 'DS', 'long_name': 'Data Science', 'description': 'Introduction to data science'}, {'code': 'IT3030', 'name': 'AI', 'long_name': 'Artificial Intelligence', 'description': 'AI fundamentals'}, {'code': 'IT3040', 'name': 'Cloud Computing', 'long_name': 'Cloud Computing', 'description': 'Cloud computing concepts'}, {'code': 'IT3550', 'name': 'ML', 'long_name': 'Machine Learning', 'description': 'Machine learning fundamentals'}, {'code': 'IT3560', 'name': 'Research Methods', 'long_name': 'Research Methods', 'description': 'Research methodology'}, {'code': 'IT3570', 'name': 'DevOps', 'long_name': 'DevOps Practices', 'description': 'DevOps principles'}, {'code': 'IT3580', 'name': 'QA', 'long_name': 'Quality Assurance', 'description': 'Software quality assurance'}, {'code': 'IT4010', 'name': 'Research Project', 'long_name': 'Research Project I', 'description': 'Final year research project'}, {'code': 'IT4020', 'name': 'Enterprise Architecture', 'long_name': 'Enterprise Architecture', 'description': 'Enterprise systems design'}, {'code': 'IT4030', 'name': 'Business Analytics', 'long_name': 'Business Analytics', 'description': 'Business analytics and intelligence'}, {'code': 'IT4550', 'name': 'Research Project II', 'long_name': 'Research Project II', 'description': 'Final year research project continuation'}, {'code': 'IT4560', 'name': 'Emerging Technologies', 'long_name': 'Emerging Technologies', 'description': 'Latest technology trends'}, {'code': 'IT4570', 'name': 'Professional Practice', 'long_name': 'Professional Practice', 'description': 'Professional development'} ...

# %%
class Space:
    def __init__(self, *args):
        self.code = args[0]
        self.size = args[1]


class Group:
    def __init__(self, *args):
        self.id = args[0]
        self.size = args[1]


class Activity:
    def __init__(self, id, *args):
        self.id = id
        self.subject = args[0]
        self.teacher_id = args[1]
        self.group_ids = args[2]
        self.duration = args[3]


class Period:
    def __init__(self, *args):
        self.space = args[0]
        self.group = args[1]
        self.activity = args[2]

# %%
import json

# Load data from JSON file
with open('sliit_computing_dataset.json', 'r') as file:
    data = json.load(file)

# Create dictionaries to store instances
spaces_dict = {}
groups_dict = {}
activities_dict = {}
slots = []
# Populate the dictionaries with data from the JSON file
for space in data['spaces']:
    spaces_dict[space['code']] = Space(space['code'], space['capacity'])

for group in data['years']:
    groups_dict[group['id']] = Group(group['id'], group['size'])

for activity in data['activities']:
    activities_dict[activity['code']] = Activity(
        activity['code'], activity['subject'], activity['teacher_ids'][0], activity['subgroup_ids'], activity['duration'])

for day in ["MON", "TUE", "WED", "THU", "FRI"]:
    for id in range(1, 9):
        slots.append(day+str(id))
# Print the dictionaries to verify
print(spaces_dict)
print(groups_dict)
print(activities_dict)
print(slots)
# Out:
# {'LH401': <__main__.Space object at 0x000001AEA318A090>, 'LH501': <__main__.Space object at 0x000001AEA3142B40>, 'LAB501': <__main__.Space object at 0x000001AEA32B6ED0>, 'LAB502': <__main__.Space object at 0x000001AEA32B7350>}
# {'Y1S1.1': <__main__.Group object at 0x000001AEA32B6E10>, 'Y1S1.2': <__main__.Group object at 0x000001AEA32B7380>, 'Y1S1.3': <__main__.Group object at 0x000001AEA32B6E40>, 'Y1S1.4': <__main__.Group object at 0x000001AEA32B6E70>, 'Y1S1.5': <__main__.Group object at 0x000001AEA32B73B0>, 'Y1S2.1': <__main__.Group object at 0x000001AEA32B7470>, 'Y1S2.2': <__main__.Group object at 0x000001AEA32B6EA0>, 'Y1S2.3': <__main__.Group object at 0x000001AEA32B6C90>, 'Y1S2.4': <__main__.Group object at 0x000001AEA32B6F30>, 'Y1S2.5': <__main__.Group object at 0x000001AEA32B73E0>, 'Y2S1.1': <__main__.Group object at 0x000001AEA32B74A0>, 'Y2S1.2': <__main__.Group object at 0x000001AEA32B6F90>, 'Y2S1.3': <__main__.Group object at 0x000001AEA32B7080>, 'Y2S1.4': <__main__.Group object at 0x000001AEA32B6F60>, 'Y2S1.5': <__main__.Group object at 0x000001AEA32B6F00>, 'Y2S2.1': <__main__.Group object at 0x000001AEA32B7050>, 'Y2S2.2': <__main__.Group object at 0x000001AEA32B7020>, 'Y2S2.3': <__main__.Group object at 0x000001AEA32B70B0>, 'Y2S2.4': <__main__.Group object at 0x000001AEA32B6FF0>, 'Y2S2.5': <__main__.Group object at 0x000001AEA32B6FC0>, 'Y3S1.1': <__main__.Group object at 0x000001AEA32B7530>, 'Y3S1.2': <__main__.Group object at 0x000001AEA32B70E0>, 'Y3S1.3': <__main__.Group object at 0x000001AEA32B75F0>, 'Y3S1.4': <__main__.Group object at 0x000001AEA32B71A0>, 'Y3S1.5': <__main__.Group object at 0x000001AEA32B7560>, 'Y3S2.1': <__main__.Group object at 0x000001AEA32B7500>, 'Y3S2.2': <__main__.Group object at 0x000001AEA32B7620>, 'Y3S2.3': <__main__.Group object at 0x000001AEA32B7680>, 'Y3S2.4': <__main__.Group object at 0x000001AEA32B76B0>, 'Y3S2.5': <__main__.Group object at 0x000001AEA32B75C0>, 'Y4S1.1': <__main__.Group object at 0x000001AEA32B7650>, 'Y4S1.2': <__main__.Group object at 0x000001AEA32B7410>, 'Y4S1.3': <__main__.Group object at 0x000001AEA32B7A40>, 'Y4S1.4': <__main__.Group object at 0x000001AEA32B7710>, 'Y4S1.5': <__main__.Group object at 0x000001AEA32B7A70>, 'Y4S2.1': <__main__.Group object at 0x000001AEA32B7AD0>, 'Y4S2.2': <__main__.Group object at 0x000001AEA32B7B00>, 'Y4S2.3': <__main__.Group object at 0x000001AEA32B7B30>, 'Y4S2.4': <__main__.Group object at 0x000001AEA32B7B90>, 'Y4S2.5': <__main__.Group object at 0x000001AEA32B7C80>}
# {'AC-001': <__main__.Activity object at 0x000001AEA32B7BC0>, 'AC-002': <__main__.Activity object at 0x000001AEA31419D0>, 'AC-003': <__main__.Activity object at 0x000001AEA3143CB0>, 'AC-004': <__main__.Activity object at 0x000001AEA32B7BF0>, 'AC-005': <__main__.Activity object at 0x000001AEA32B76E0>, 'AC-006': <__main__.Activity object at 0x000001AEA32B7DD0>, 'AC-007': <__main__.Activity object at 0x000001AEA32B7C20>, 'AC-008': <__main__.Activity object at 0x000001AEA32B77A0>, 'AC-009': <__main__.Activity object at 0x000001AEA32B77D0>, 'AC-010': <__main__.Activity object at 0x000001AEA32B7770>, 'AC-011': <__main__.Activity object at 0x000001AEA32B7D10>, 'AC-012': <__main__.Activity object at 0x000001AEA32B7740>, 'AC-013': <__main__.Activity object at 0x000001AEA32B7C50>, 'AC-014': <__main__.Activity object at 0x000001AEA32B7950>, 'AC-015': <__main__.Activity object at 0x000001AEA32B7D40>, 'AC-016': <__main__.Activity object at 0x000001AEA32B7CB0>, 'AC-017': <__main__.Activity object at 0x000001AEA32B7D70>, 'AC-018': <__main__.Activity object at 0x000001AEA32B78F0>, 'AC-019': <__main__.Activity object at 0x000001AEA32B7800>, 'AC-020': <__main__.Activity object at 0x000001AEA32B7830>, 'AC-021': <__main__.Activity object at 0x000001AEA32B7E90>, 'AC-022': <__main__.Activity object at 0x000001AEA32B7860>, 'AC-023': <__main__.Activity object at 0x000001AEA32B78C0>, 'AC-024': <__main__.Activity object at 0x000001AEA32B7980>, 'AC-025': <__main__.Activity object at 0x000001AEA32B79B0>, 'AC-026': <__main__.Activity object at 0x000001AEA32B7890>, 'AC-027': <__main__.Activity object at 0x000001AEA32B7590>, 'AC-028': <__main__.Activity object at 0x000001AEA32B7920>, 'AC-029': <__main__.Activity object at 0x000001AEA32B7E00>, 'AC-030': <__main__.Activity object at 0x000001AEA32B7F80>, 'AC-031': <__main__.Activity object at 0x000001AEA32B79E0>, 'AC-032': <__main__.Activity object at 0x000001AEA32B7AA0>, 'AC-033': <__main__.Activity object at 0x000001AEA32B7E30>, 'AC-034': <__main__.Activity object at 0x000001AEA32B7EC0>, 'AC-035': <__main__.Activity object at 0x000001AEA32B7E60>, 'AC-036': <__main__.Activity object at 0x000001AEA32B7A10>, 'AC-037': <__main__.Activity object at 0x000001AEA32B7F20>, 'AC-038': <__main__.Activity object at 0x000001AEA32B7CE0>, 'AC-039': <__main__.Activity object at 0x000001AEA32B7EF0>, 'AC-040': <__main__.Activity object at 0x000001AEA32B7F50>, 'AC-041': <__main__.Activity object at 0x000001AEA32B7FB0>, 'AC-042': <__main__.Activity object at 0x000001AEA32B7FE0>, 'AC-043': <__main__.Activity object at 0x000001AEA32B7DA0>, 'AC-044': <__main__.Activity object at 0x000001AEA32D8050>, 'AC-045': <__main__.Activity object at 0x000001AEA32D8080>, 'AC-046': <__main__.Activity object at 0x000001AEA32D80B0>, 'AC-047': <__main__.Activity object at 0x000001AEA32D80E0>, 'AC-048': <__main__.Activity object at 0x000001AEA32D8110>, 'AC-049': <__main__.Activity object at 0x000001AEA32D8140>, 'AC-050': <__main__.Activity object at 0x000001AEA32D8170>, 'AC-051': <__main__.Activity object at 0x000001AEA32D8230>, 'AC-052': <__main__.Activity object at 0x000001AEA32D8200>, 'AC-053': <__main__.Activity object at 0x000001AEA32D81D0>, 'AC-054': <__main__.Activity object at 0x000001AEA32D81A0>, 'AC-055': <__main__.Activity object at 0x000001AEA32D82F0>, 'AC-056': <__main__.Activity object at 0x000001AEA32D8290>, 'AC-057': <__main__.Activity object at 0x000001AEA32D8260>, 'AC-058': <__main__.Activity object at 0x000001AEA32D8320>, 'AC-059': <__main__.Activity object at 0x000001AEA32D8380>, 'AC-060': <__main__.Activity object at 0x000001AEA32D83B0>, 'AC-061': <__main__.Activity object at 0x000001AEA32D83E0>, 'AC-062': <__main__.Activity object at 0x000001AEA32D8410>, 'AC-063': <__main__.Activity object at 0x000001AEA32D8440>, 'AC-064': <__main__.Activity object at 0x000001AEA32D8470>, 'AC-065': <__main__.Activity object at 0x000001AEA32D84A0>, 'AC-066': <__main__.Activity object at 0x000001AEA32D84D0>, 'AC-067': <__main__.Activity object at  ...
# ['MON1', 'MON2', 'MON3', 'MON4', 'MON5', 'MON6', 'MON7', 'MON8', 'TUE1', 'TUE2', 'TUE3', 'TUE4', 'TUE5', 'TUE6', 'TUE7', 'TUE8', 'WED1', 'WED2', 'WED3', 'WED4', 'WED5', 'WED6', 'WED7', 'WED8', 'THU1', 'THU2', 'THU3', 'THU4', 'THU5', 'THU6', 'THU7', 'THU8', 'FRI1', 'FRI2', 'FRI3', 'FRI4', 'FRI5', 'FRI6', 'FRI7', 'FRI8']

# %%
import random


def fitness(solution):
    room_overbooking = 0
    slot_conflicts = 0
    prof_conflicts = 0

    slot_assignments = {}
    prof_assignments = {}

    # Evaluate room overbooking and slot conflicts
    for entry in solution:
        course_id, student_group, room_id, valid_slots, professor = entry
        course = activities_dict[course_id]
        room = spaces_dict[room_id]

        # Room overbooking
        if room.size < get_classsize(course):
            room_overbooking += 1

        # Slot conflicts (same student in multiple classes at the same time)
        for slot_id in valid_slots:
            if slot_id not in slot_assignments:
                slot_assignments[slot_id] = []
            slot_assignments[slot_id].append((student_group, course_id))

        # Professor conflicts (same professor teaching multiple courses at the same time)
        if course.teacher_id not in prof_assignments:
            prof_assignments[course.teacher_id] = []
        prof_assignments[course.teacher_id].append(slot_id)

    # Calculate slot conflicts
    for slot_id, assignments in slot_assignments.items():
        student_groups_in_slot = {}
        for student_groups, course_id in assignments:
            for student_group in student_groups:
                if student_group in student_groups_in_slot:
                    slot_conflicts += 1  # Conflict when a student is assigned to two courses at the same time
                else:
                    student_groups_in_slot[student_group] = course_id

    # Calculate professor conflicts
    for professor, assigned_slots in prof_assignments.items():
        if len(assigned_slots) > len(set(assigned_slots)):  # Duplicate slots means conflict
            prof_conflicts += 1

    return room_overbooking, slot_conflicts, prof_conflicts


def get_classsize(activity: Activity) -> int:
    classsize = 0
    for id in activity.group_ids:
        classsize += groups_dict[id].size
    return classsize

# Updated create_population function


def create_population(pop_size):
    population = []
    for _ in range(pop_size):
        solution = []
        room_slot_assignments = {space.code: set()
                                 # Track slots per room
                                 for space in spaces_dict.values()}
        prof_slot_assignments = {prof: set() for prof in set(
            activity.teacher_id for activity in activities_dict.values())}  # Track professor slots

        for activity in activities_dict.values():
            # course = courses[course_id]

            student_groups = activity.group_ids
            rooms = [room for room in spaces_dict.values(
            ) if room.size >= get_classsize(activity)]
            # student_group = course.student  # Get student group
            selected_room = random.choice(rooms)  # Random room

            # Find consecutive slots for the course
            valid_slots = [
                slot for slot in slots if slot not in room_slot_assignments[selected_room.code] and slot not in prof_slot_assignments[activity.teacher_id]]

            if len(valid_slots) >= activity.duration:
                selected_slots = random.sample(valid_slots, activity.duration)
            else:
                selected_slots = random.sample(slots, activity.duration)

            for slot in selected_slots:
                room_slot_assignments[selected_room.code].add(slot)
                prof_slot_assignments[activity.teacher_id].add(slot)

            solution.append(
                (activity.id, student_groups, selected_room.code, selected_slots, activity.teacher_id))

        population.append(solution)
    return population

# Crossover function


def crossover(parent1, parent2):
    crossover_point = random.choice(range(1, len(parent1)))
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]
    return child1, child2


# NSGA-II selection based on non-dominated sorting and crowding distance
def non_dominated_sorting(population, fitness_values):
    fronts = [[]]
    rank = [0] * len(population)
    domination_count = [0] * len(population)
    dominated_solutions = [[] for _ in range(len(population))]

    for p in range(len(population)):
        for q in range(len(population)):
            if dominates(fitness_values[p], fitness_values[q]):
                dominated_solutions[p].append(q)
            elif dominates(fitness_values[q], fitness_values[p]):
                domination_count[p] += 1

        if domination_count[p] == 0:
            rank[p] = 0
            fronts[0].append(p)

    front_counter = 0
    while len(fronts[front_counter]) > 0:
        next_front = []
        for p in fronts[front_counter]:
            for q in dominated_solutions[p]:
                domination_count[q] -= 1
                if domination_count[q] == 0:
                    rank[q] = front_counter + 1
                    next_front.append(q)
        front_counter += 1
        fronts.append(next_front)

    return fronts


# Crowding distance for maintaining diversity in the population
def crowding_distance(front, fitness_values):
    distance = [0] * len(front)
    if len(front) > 1:  # Only calculate crowding distance if there are at least two individuals in the front
        sorted_by_first = sorted(front, key=lambda x: fitness_values[x][0])
        sorted_by_second = sorted(front, key=lambda x: fitness_values[x][1])

        # Set infinity for boundary individuals
        distance[0] = distance[-1] = float('inf')
        for i in range(1, len(front) - 1):
            distance[i] = (fitness_values[sorted_by_first[i + 1]][0] - fitness_values[sorted_by_first[i - 1]][0]) + \
                          (fitness_values[sorted_by_second[i + 1]][1] -
                           fitness_values[sorted_by_second[i - 1]][1])

    return distance


# Tournament selection for parents
def tournament_selection(population, fitness_values):
    selected_parents = random.sample(list(range(len(population))), 2)
    p1, p2 = selected_parents[0], selected_parents[1]

    if dominates(fitness_values[p1], fitness_values[p2]):
        return p1
    else:
        return p2


def mutate(solution):
    mutation_point = random.randint(0, len(solution) - 1)
    course_id, student_group, _, _, _ = solution[mutation_point]

    new_room = random.choice(list(spaces_dict.values())).code  # Random room
    new_slot = random.choice(slots)  # Random slot

    professor = activities_dict[course_id].teacher_id
    # Update with new room and slot, keep course_id and student_group the same
    solution[mutation_point] = (
        course_id, student_group, new_room, new_slot, professor)
    return solution

# Domination check


def dominates(fit1, fit2):
    return (fit1[0] <= fit2[0] and fit1[1] <= fit2[1] and fit1[2] <= fit2[2]) and \
           (fit1[0] < fit2[0] or fit1[1] < fit2[1] or fit1[2] < fit2[2])


# Run NSGA-II algorithm
def run_nsga2(pop_size=50, generations=200):
    population = create_population(pop_size)
    for generation in range(generations):
        # Evaluate the fitness of the current population
        fitness_values = [fitness(solution) for solution in population]

        # Non-dominated sorting
        fronts = non_dominated_sorting(population, fitness_values)
        new_population = []

        # Iterate through each front and apply crossover and mutation
        for front in fronts:
            distances = crowding_distance(front, fitness_values)
            sorted_front = sorted(
                front, key=lambda x: distances[front.index(x)], reverse=True)

            # Select parents from the sorted front
            while len(new_population) < pop_size and len(sorted_front) > 1:
                parent1 = population[sorted_front[0]]
                parent2 = population[sorted_front[1]]

                # Crossover
                child1, child2 = crossover(parent1, parent2)

                # Mutation
                child1 = mutate(child1)
                child2 = mutate(child2)

                # Add children to the new population
                new_population.append(child1)
                new_population.append(child2)

        # Truncate to maintain population size
        population = new_population[:pop_size]

        # Print the progress
        if generation % 10 == 0:
            print(
                f"Generation {generation}: Population size {len(population)}")

    return population


# Running the algorithm
best_solution = run_nsga2()
print(f"Best solution: {best_solution}")
# Out:
# Generation 0: Population size 50
# Generation 10: Population size 50
# Generation 20: Population size 50
# Generation 30: Population size 50
# Generation 40: Population size 50
# Generation 50: Population size 50
# Generation 60: Population size 50
# Generation 70: Population size 50
# Generation 80: Population size 50
# Generation 90: Population size 50
# Generation 100: Population size 50
# Generation 110: Population size 50
# Generation 120: Population size 50
# Generation 130: Population size 50
# Generation 140: Population size 50
# Generation 150: Population size 50
# Generation 160: Population size 50
# Generation 170: Population size 50
# Generation 180: Population size 50
# Generation 190: Population size 50
# Best solution: [[('AC-001', ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], 'LH501', ['FRI4', 'WED5'], 'FA0000004'), ('AC-002', ['Y1S1.1'], 'LH501', 'MON3', 'FA0000001'), ('AC-003', ['Y1S1.2'], 'LH401', 'FRI5', 'FA0000006'), ('AC-004', ['Y1S1.3'], 'LAB502', 'THU1', 'FA0000009'), ('AC-005', ['Y1S1.4'], 'LAB501', 'FRI3', 'FA0000008'), ('AC-006', ['Y1S1.5'], 'LH401', 'FRI6', 'FA0000001'), ('AC-007', ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], 'LH401', ['MON4', 'FRI6'], 'FA0000003'), ('AC-008', ['Y1S1.1'], 'LH401', ['THU5'], 'FA0000004'), ('AC-009', ['Y1S1.2'], 'LAB502', 'MON3', 'FA0000004'), ('AC-010', ['Y1S1.3'], 'LAB502', 'FRI7', 'FA0000005'), ('AC-011', ['Y1S1.4'], 'LAB502', 'MON5', 'FA0000004'), ('AC-012', ['Y1S1.5'], 'LAB502', 'MON5', 'FA0000006'), ('AC-013', ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], 'LH401', ['THU8', 'THU3'], 'FA0000006'), ('AC-014', ['Y1S1.1'], 'LH401', 'FRI6', 'FA0000001'), ('AC-015', ['Y1S1.2'], 'LAB502', 'FRI2', 'FA0000007'), ('AC-016', ['Y1S1.3'], 'LH401', ['THU1'], 'FA0000010'), ('AC-017', ['Y1S1.4'], 'LAB502', 'WED2', 'FA0000002'), ('AC-018', ['Y1S1.5'], 'LH501', ['THU4'], 'FA0000005'), ('AC-019', ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'], 'LH401', ['FRI2', 'TUE3'], 'FA0000007'), ('AC-020', ['Y1S1.1'], 'LAB501', 'WED8', 'FA0000006'), ('AC-021', ['Y1S1.2'], 'LH501', 'THU8', 'FA0000005'), ('AC-022', ['Y1S1.3'], 'LAB502', 'WED5', 'FA0000004'), ('AC-023', ['Y1S1.4'], 'LH401', 'THU1', 'FA0000005'), ('AC-024', ['Y1S1.5'], 'LH401', 'TUE7', 'FA0000001'), ('AC-025', ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], 'LH501', ['THU6', 'FRI6'], 'FA0000004'), ('AC-026', ['Y1S2.1'], 'LH401', 'FRI3', 'FA0000006'), ('AC-027', ['Y1S2.2'], 'LAB501', 'FRI3', 'FA0000009'), ('AC-028', ['Y1S2.3'], 'LAB502', 'MON7', 'FA0000008'), ('AC-029', ['Y1S2.4'], 'LAB501', 'THU7', 'FA0000009'), ('AC-030', ['Y1S2.5'], 'LH401', 'FRI5', 'FA0000007'), ('AC-031', ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], 'LH401', ['MON1', 'WED1'], 'FA0000007'), ('AC-032', ['Y1S2.1'], 'LH401', 'MON5', 'FA0000003'), ('AC-033', ['Y1S2.2'], 'LAB502', ['WED4'], 'FA0000006'), ('AC-034', ['Y1S2.3'], 'LAB501', 'THU2', 'FA0000006'), ('AC-035', ['Y1S2.4'], 'LAB502', ['WED2'], 'FA0000005'), ('AC-036', ['Y1S2.5'], 'LAB501', 'MON4', 'FA0000008'), ('AC-037', ['Y1S2.1'], 'LAB501', ['THU5', 'THU8'], 'FA0000009'), ('AC-038', ['Y1S2.2'], 'LH501', 'MON1', 'FA0000006'), ('AC-039', ['Y1S2.3'], 'LH401', 'FRI6', 'FA0000010'), ('AC-040', ['Y1S2.4'], 'LH401', 'WED2', 'FA0000006'), ('AC-041', ['Y1S2.5'], 'LAB502', 'WED8', 'FA0000003'), ('AC-042', ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], 'LH501', ['MON6', 'FRI8'], 'FA0000001'), ('AC-043', ['Y1S2.1'], 'LAB501', 'THU2', 'FA0000003'), ('AC-044', ['Y1S2.2'], 'LH401', 'THU4', 'FA0000006'), ('AC-045', ['Y1S2.3'], 'LAB502', ['TUE5'], 'FA0000004'), ('AC-046', ['Y1S2.4'], 'LAB501', ['TUE8'], 'FA0000009'), ('AC-047', ['Y1S2.5'], 'LAB502', ['THU5'], 'FA0000007'), ('AC-048', ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'], 'LH501', ['TUE3', 'TUE2'], 'FA0000004'), ('AC-049', ['Y1S2.1'], 'LAB502', 'WED8', 'FA0000010'), ('AC-050', ['Y1S2.2'], 'LAB502', ['THU2'], 'FA0000002'), ('AC-051', ['Y1S2.3'], 'LAB502', 'WED1', 'FA0000006'), ('AC-052', ['Y1S2.4'], 'LH401', 'MON3', 'FA0000010'), ('AC-053', ['Y1S2.5'], 'LAB501', 'THU6', 'FA0000001'), ('AC-054', ['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'], 'LH401', ['THU4', 'WED2'], 'FA0000009'), ('AC-055', ['Y2S1.1'], 'LH501', 'MON8', 'FA0000007'), ('AC-056', ['Y2S1.2'], 'LAB501', ['TUE7'], 'FA0000009'), ('AC-057', ['Y2S1.3'], 'LAB502', 'WED7', 'FA0000010'), ('AC-058', ['Y2S1.4'], 'LAB502', 'MON7', 'FA0000001'), ('AC-059', ['Y2S1.5'], 'LH501', ['TUE8'], 'FA0000002'), ('AC-060', ['Y2S1.1'], 'LAB502', ['THU8', 'MON7'], 'FA0000001'), ('AC-061', ['Y2S1.2'], 'LAB501', 'MON3', 'FA0000004'), ('AC-062', ['Y2S1.3'], 'LH401', 'FRI1', 'FA0000001'), ('AC-063', ['Y2S1.4'], 'LAB501', ['FRI5', 'MON5'], 'FA0000006'), ('AC-064', ['Y2S1.5'], 'LAB501', ['WED4', 'WED ...

# %%
best_solution[0], fitness(best_solution[0])
# Out:
# ([('AC-001',
#    ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'],
#    'LH501',
#    ['FRI4', 'WED5'],
#    'FA0000004'),
#   ('AC-002', ['Y1S1.1'], 'LH501', 'MON3', 'FA0000001'),
#   ('AC-003', ['Y1S1.2'], 'LH401', 'FRI5', 'FA0000006'),
#   ('AC-004', ['Y1S1.3'], 'LAB502', 'THU1', 'FA0000009'),
#   ('AC-005', ['Y1S1.4'], 'LAB501', 'FRI3', 'FA0000008'),
#   ('AC-006', ['Y1S1.5'], 'LH401', 'FRI6', 'FA0000001'),
#   ('AC-007',
#    ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'],
#    'LH401',
#    ['MON4', 'FRI6'],
#    'FA0000003'),
#   ('AC-008', ['Y1S1.1'], 'LH401', ['THU5'], 'FA0000004'),
#   ('AC-009', ['Y1S1.2'], 'LAB502', 'MON3', 'FA0000004'),
#   ('AC-010', ['Y1S1.3'], 'LAB502', 'FRI7', 'FA0000005'),
#   ('AC-011', ['Y1S1.4'], 'LAB502', 'MON5', 'FA0000004'),
#   ('AC-012', ['Y1S1.5'], 'LAB502', 'MON5', 'FA0000006'),
#   ('AC-013',
#    ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'],
#    'LH401',
#    ['THU8', 'THU3'],
#    'FA0000006'),
#   ('AC-014', ['Y1S1.1'], 'LH401', 'FRI6', 'FA0000001'),
#   ('AC-015', ['Y1S1.2'], 'LAB502', 'FRI2', 'FA0000007'),
#   ('AC-016', ['Y1S1.3'], 'LH401', ['THU1'], 'FA0000010'),
#   ('AC-017', ['Y1S1.4'], 'LAB502', 'WED2', 'FA0000002'),
#   ('AC-018', ['Y1S1.5'], 'LH501', ['THU4'], 'FA0000005'),
#   ('AC-019',
#    ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'],
#    'LH401',
#    ['FRI2', 'TUE3'],
#    'FA0000007'),
#   ('AC-020', ['Y1S1.1'], 'LAB501', 'WED8', 'FA0000006'),
#   ('AC-021', ['Y1S1.2'], 'LH501', 'THU8', 'FA0000005'),
#   ('AC-022', ['Y1S1.3'], 'LAB502', 'WED5', 'FA0000004'),
#   ('AC-023', ['Y1S1.4'], 'LH401', 'THU1', 'FA0000005'),
#   ('AC-024', ['Y1S1.5'], 'LH401', 'TUE7', 'FA0000001'),
#   ('AC-025',
#    ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'],
#    'LH501',
#    ['THU6', 'FRI6'],
#    'FA0000004'),
#   ('AC-026', ['Y1S2.1'], 'LH401', 'FRI3', 'FA0000006'),
#   ('AC-027', ['Y1S2.2'], 'LAB501', 'FRI3', 'FA0000009'),
#   ('AC-028', ['Y1S2.3'], 'LAB502', 'MON7', 'FA0000008'),
#   ('AC-029', ['Y1S2.4'], 'LAB501', 'THU7', 'FA0000009'),
#   ('AC-030', ['Y1S2.5'], 'LH401', 'FRI5', 'FA0000007'),
#   ('AC-031',
#    ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'],
#    'LH401',
#    ['MON1', 'WED1'],
#    'FA0000007'),
#   ('AC-032', ['Y1S2.1'], 'LH401', 'MON5', 'FA0000003'),
#   ('AC-033', ['Y1S2.2'], 'LAB502', ['WED4'], 'FA0000006'),
#   ('AC-034', ['Y1S2.3'], 'LAB501', 'THU2', 'FA0000006'),
#   ('AC-035', ['Y1S2.4'], 'LAB502', ['WED2'], 'FA0000005'),
#   ('AC-036', ['Y1S2.5'], 'LAB501', 'MON4', 'FA0000008'),
#   ('AC-037', ['Y1S2.1'], 'LAB501', ['THU5', 'THU8'], 'FA0000009'),
#   ('AC-038', ['Y1S2.2'], 'LH501', 'MON1', 'FA0000006'),
#   ('AC-039', ['Y1S2.3'], 'LH401', 'FRI6', 'FA0000010'),
#   ('AC-040', ['Y1S2.4'], 'LH401', 'WED2', 'FA0000006'),
#   ('AC-041', ['Y1S2.5'], 'LAB502', 'WED8', 'FA0000003'),
#   ('AC-042',
#    ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'],
#    'LH501',
#    ['MON6', 'FRI8'],
#    'FA0000001'),
#   ('AC-043', ['Y1S2.1'], 'LAB501', 'THU2', 'FA0000003'),
#   ('AC-044', ['Y1S2.2'], 'LH401', 'THU4', 'FA0000006'),
#   ('AC-045', ['Y1S2.3'], 'LAB502', ['TUE5'], 'FA0000004'),
#   ('AC-046', ['Y1S2.4'], 'LAB501', ['TUE8'], 'FA0000009'),
#   ('AC-047', ['Y1S2.5'], 'LAB502', ['THU5'], 'FA0000007'),
#   ('AC-048',
#    ['Y1S2.1', 'Y1S2.2', 'Y1S2.3', 'Y1S2.4', 'Y1S2.5'],
#    'LH501',
#    ['TUE3', 'TUE2'],
#    'FA0000004'),
#   ('AC-049', ['Y1S2.1'], 'LAB502', 'WED8', 'FA0000010'),
#   ('AC-050', ['Y1S2.2'], 'LAB502', ['THU2'], 'FA0000002'),
#   ('AC-051', ['Y1S2.3'], 'LAB502', 'WED1', 'FA0000006'),
#   ('AC-052', ['Y1S2.4'], 'LH401', 'MON3', 'FA0000010'),
#   ('AC-053', ['Y1S2.5'], 'LAB501', 'THU6', 'FA0000001'),
#   ('AC-054',
#    ['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'],
#    'LH401',
#    ['THU4', 'WED2'],
#    'FA0000009'),
#   ('AC-055', ['Y2S1.1'], 'LH501', 'MON8', 'FA0000007'),
#   ('AC-056', ['Y2S1.2'], 'LAB501', ['TUE7'], 'FA0000009'),
#   ('AC-057', ['Y2S1.3'], 'LAB502', 'WED7', 'FA0000010'),
#   ('AC-058', ['Y2S1.4'], 'LAB502', 'MON7', 'FA0000001'),
#   ('AC-059', ['Y2S1.5'], 'LH501', ['TUE8'], 'FA0000002'),
#   ('AC-060', ['Y2S1.1'], 'LAB502', ['THU8', 'MON7'], 'FA0000001'),
#   ('AC-061', ['Y2S1.2'], 'LAB501', 'MON3', 'FA0000004'),
#   ('AC-062', ['Y2S1.3'], 'LH401', 'FRI1', 'FA0000001'),
#   ('AC-063', ['Y2S1.4'], 'LAB501', ['FRI5', 'MON5'], 'FA0000006'),
#   ('AC-064', ['Y2S1.5'], 'LAB501', ['WED4', 'WED6'], 'FA0000005'),
#   ('AC-065',
#    ['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'],
#    'LH401',
#    ['MON3', 'TUE1'],
#    'FA0000003'),
#   ('AC-066', ['Y2S1.1'], 'LAB502', 'FRI2', 'FA0000008'),
#   ('AC-067', ['Y2S1.2'], 'LH501', ['WED8'], 'FA0000009'),
#   ('AC-068', ['Y2S1.3'], 'LAB502', ['THU3'], 'FA0000002'),
#   ('AC-069', ['Y2S1.4'], 'LH401', 'FRI3', 'FA0000009'),
#   ('AC-070', ['Y2S1.5'], 'LAB502', 'WED7', 'FA0000007'),
#   ('AC-071',
#    ['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'],
#    'LH401',
#    ['TUE5', 'TUE6'],
#    'FA0000008'),
#   ('AC-072', ['Y2S1.1'], 'LAB502', 'THU5', 'FA0000010'),
#   ('AC-073', ['Y2S1.2'], 'LH501', 'FRI7', 'FA0000003'),
#   ('AC-074', ['Y2S1.3'], 'LAB502', 'THU6', 'FA0000009'),
#   ('AC-075', ['Y2S1.4'], 'LH501', 'WED5', 'FA0000006'),
#   ('AC-076', ['Y2S1.5'], 'LAB502', 'MON5', 'FA0000001'),
#   ('AC-077',
#    ['Y2S1.1', 'Y2S1.2', 'Y2S1.3', 'Y2S1.4', 'Y2S1.5'],
#    'LH401',
#    ['FRI1', 'TUE7'],
#    'FA0000006'),
#   ('AC-078', ['Y2S1.1'], 'LH401', ['TUE8'], 'FA0000003'),
#   ('AC-079', ['Y2S1.2'], 'LH501', 'WED6', 'FA0000004'),
#   ('AC-080', ['Y2S1.3'], 'LH401', 'MON3', 'FA0000008'),
#   ('AC-081', ['Y2S1.4'], 'LAB501', ['MON4'], 'FA0000007'),
#   ('AC-082', ['Y2S1.5'], 'LH401', 'THU4', 'FA0000003'),
#   ('AC-083',
#    ['Y2S2.1', 'Y2S2.2', 'Y2S2.3', 'Y2S2.4', 'Y2S2.5'],
#    'LH501',
#    'THU7',
#    'FA0000001'),
#   ('AC-084', ['Y2S2.1'], 'LAB502', 'MON1', 'FA0000008'),
#   ('AC-085', ['Y2S2.2'], 'LAB502', ['THU7'], 'FA0000008'),
#   ('AC-086', ['Y2S2.3'], 'LH401', ['FRI8'], 'FA0000005'),
#   ('AC-087', ['Y2S2.4'], 'LAB502', ['TUE7'], 'FA0000002'),
#   ('AC-088', ['Y2S2.5'], 'LH401', ['WED6'], 'FA0000007'),
#   ('AC-089',
#    ['Y2S2.1', 'Y2S2.2', 'Y2S2.3', 'Y2S2.4', 'Y2S2.5'],
#    'LH501',
#    ['MON1', 'WED1'],
#    'FA0000004'),
#   ('AC-090', ['Y2S2.1'], 'LAB502', 'FRI2', 'FA0000009'),
#   ('AC-091', ['Y2S2.2'], 'LAB501', ['WED2'], 'FA0000001'),
#   ('AC-092', ['Y2S2.3'], 'LAB501', 'MON1', 'FA0000006'),
#   ('AC-093', ['Y2S2.4'], 'LH401', ['FRI3'], 'FA0000009'),
#   ('AC-094', ['Y2S2.5'], 'LAB502', ['MON6'], 'FA0000010'),
#   ('AC-095', ['Y2S2.1'], 'LAB502', ['FRI4', 'WED3'], 'FA0000009'),
#   ('AC-096', ['Y2S2.2'], 'LAB502', 'MON5', 'FA0000004'),
#   ('AC-097', ['Y2S2.3'], 'LAB502', ['FRI7', 'FRI1'], 'FA0000002'),
#   ('AC-098', ['Y2S2.4'], 'LAB502', 'FRI4', 'FA0000004'),
#   ('AC-099', ['Y2S2.5'], 'LH501', 'WED2', 'FA0000009'),
#   ('AC-100',
#    ['Y2S2.1', 'Y2S2.2', 'Y2S2.3', 'Y2S2.4', 'Y2S2.5'],
#    'LH501',
#    ['MON5', 'WED5'],
#    'FA0000009'),
#   ('AC-101', ['Y2S2.1'], 'LAB502', ['FRI5'], 'FA0000005'),
#   ('AC-102', ['Y2S2.2'], 'LAB502', 'WED3', 'FA0000006'),
#   ('AC-103', ['Y2S2.3'], 'LAB501', 'FRI4', 'FA0000008'),
#   ('AC-104', ['Y2S2.4'], 'LAB502', 'WED8', 'FA0000002'),
#   ('AC-105', ['Y2S2.5'], 'LH401', ['MON2'], 'FA0000010'),
#   ('AC-106',
#    ['Y2S2.1', 'Y2S2.2', 'Y2S2.3', 'Y2S2.4', 'Y2S2.5'],
#    'LH401',
#    ['TUE1', 'WED8'],
#    'FA0000002'),
#   ('AC-107', ['Y2S2.1'], 'LH401', 'WED3', 'FA0000003'),
#   ('AC-108', ['Y2S2.2'], 'LH401', 'FRI6', 'FA0000007'),
#   ('AC-109', ['Y2S2.3'], 'LAB502', 'WED8', 'FA0000004'),
#   ('AC-110', ['Y2S2.4'], 'LH401', 'MON5', 'FA0000006'),
#   ('AC-111', ['Y2S2.5'], 'LH401', 'FRI4', 'FA0000007'),
#   ('AC-112',
#    ['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'],
#    'LH501',
#    ['TUE1', 'WED4'],
#    'FA0000007'),
#   ('AC-113', ['Y3S1.1'], 'LH401', ['THU2'], 'FA0000007'),
#   ('AC-114', ['Y3S1.2'], 'LH401', ['TUE3'], 'FA0000010'),
#   ('AC-115', ['Y3S1.3'], 'LAB501', ['FRI8'], 'FA0000010'),
#   ('AC-116', ['Y3S1.4'], 'LH501', 'FRI5', 'FA0000006'),
#   ('AC-117', ['Y3S1.5'], 'LH401', 'MON8', 'FA0000005'),
#   ('AC-118',
#    ['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'],
#    'LH401',
#    ['MON8', 'FRI8'],
#    'FA0000001'),
#   ('AC-119', ['Y3S1.1'], 'LH401', 'THU7', 'FA0000002'),
#   ('AC-120', ['Y3S1.2'], 'LAB502', 'THU5', 'FA0000001'),
#   ('AC-121', ['Y3S1.3'], 'LH401', 'THU4', 'FA0000010'),
#   ('AC-122', ['Y3S1.4'], 'LH401', 'THU1', 'FA0000005'),
#   ('AC-123', ['Y3S1.5'], 'LH401', ['THU3'], 'FA0000006'),
#   ('AC-124',
#    ['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'],
#    'LH501',
#    'WED4',
#    'FA0000004'),
#   ('AC-125', ['Y3S1.1'], 'LH501', ['THU5'], 'FA0000006'),
#   ('AC-126', ['Y3S1.2'], 'LH501', 'MON1', 'FA0000006'),
#   ('AC-127', ['Y3S1.3'], 'LAB502', 'MON6', 'FA0000003'),
#   ('AC-128', ['Y3S1.4'], 'LAB501', 'MON8', 'FA0000008'),
#   ('AC-129', ['Y3S1.5'], 'LH401', 'THU1', 'FA0000010'),
#   ('AC-130',
#    ['Y3S1.1', 'Y3S1.2', 'Y3S1.3', 'Y3S1.4', 'Y3S1.5'],
#    'LH401',
#    ['MON3', 'WED2'],
#    'FA0000007'),
#   ('AC-131', ['Y3S1.1'], 'LH401', ['TUE5'], 'FA0000005'),
#   ('AC-132', ['Y3S1.2'], 'LAB502', 'FRI7', 'FA0000005'),
#   ('AC-133', ['Y3S1.3'], 'LH401', 'FRI1', 'FA0000008'),
#   ('AC-134', ['Y3S1.4'], 'LAB501', ['TUE5'], 'FA0000010'),
#   ('AC-135', ['Y3S1.5'], 'LAB501', 'FRI5', 'FA0000005'),
#   ('AC-136',
#    ['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'],
#    'LH401',
#    ['THU5', 'TUE5'],
#    'FA0000002'),
#   ('AC-137', ['Y3S2.1'], 'LH401', ['MON8'], 'FA0000003'),
#   ('AC-138', ['Y3S2.2'], 'LAB502', 'MON2', 'FA0000010'),
#   ('AC-139', ['Y3S2.3'], 'LAB501', ['MON8'], 'FA0000001'),
#   ('AC-140', ['Y3S2.4'], 'LAB501', ['FRI1'], 'FA0000007'),
#   ('AC-141', ['Y3S2.5'], 'LH401', 'FRI7', 'FA0000001'),
#   ('AC-142',
#    ['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'],
#    'LH401',
#    ['FRI4', 'MON3'],
#    'FA0000008'),
#   ('AC-143', ['Y3S2.1'], 'LH401', 'THU8', 'FA0000005'),
#   ('AC-144', ['Y3S2.2'], 'LH401', 'FRI3', 'FA0000001'),
#   ('AC-145', ['Y3S2.3'], 'LAB502', ['FRI6'], 'FA0000004'),
#   ('AC-146', ['Y3S2.4'], 'LAB502', 'MON3', 'FA0000004'),
#   ('AC-147', ['Y3S2.5'], 'LAB502', 'THU3', 'FA0000004'),
#   ('AC-148',
#    ['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'],
#    'LH401',
#    ['WED8', 'TUE3'],
#    'FA0000003'),
#   ('AC-149', ['Y3S2.1'], 'LH401', ['THU8'], 'FA0000009'),
#   ('AC-150', ['Y3S2.2'], 'LH401', ['WED6'], 'FA0000010'),
#   ('AC-151', ['Y3S2.3'], 'LH401', 'THU1', 'FA0000008'),
#   ('AC-152', ['Y3S2.4'], 'LAB501', ['FRI3'], 'FA0000004'),
#   ('AC-153', ['Y3S2.5'], 'LH501', ['MON4'], 'FA0000008'),
#   ('AC-154',
#    ['Y3S2.1', 'Y3S2.2', 'Y3S2.3', 'Y3S2.4', 'Y3S2.5'],
#    'LH501',
#    'WED6',
#    'FA0000009'),
#   ('AC-155', ['Y3S2.1'], 'LAB501', 'MON3', 'FA0000005'),
#   ('AC-156', ['Y3S2.2'], 'LH401', ['MON4'], 'FA0000010'),
#   ('AC-157', ['Y3S2.3'], 'LAB501', 'FRI7', 'FA0000002'),
#   ('AC-158', ['Y3S2.4'], 'LH401', 'THU4', 'FA0000009'),
#   ('AC-159', ['Y3S2.5'], 'LAB502', 'MON1', 'FA0000005'),
#   ('AC-160',
#    ['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'],
#    'LH401',
#    ['MON3', 'FRI7'],
#    'FA0000006'),
#   ('AC-161', ['Y4S1.1'], 'LAB501', ['THU6'], 'FA0000002'),
#   ('AC-162', ['Y4S1.2'], 'LAB502', 'WED6', 'FA0000009'),
#   ('AC-163', ['Y4S1.3'], 'LH401', ['MON7'], 'FA0000007'),
#   ('AC-164', ['Y4S1.4'], 'LH501', 'FRI1', 'FA0000005'),
#   ('AC-165', ['Y4S1.5'], 'LH501', ['WED8'], 'FA0000009'),
#   ('AC-166',
#    ['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'],
#    'LH501',
#    'MON8',
#    'FA0000002'),
#   ('AC-167', ['Y4S1.1'], 'LH401', 'WED3', 'FA0000001'),
#   ('AC-168', ['Y4S1.2'], 'LH401', 'THU4', 'FA0000006'),
#   ('AC-169', ['Y4S1.3'], 'LH401', 'FRI4', 'FA0000008'),
#   ('AC-170', ['Y4S1.4'], 'LH501', 'THU4', 'FA0000006'),
#   ('AC-171', ['Y4S1.5'], 'LH401', 'TUE2', 'FA0000009'),
#   ('AC-172',
#    ['Y4S1.1', 'Y4S1.2', 'Y4S1.3', 'Y4S1.4', 'Y4S1.5'],
#    'LH501',
#    ['MON2', 'MON1'],
#    'FA0000010'),
#   ('AC-173', ['Y4S1.1'], 'LH401', 'THU6', 'FA0000008'),
#   ('AC-174', ['Y4S1.2'], 'LH401', ['THU7'], 'FA0000002'),
#   ('AC-175', ['Y4S1.3'], 'LAB502', ['FRI6'], 'FA0000004'),
#   ('AC-176', ['Y4S1.4'], 'LAB501', ['TUE4'], 'FA0000007'),
#   ('AC-177', ['Y4S1.5'], 'LH501', ['THU1'], 'FA0000003'),
#   ('AC-178',
#    ['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'],
#    'LH401',
#    ['MON4', 'FRI7'],
#    'FA0000007'),
#   ('AC-179', ['Y4S2.1'], 'LH401', 'THU7', 'FA0000001'),
#   ('AC-180', ['Y4S2.2'], 'LAB501', 'THU6', 'FA0000001'),
#   ('AC-181', ['Y4S2.3'], 'LH401', 'WED4', 'FA0000002'),
#   ('AC-182', ['Y4S2.4'], 'LH501', ['TUE3'], 'FA0000004'),
#   ('AC-183', ['Y4S2.5'], 'LAB501', ['MON5'], 'FA0000007'),
#   ('AC-184',
#    ['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'],
#    'LH401',
#    ['MON6', 'FRI2'],
#    'FA0000001'),
#   ('AC-185', ['Y4S2.1'], 'LAB501', 'FRI3', 'FA0000008'),
#   ('AC-186', ['Y4S2.2'], 'LAB501', 'FRI3', 'FA0000001'),
#   ('AC-187', ['Y4S2.3'], 'LH501', ['THU2'], 'FA0000010'),
#   ('AC-188', ['Y4S2.4'], 'LH401', 'FRI6', 'FA0000001'),
#   ('AC-189', ['Y4S2.5'], 'LH501', 'TUE2', 'FA0000006'),
#   ('AC-190',
#    ['Y4S2.1', 'Y4S2.2', 'Y4S2.3', 'Y4S2.4', 'Y4S2.5'],
#    'LH501',
#    'MON1',
#    'FA0000008'),
#   ('AC-191', ['Y4S2.1'], 'LH501', 'WED6', 'FA0000004'),
#   ('AC-192', ['Y4S2.2'], 'LH501', 'WED2', 'FA0000001'),
#   ('AC-193', ['Y4S2.3'], 'LH501', 'FRI5', 'FA0000004'),
#   ('AC-194', ['Y4S2.4'], 'LH501', 'THU7', 'FA0000005'),
#   ('AC-195', ['Y4S2.5'], 'LH401', 'FRI7', 'FA0000008')],
#  (0, 6, 7))

# %%
minimum_conflicts = 1000
final_solution = "hello"
for solution in best_solution:
    if minimum_conflicts >= sum(fitness(solution)):
        minimum_conflicts = sum(fitness(solution))
        final_solution = solution
print(minimum_conflicts)
# Out:
# 10

# %%
final_solution[0]
# Out:
# ('AC-001',
#  ['Y1S1.1', 'Y1S1.2', 'Y1S1.3', 'Y1S1.4', 'Y1S1.5'],
#  'LH501',
#  ['FRI4', 'WED5'],
#  'FA0000004')

# %%
periods = []
for per in final_solution:
    for slot in per[3]:
        periods.append(Period(per[2],slot,activities_dict[per[0]]))
fitness(final_solution)
periods
# Out:
# [<__main__.Period at 0x1aea32dc950>,
#  <__main__.Period at 0x1aea32dcfe0>,
#  <__main__.Period at 0x1aea32dc5f0>,
#  <__main__.Period at 0x1aea32dce00>,
#  <__main__.Period at 0x1aea32df2c0>,
#  <__main__.Period at 0x1aea32de3c0>,
#  <__main__.Period at 0x1aea32dfec0>,
#  <__main__.Period at 0x1aea32dc080>,
#  <__main__.Period at 0x1aea32dd040>,
#  <__main__.Period at 0x1aea32de4b0>,
#  <__main__.Period at 0x1aea32dda90>,
#  <__main__.Period at 0x1aea3322090>,
#  <__main__.Period at 0x1aea33217f0>,
#  <__main__.Period at 0x1aea33226f0>,
#  <__main__.Period at 0x1aea3321040>,
#  <__main__.Period at 0x1aea3321c70>,
#  <__main__.Period at 0x1aea33214c0>,
#  <__main__.Period at 0x1aea3321160>,
#  <__main__.Period at 0x1aea33221e0>,
#  <__main__.Period at 0x1aea3322600>,
#  <__main__.Period at 0x1aea3321790>,
#  <__main__.Period at 0x1aea33225d0>,
#  <__main__.Period at 0x1aea3322660>,
#  <__main__.Period at 0x1aea3322690>,
#  <__main__.Period at 0x1aea3320320>,
#  <__main__.Period at 0x1aea33224e0>,
#  <__main__.Period at 0x1aea33224b0>,
#  <__main__.Period at 0x1aea3322360>,
#  <__main__.Period at 0x1aea3321b80>,
#  <__main__.Period at 0x1aea3322450>,
#  <__main__.Period at 0x1aea3322480>,
#  <__main__.Period at 0x1aea3322330>,
#  <__main__.Period at 0x1aea3322300>,
#  <__main__.Period at 0x1aea33223c0>,
#  <__main__.Period at 0x1aea3321ca0>,
#  <__main__.Period at 0x1aea3320860>,
#  <__main__.Period at 0x1aea3321940>,
#  <__main__.Period at 0x1aea3322720>,
#  <__main__.Period at 0x1aea3322780>,
#  <__main__.Period at 0x1aea33227e0>,
#  <__main__.Period at 0x1aea3322840>,
#  <__main__.Period at 0x1aea33228a0>,
#  <__main__.Period at 0x1aea3322900>,
#  <__main__.Period at 0x1aea3322960>,
#  <__main__.Period at 0x1aea33229c0>,
#  <__main__.Period at 0x1aea3322a50>,
#  <__main__.Period at 0x1aea3322ab0>,
#  <__main__.Period at 0x1aea3322b10>,
#  <__main__.Period at 0x1aea3322b70>,
#  <__main__.Period at 0x1aea3322bd0>,
#  <__main__.Period at 0x1aea3322c30>,
#  <__main__.Period at 0x1aea3322c90>,
#  <__main__.Period at 0x1aea3322cf0>,
#  <__main__.Period at 0x1aea3322d50>,
#  <__main__.Period at 0x1aea3322db0>,
#  <__main__.Period at 0x1aea3322e10>,
#  <__main__.Period at 0x1aea3322e70>,
#  <__main__.Period at 0x1aea3322ed0>,
#  <__main__.Period at 0x1aea3322f30>,
#  <__main__.Period at 0x1aea3322f90>,
#  <__main__.Period at 0x1aea3322ff0>,
#  <__main__.Period at 0x1aea3323050>,
#  <__main__.Period at 0x1aea33230b0>,
#  <__main__.Period at 0x1aea3323110>,
#  <__main__.Period at 0x1aea3323170>,
#  <__main__.Period at 0x1aea33231d0>,
#  <__main__.Period at 0x1aea3323230>,
#  <__main__.Period at 0x1aea3323290>,
#  <__main__.Period at 0x1aea33232f0>,
#  <__main__.Period at 0x1aea3323350>,
#  <__main__.Period at 0x1aea33233b0>,
#  <__main__.Period at 0x1aea3323410>,
#  <__main__.Period at 0x1aea3323470>,
#  <__main__.Period at 0x1aea33234d0>,
#  <__main__.Period at 0x1aea3323530>,
#  <__main__.Period at 0x1aea3323590>,
#  <__main__.Period at 0x1aea33235f0>,
#  <__main__.Period at 0x1aea3323650>,
#  <__main__.Period at 0x1aea33236b0>,
#  <__main__.Period at 0x1aea3323710>,
#  <__main__.Period at 0x1aea3323770>,
#  <__main__.Period at 0x1aea33237d0>,
#  <__main__.Period at 0x1aea3323830>,
#  <__main__.Period at 0x1aea3323890>,
#  <__main__.Period at 0x1aea33238f0>,
#  <__main__.Period at 0x1aea3323980>,
#  <__main__.Period at 0x1aea33239e0>,
#  <__main__.Period at 0x1aea3323a70>,
#  <__main__.Period at 0x1aea3323ad0>,
#  <__main__.Period at 0x1aea3323b60>,
#  <__main__.Period at 0x1aea3323bc0>,
#  <__main__.Period at 0x1aea3323c20>,
#  <__main__.Period at 0x1aea3323cb0>,
#  <__main__.Period at 0x1aea3323d10>,
#  <__main__.Period at 0x1aea3323da0>,
#  <__main__.Period at 0x1aea3323e00>,
#  <__main__.Period at 0x1aea3323e60>,
#  <__main__.Period at 0x1aea3323ec0>,
#  <__main__.Period at 0x1aea3323f50>,
#  <__main__.Period at 0x1aea3323fb0>,
#  <__main__.Period at 0x1aea3328080>,
#  <__main__.Period at 0x1aea33280e0>,
#  <__main__.Period at 0x1aea3328170>,
#  <__main__.Period at 0x1aea33281d0>,
#  <__main__.Period at 0x1aea3328230>,
#  <__main__.Period at 0x1aea3328290>,
#  <__main__.Period at 0x1aea33282f0>,
#  <__main__.Period at 0x1aea3328350>,
#  <__main__.Period at 0x1aea33283b0>,
#  <__main__.Period at 0x1aea3328410>,
#  <__main__.Period at 0x1aea3328470>,
#  <__main__.Period at 0x1aea33284d0>,
#  <__main__.Period at 0x1aea3328530>,
#  <__main__.Period at 0x1aea3328590>,
#  <__main__.Period at 0x1aea33285f0>,
#  <__main__.Period at 0x1aea3328650>,
#  <__main__.Period at 0x1aea33286b0>,
#  <__main__.Period at 0x1aea3328710>,
#  <__main__.Period at 0x1aea3328770>,
#  <__main__.Period at 0x1aea33287d0>,
#  <__main__.Period at 0x1aea3328830>,
#  <__main__.Period at 0x1aea3328890>,
#  <__main__.Period at 0x1aea33288f0>,
#  <__main__.Period at 0x1aea3328950>,
#  <__main__.Period at 0x1aea33289b0>,
#  <__main__.Period at 0x1aea3328a10>,
#  <__main__.Period at 0x1aea3328a70>,
#  <__main__.Period at 0x1aea3328ad0>,
#  <__main__.Period at 0x1aea3328b30>,
#  <__main__.Period at 0x1aea3328b90>,
#  <__main__.Period at 0x1aea3328bf0>,
#  <__main__.Period at 0x1aea3328c50>,
#  <__main__.Period at 0x1aea3328cb0>,
#  <__main__.Period at 0x1aea3328d10>,
#  <__main__.Period at 0x1aea3328d70>,
#  <__main__.Period at 0x1aea3328dd0>,
#  <__main__.Period at 0x1aea3328e30>,
#  <__main__.Period at 0x1aea3328e90>,
#  <__main__.Period at 0x1aea3328ef0>,
#  <__main__.Period at 0x1aea3328f50>,
#  <__main__.Period at 0x1aea3328fb0>,
#  <__main__.Period at 0x1aea3329010>,
#  <__main__.Period at 0x1aea3329070>,
#  <__main__.Period at 0x1aea33290d0>,
#  <__main__.Period at 0x1aea3329130>,
#  <__main__.Period at 0x1aea3329190>,
#  <__main__.Period at 0x1aea33291f0>,
#  <__main__.Period at 0x1aea3329250>,
#  <__main__.Period at 0x1aea33292b0>,
#  <__main__.Period at 0x1aea3329310>,
#  <__main__.Period at 0x1aea3329370>,
#  <__main__.Period at 0x1aea33293d0>,
#  <__main__.Period at 0x1aea3329430>,
#  <__main__.Period at 0x1aea3329490>,
#  <__main__.Period at 0x1aea33294f0>,
#  <__main__.Period at 0x1aea3329550>,
#  <__main__.Period at 0x1aea33295b0>,
#  <__main__.Period at 0x1aea3329610>,
#  <__main__.Period at 0x1aea3329670>,
#  <__main__.Period at 0x1aea33296d0>,
#  <__main__.Period at 0x1aea3329730>,
#  <__main__.Period at 0x1aea3329790>,
#  <__main__.Period at 0x1aea33297f0>,
#  <__main__.Period at 0x1aea3329850>,
#  <__main__.Period at 0x1aea33298b0>,
#  <__main__.Period at 0x1aea3329910>,
#  <__main__.Period at 0x1aea3329970>,
#  <__main__.Period at 0x1aea3329a00>,
#  <__main__.Period at 0x1aea3329a60>,
#  <__main__.Period at 0x1aea3329af0>,
#  <__main__.Period at 0x1aea3329bb0>,
#  <__main__.Period at 0x1aea3329c40>,
#  <__main__.Period at 0x1aea3329ca0>,
#  <__main__.Period at 0x1aea3329d00>,
#  <__main__.Period at 0x1aea3329d60>,
#  <__main__.Period at 0x1aea3329df0>,
#  <__main__.Period at 0x1aea3329e50>,
#  <__main__.Period at 0x1aea3329eb0>,
#  <__main__.Period at 0x1aea3329f10>,
#  <__main__.Period at 0x1aea3329f70>,
#  <__main__.Period at 0x1aea3329fd0>,
#  <__main__.Period at 0x1aea332a030>,
#  <__main__.Period at 0x1aea332a090>,
#  <__main__.Period at 0x1aea332a0f0>,
#  <__main__.Period at 0x1aea332a150>,
#  <__main__.Period at 0x1aea332a1b0>,
#  <__main__.Period at 0x1aea332a210>,
#  <__main__.Period at 0x1aea332a270>,
#  <__main__.Period at 0x1aea332a2d0>,
#  <__main__.Period at 0x1aea332a330>,
#  <__main__.Period at 0x1aea332a390>,
#  <__main__.Period at 0x1aea332a3f0>,
#  <__main__.Period at 0x1aea332a450>,
#  <__main__.Period at 0x1aea332a4b0>,
#  <__main__.Period at 0x1aea332a510>,
#  <__main__.Period at 0x1aea332a570>,
#  <__main__.Period at 0x1aea332a5d0>,
#  <__main__.Period at 0x1aea332a630>,
#  <__main__.Period at 0x1aea332a690>,
#  <__main__.Period at 0x1aea332a6f0>,
#  <__main__.Period at 0x1aea332a750>,
#  <__main__.Period at 0x1aea332a7b0>,
#  <__main__.Period at 0x1aea332a810>,
#  <__main__.Period at 0x1aea332a870>,
#  <__main__.Period at 0x1aea332a8d0>,
#  <__main__.Period at 0x1aea332a930>,
#  <__main__.Period at 0x1aea332a990>,
#  <__main__.Period at 0x1aea332a9f0>,
#  <__main__.Period at 0x1aea332aa50>,
#  <__main__.Period at 0x1aea332aab0>,
#  <__main__.Period at 0x1aea332ab10>,
#  <__main__.Period at 0x1aea332ab70>,
#  <__main__.Period at 0x1aea332abd0>,
#  <__main__.Period at 0x1aea332ac30>,
#  <__main__.Period at 0x1aea332ac90>,
#  <__main__.Period at 0x1aea332acf0>,
#  <__main__.Period at 0x1aea332ad50>,
#  <__main__.Period at 0x1aea332adb0>,
#  <__main__.Period at 0x1aea332ae10>,
#  <__main__.Period at 0x1aea332ae70>,
#  <__main__.Period at 0x1aea332af30>,
#  <__main__.Period at 0x1aea332af90>,
#  <__main__.Period at 0x1aea332aff0>,
#  <__main__.Period at 0x1aea332b050>,
#  <__main__.Period at 0x1aea332b0b0>,
#  <__main__.Period at 0x1aea332b110>,
#  <__main__.Period at 0x1aea332b170>,
#  <__main__.Period at 0x1aea332b1d0>,
#  <__main__.Period at 0x1aea332b230>,
#  <__main__.Period at 0x1aea332b290>,
#  <__main__.Period at 0x1aea332b2f0>,
#  <__main__.Period at 0x1aea332b350>,
#  <__main__.Period at 0x1aea332b3b0>,
#  <__main__.Period at 0x1aea332b410>,
#  <__main__.Period at 0x1aea332b470>,
#  <__main__.Period at 0x1aea332b4d0>,
#  <__main__.Period at 0x1aea332b530>,
#  <__main__.Period at 0x1aea332b590>,
#  <__main__.Period at 0x1aea332b5f0>,
#  <__main__.Period at 0x1aea332b650>,
#  <__main__.Period at 0x1aea332b6b0>,
#  <__main__.Period at 0x1aea332b710>,
#  <__main__.Period at 0x1aea332b770>,
#  <__main__.Period at 0x1aea332b7d0>,
#  <__main__.Period at 0x1aea332b830>,
#  <__main__.Period at 0x1aea332b890>,
#  <__main__.Period at 0x1aea332b8f0>,
#  <__main__.Period at 0x1aea332b950>,
#  <__main__.Period at 0x1aea332b9b0>,
#  <__main__.Period at 0x1aea332ba10>,
#  <__main__.Period at 0x1aea332ba70>,
#  <__main__.Period at 0x1aea332bad0>,
#  <__main__.Period at 0x1aea332bb30>,
#  <__main__.Period at 0x1aea332bb90>,
#  <__main__.Period at 0x1aea332bbf0>,
#  <__main__.Period at 0x1aea332bc50>,
#  <__main__.Period at 0x1aea332bcb0>,
#  <__main__.Period at 0x1aea332bd10>,
#  <__main__.Period at 0x1aea332bd70>,
#  <__main__.Period at 0x1aea332bdd0>,
#  <__main__.Period at 0x1aea332be30>,
#  <__main__.Period at 0x1aea332be90>,
#  <__main__.Period at 0x1aea332bef0>,
#  <__main__.Period at 0x1aea332bf50>,
#  <__main__.Period at 0x1aea332bfb0>,
#  <__main__.Period at 0x1aea332c050>,
#  <__main__.Period at 0x1aea332c0b0>,
#  <__main__.Period at 0x1aea332c110>,
#  <__main__.Period at 0x1aea332c170>,
#  <__main__.Period at 0x1aea332c1d0>,
#  <__main__.Period at 0x1aea332c230>,
#  <__main__.Period at 0x1aea332c290>,
#  <__main__.Period at 0x1aea332c2f0>,
#  <__main__.Period at 0x1aea332c350>,
#  <__main__.Period at 0x1aea332c3b0>,
#  <__main__.Period at 0x1aea332c410>,
#  <__main__.Period at 0x1aea332c470>,
#  <__main__.Period at 0x1aea332c4d0>,
#  <__main__.Period at 0x1aea332c530>,
#  <__main__.Period at 0x1aea332c590>,
#  <__main__.Period at 0x1aea332c5f0>,
#  <__main__.Period at 0x1aea332c650>,
#  <__main__.Period at 0x1aea332c6b0>,
#  <__main__.Period at 0x1aea332c710>,
#  <__main__.Period at 0x1aea332c770>,
#  <__main__.Period at 0x1aea332c7d0>,
#  <__main__.Period at 0x1aea332c830>,
#  <__main__.Period at 0x1aea332c890>,
#  <__main__.Period at 0x1aea332c8f0>,
#  <__main__.Period at 0x1aea332c950>,
#  <__main__.Period at 0x1aea332c9b0>,
#  <__main__.Period at 0x1aea332ca10>,
#  <__main__.Period at 0x1aea332ca70>,
#  <__main__.Period at 0x1aea332cad0>,
#  <__main__.Period at 0x1aea332cb30>,
#  <__main__.Period at 0x1aea332cb90>,
#  <__main__.Period at 0x1aea332cbf0>,
#  <__main__.Period at 0x1aea332cc50>,
#  <__main__.Period at 0x1aea332ccb0>,
#  <__main__.Period at 0x1aea332cd10>,
#  <__main__.Period at 0x1aea332cd70>,
#  <__main__.Period at 0x1aea332cdd0>,
#  <__main__.Period at 0x1aea332ce30>,
#  <__main__.Period at 0x1aea332ce90>,
#  <__main__.Period at 0x1aea332cef0>,
#  <__main__.Period at 0x1aea332cf50>,
#  <__main__.Period at 0x1aea332cfb0>,
#  <__main__.Period at 0x1aea332d010>,
#  <__main__.Period at 0x1aea332d070>,
#  <__main__.Period at 0x1aea332d0d0>,
#  <__main__.Period at 0x1aea332d130>,
#  <__main__.Period at 0x1aea332d190>,
#  <__main__.Period at 0x1aea332d1f0>,
#  <__main__.Period at 0x1aea1e29130>,
#  <__main__.Period at 0x1aea3140320>,
#  <__main__.Period at 0x1aea3142ab0>,
#  <__main__.Period at 0x1aea3140890>,
#  <__main__.Period at 0x1aea3140f50>,
#  <__main__.Period at 0x1aea3141820>,
#  <__main__.Period at 0x1aea318bc50>,
#  <__main__.Period at 0x1aea31892b0>,
#  <__main__.Period at 0x1aea32dbad0>,
#  <__main__.Period at 0x1aea32da930>,
#  <__main__.Period at 0x1aea32dbd10>,
#  <__main__.Period at 0x1aea32dbdd0>,
#  <__main__.Period at 0x1aea32db560>,
#  <__main__.Period at 0x1aea32db740>,
#  <__main__.Period at 0x1aea32db680>,
#  <__main__.Period at 0x1aea32db1a0>,
#  <__main__.Period at 0x1aea32db380>,
#  <__main__.Period at 0x1aea32dbaa0>,
#  <__main__.Period at 0x1aea32db4a0>,
#  <__main__.Period at 0x1aea32dbc80>,
#  <__main__.Period at 0x1aea32db320>,
#  <__main__.Period at 0x1aea32dbe30>,
#  <__main__.Period at 0x1aea32db7a0>,
#  <__main__.Period at 0x1aea32dd970>,
#  <__main__.Period at 0x1aea32df590>,
#  <__main__.Period at 0x1aea32dff20>,
#  <__main__.Period at 0x1aea32ddd60>,
#  <__main__.Period at 0x1aea32dd730>,
#  <__main__.Period at 0x1aea32de600>,
#  <__main__.Period at 0x1aea32dcaa0>,
#  <__main__.Period at 0x1aea32deba0>,
#  <__main__.Period at 0x1aea32dc680>,
#  <__main__.Period at 0x1aea32de120>,
#  <__main__.Period at 0x1aea32de6c0>,
#  <__main__.Period at 0x1aea32de870>,
#  <__main__.Period at 0x1aea32dc3e0>,
#  <__main__.Period at 0x1aea32df800>,
#  <__main__.Period at 0x1aea32dfaa0>,
#  <__main__.Period at 0x1aea32de1e0>,
#  <__main__.Period at 0x1aea32df4a0>,
#  <__main__.Period at 0x1aea32dfe60>,
#  <__main__.Period at 0x1aea32dde20>,
#  <__main__.Period at 0x1aea32de960>,
#  <__main__.Period at 0x1aea32ddcd0>,
#  <__main__.Period at 0x1aea32dce30>,
#  <__main__.Period at 0x1aea32de090>,
#  <__main__.Period at 0x1aea32ddd30>,
#  <__main__.Period at 0x1aea32dcd40>,
#  <__main__.Period at 0x1aea32dd2b0>,
#  <__main__.Period at 0x1aea32de7e0>,
#  <__main__.Period at 0x1aea32de330>,
#  <__main__.Period at 0x1aea32de5a0>,
#  <__main__.Period at 0x1aea3320ce0>,
#  <__main__.Period at 0x1aea33201d0>,
#  <__main__.Period at 0x1aea3320080>,
#  <__main__.Period at 0x1aea3320f20>,
#  <__main__.Period at 0x1aea3321850>,
#  <__main__.Period at 0x1aea3320d40>,
#  <__main__.Period at 0x1aea33216a0>,
#  <__main__.Period at 0x1aea3320ec0>,
#  <__main__.Period at 0x1aea33200b0>,
#  <__main__.Period at 0x1aea3321e20>,
#  <__main__.Period at 0x1aea3321640>,
#  <__main__.Period at 0x1aea3321250>,
#  <__main__.Period at 0x1aea3321cd0>,
#  <__main__.Period at 0x1aea3321520>,
#  <__main__.Period at 0x1aea33201a0>,
#  <__main__.Period at 0x1aea3320110>,
#  <__main__.Period at 0x1aea3321190>,
#  <__main__.Period at 0x1aea33204a0>,
#  <__main__.Period at 0x1aea3320620>,
#  <__main__.Period at 0x1aea3320f80>,
#  <__main__.Period at 0x1aea3320da0>,
#  <__main__.Period at 0x1aea3320d70>,
#  <__main__.Period at 0x1aea332d280>,
#  <__main__.Period at 0x1aea332d2e0>,
#  <__main__.Period at 0x1aea332d340>,
#  <__main__.Period at 0x1aea332d3a0>,
#  <__main__.Period at 0x1aea332d400>,
#  <__main__.Period at 0x1aea332d460>,
#  <__main__.Period at 0x1aea332d4c0>,
#  <__main__.Period at 0x1aea332d520>,
#  <__main__.Period at 0x1aea332d580>,
#  <__main__.Period at 0x1aea332d5e0>,
#  <__main__.Period at 0x1aea332d640>,
#  <__main__.Period at 0x1aea332d6a0>,
#  <__main__.Period at 0x1aea332d700>,
#  <__main__.Period at 0x1aea332d760>,
#  <__main__.Period at 0x1aea332d7c0>,
#  <__main__.Period at 0x1aea332d820>,
#  <__main__.Period at 0x1aea332d880>,
#  <__main__.Period at 0x1aea332d8e0>,
#  <__main__.Period at 0x1aea332d940>,
#  <__main__.Period at 0x1aea332d9a0>,
#  <__main__.Period at 0x1aea332da00>,
#  <__main__.Period at 0x1aea332da60>,
#  <__main__.Period at 0x1aea332dac0>,
#  <__main__.Period at 0x1aea332db20>,
#  <__main__.Period at 0x1aea332db80>,
#  <__main__.Period at 0x1aea332dbe0>,
#  <__main__.Period at 0x1aea332dc40>,
#  <__main__.Period at 0x1aea332dca0>,
#  <__main__.Period at 0x1aea332dd00>,
#  <__main__.Period at 0x1aea332dd60>,
#  <__main__.Period at 0x1aea332ddc0>,
#  <__main__.Period at 0x1aea332de20>,
#  <__main__.Period at 0x1aea332de80>,
#  <__main__.Period at 0x1aea332dee0>,
#  <__main__.Period at 0x1aea332df40>,
#  <__main__.Period at 0x1aea332dfa0>,
#  <__main__.Period at 0x1aea332e000>,
#  <__main__.Period at 0x1aea332e060>,
#  <__main__.Period at 0x1aea332e0c0>,
#  <__main__.Period at 0x1aea332e120>,
#  <__main__.Period at 0x1aea332e180>,
#  <__main__.Period at 0x1aea332e1e0>,
#  <__main__.Period at 0x1aea332e240>,
#  <__main__.Period at 0x1aea332e2a0>,
#  <__main__.Period at 0x1aea332e300>,
#  <__main__.Period at 0x1aea332e360>,
#  <__main__.Period at 0x1aea332e3c0>,
#  <__main__.Period at 0x1aea332e420>,
#  <__main__.Period at 0x1aea332e480>,
#  <__main__.Period at 0x1aea332e4e0>,
#  <__main__.Period at 0x1aea332e540>,
#  <__main__.Period at 0x1aea332e5a0>,
#  <__main__.Period at 0x1aea332e600>,
#  <__main__.Period at 0x1aea332e660>,
#  <__main__.Period at 0x1aea332e6c0>,
#  <__main__.Period at 0x1aea332e720>,
#  <__main__.Period at 0x1aea332e780>,
#  <__main__.Period at 0x1aea332e7e0>,
#  <__main__.Period at 0x1aea332e840>,
#  <__main__.Period at 0x1aea332e8a0>,
#  <__main__.Period at 0x1aea332e900>,
#  <__main__.Period at 0x1aea332e960>,
#  <__main__.Period at 0x1aea332e9c0>,
#  <__main__.Period at 0x1aea332ea20>,
#  <__main__.Period at 0x1aea332ea80>,
#  <__main__.Period at 0x1aea332eae0>,
#  <__main__.Period at 0x1aea332eb40>,
#  <__main__.Period at 0x1aea332eba0>,
#  <__main__.Period at 0x1aea332ec00>,
#  <__main__.Period at 0x1aea332ec60>,
#  <__main__.Period at 0x1aea332ecc0>,
#  <__main__.Period at 0x1aea332ed20>,
#  <__main__.Period at 0x1aea332ed80>,
#  <__main__.Period at 0x1aea332ede0>,
#  <__main__.Period at 0x1aea332ee40>,
#  <__main__.Period at 0x1aea332eea0>,
#  <__main__.Period at 0x1aea332ef00>,
#  <__main__.Period at 0x1aea332ef60>,
#  <__main__.Period at 0x1aea332efc0>,
#  <__main__.Period at 0x1aea332f020>,
#  <__main__.Period at 0x1aea332f080>,
#  <__main__.Period at 0x1aea332f0e0>,
#  <__main__.Period at 0x1aea332f140>,
#  <__main__.Period at 0x1aea332f1a0>,
#  <__main__.Period at 0x1aea332f200>,
#  <__main__.Period at 0x1aea332f260>,
#  <__main__.Period at 0x1aea332f2c0>,
#  <__main__.Period at 0x1aea332f320>,
#  <__main__.Period at 0x1aea332f380>,
#  <__main__.Period at 0x1aea332f3e0>,
#  <__main__.Period at 0x1aea332f440>,
#  <__main__.Period at 0x1aea332f4a0>,
#  <__main__.Period at 0x1aea332f500>,
#  <__main__.Period at 0x1aea332f560>,
#  <__main__.Period at 0x1aea332f5c0>,
#  <__main__.Period at 0x1aea332f620>,
#  <__main__.Period at 0x1aea332f680>,
#  <__main__.Period at 0x1aea332f6e0>,
#  <__main__.Period at 0x1aea332f740>,
#  <__main__.Period at 0x1aea332f7a0>,
#  <__main__.Period at 0x1aea332f800>,
#  <__main__.Period at 0x1aea332f860>,
#  <__main__.Period at 0x1aea332f8c0>,
#  <__main__.Period at 0x1aea332f920>,
#  <__main__.Period at 0x1aea332f980>,
#  <__main__.Period at 0x1aea332f9e0>,
#  <__main__.Period at 0x1aea332fa40>,
#  <__main__.Period at 0x1aea332faa0>,
#  <__main__.Period at 0x1aea332fb00>,
#  <__main__.Period at 0x1aea332fb60>,
#  <__main__.Period at 0x1aea332fbc0>,
#  <__main__.Period at 0x1aea332fc20>,
#  <__main__.Period at 0x1aea332fc80>,
#  <__main__.Period at 0x1aea332fd40>,
#  <__main__.Period at 0x1aea332fe00>,
#  <__main__.Period at 0x1aea332fe90>,
#  <__main__.Period at 0x1aea332fef0>,
#  <__main__.Period at 0x1aea332ff50>,
#  <__main__.Period at 0x1aea332ffb0>,
#  <__main__.Period at 0x1aea3334050>,
#  <__main__.Period at 0x1aea33340b0>,
#  <__main__.Period at 0x1aea3334110>,
#  <__main__.Period at 0x1aea3334170>,
#  <__main__.Period at 0x1aea33341d0>,
#  <__main__.Period at 0x1aea3334230>,
#  <__main__.Period at 0x1aea3334290>,
#  <__main__.Period at 0x1aea33342f0>,
#  <__main__.Period at 0x1aea3334350>,
#  <__main__.Period at 0x1aea33343b0>,
#  <__main__.Period at 0x1aea3334410>,
#  <__main__.Period at 0x1aea3334470>,
#  <__main__.Period at 0x1aea33344d0>,
#  <__main__.Period at 0x1aea3334530>,
#  <__main__.Period at 0x1aea3334590>,
#  <__main__.Period at 0x1aea33345f0>,
#  <__main__.Period at 0x1aea3334650>,
#  <__main__.Period at 0x1aea33346b0>,
#  <__main__.Period at 0x1aea3334710>,
#  <__main__.Period at 0x1aea3334770>,
#  <__main__.Period at 0x1aea33347d0>,
#  <__main__.Period at 0x1aea3334830>,
#  <__main__.Period at 0x1aea3334890>,
#  <__main__.Period at 0x1aea33348f0>,
#  <__main__.Period at 0x1aea3334950>,
#  <__main__.Period at 0x1aea33349b0>,
#  <__main__.Period at 0x1aea3334a10>,
#  <__main__.Period at 0x1aea3334a70>,
#  <__main__.Period at 0x1aea3334ad0>,
#  <__main__.Period at 0x1aea3334b30>,
#  <__main__.Period at 0x1aea3334b90>,
#  <__main__.Period at 0x1aea3334bf0>,
#  <__main__.Period at 0x1aea3334c50>,
#  <__main__.Period at 0x1aea3334cb0>,
#  <__main__.Period at 0x1aea3334d10>,
#  <__main__.Period at 0x1aea3334d70>,
#  <__main__.Period at 0x1aea3334dd0>,
#  <__main__.Period at 0x1aea3334e30>,
#  <__main__.Period at 0x1aea3334e90>,
#  <__main__.Period at 0x1aea3334ef0>,
#  <__main__.Period at 0x1aea3334f50>,
#  <__main__.Period at 0x1aea3334fb0>,
#  <__main__.Period at 0x1aea3335010>,
#  <__main__.Period at 0x1aea3335070>,
#  <__main__.Period at 0x1aea33350d0>,
#  <__main__.Period at 0x1aea3335130>,
#  <__main__.Period at 0x1aea3335190>,
#  <__main__.Period at 0x1aea33351f0>,
#  <__main__.Period at 0x1aea3335250>,
#  <__main__.Period at 0x1aea33352b0>,
#  <__main__.Period at 0x1aea3335310>,
#  <__main__.Period at 0x1aea3335370>,
#  <__main__.Period at 0x1aea33353d0>,
#  <__main__.Period at 0x1aea3335430>,
#  <__main__.Period at 0x1aea3335490>,
#  <__main__.Period at 0x1aea33354f0>,
#  <__main__.Period at 0x1aea3335550>,
#  <__main__.Period at 0x1aea33355b0>,
#  <__main__.Period at 0x1aea3335610>]

# %%
Activity(final_solution)
